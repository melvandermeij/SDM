# %% [markdown]
# Building recommendation systems using SVD++ and ItemKNN
# ---

# %%
import pandas as pd
import numpy as np

# %%
file_path = r"C:\Users\vahav\OneDrive - HvA\Courses\System Development for Marketing\E-commerce\ecommerce_data.csv"
e_commerce = pd.read_csv(file_path)

# Set the display option to show all columns
pd.set_option('display.max_columns', None)

(e_commerce.head())
# Out:
#    Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0  37-611-6911   22  Female       Middle        Married      Bachelor's
# 1  29-392-9296   49    Male         High        Married     High School
# 2  84-649-5117   24  Female       Middle         Single        Master's
# 3  48-980-6078   29  Female       Middle         Single        Master's
# 4  91-170-9072   33  Female       Middle        Widowed     High School
#
#   Occupation  Location     Purchase_Category  Purchase_Amount  \
# 0     Middle      Évry  Gardening & Outdoors           333.80
# 1       High  Huocheng      Food & Beverages           222.22
# 2       High    Huzhen       Office Supplies           426.22
# 3     Middle    Wiwilí       Home Appliances           101.31
# 4     Middle      Nara             Furniture           211.70
#
#    Frequency_of_Purchase Purchase_Channel  Brand_Loyalty  Product_Rating  \
# 0                      4            Mixed              5               5
# 1                     11         In-Store              3               1
# 2                      2            Mixed              5               5
# 3                      6            Mixed              3               1
# 4                      6            Mixed              3               4
#
#    Time_Spent_on_Product_Research(hours) Social_Media_Influence  \
# 0                                    2.0                    NaN
# 1                                    2.0                 Medium
# 2                                    0.3                    Low
# 3                                    1.0                   High
# 4                                    0.0                 Medium
#
#   Discount_Sensitivity  Return_Rate  Customer_Satisfaction  \
# 0   Somewhat Sensitive            1                      7
# 1        Not Sensitive            1                      5
# 2        Not Sensitive            1                      7
# 3   Somewhat Sensitive            0                      1
# 4        Not Sensitive            2                     10
#
#   Engagement_with_Ads Device_Used_for_Shopping Payment_Method  \
# 0                 NaN                   Tablet    Credit Card
# 1                High                   Tablet         PayPal
# 2                 Low               Smartphone     Debit Card
# 3                 NaN               Smartphone          Other
# 4                 NaN               Smartphone     Debit Card
#
#   Time_of_Purchase  Discount_Used  Customer_Loyalty_Program_Member  \
# 0         3/1/2024           True                            False
# 1        4/16/2024           True                            False
# 2        3/15/2024           True                             True
# 3        10/4/2024           True                             True
# 4        1/30/2024          False                            False
#
#   Purchase_Intent Shipping_Preference  Time_to_Decision Age_Group  \
# 0      Need-based       No Preference                 2     18–25
# 1     Wants-based            Standard                 6     46–50
# 2       Impulsive       No Preference                 3     18–25
# 3      Need-based             Express                10     26–30
# 4     Wants-based       No Preference                 4     31–35
#
#   Purchase_Amount_Group
# 0              $251–350
# 1              $151–250
# 2              $351–450
# 3               $50–150
# 4              $151–250

# %% [markdown]
# ---
# ---
# Model 1: SVD++
# ---
# SVD++ is an advanced version of the Singular Value Decomposition (SVD) algorithm, used in collaborative filtering for recommendation systems. It is particularly effective for predicting user-item interactions by learning latent factors from the data, with an enhancement that takes into account implicit feedback (user behaviors) in addition to explicit ratings (the actual item ratings). The Surprise library is a popular Python library designed for building and evaluating recommender systems, and it includes an implementation of SVD++.
#
# SVD++ in Surprise builds upon the basic SVD algorithm by incorporating implicit feedback (such as views, clicks, or purchases) along with explicit feedback (ratings). This makes it particularly effective when you have sparse rating data, but can gather additional implicit feedback from user interactions. The model works by decomposing the user-item interaction matrix into three matrices:
# - User matrix (U): A matrix that represents latent features associated with users.
# - Item matrix (V): A matrix that represents latent features associated with items.
# - Implicit feedback matrix: This matrix captures the implicit interactions of the users with the items (such as viewing, clicking, etc.).
#
# For SVD++ in Surprise, the input data needs to be in the following format: A user-item interaction dataset: A dataset where each entry represents a user's rating of an item, where:
# - UserID: Identifies the user
# - ItemID: Identifies the item
# - Rating: The rating the user gave to the item
#
# Surprise offers the SVDpp class, which can be instantiated with parameters:
# - n_factors: The number of latent factors (typically between 50 and 200).
# - lr_all: The learning rate for the gradient descent optimization.
# - reg_all: The regularization parameter to prevent overfitting.
# - n_epochs: The number of iterations to train the model.

# %% [markdown]
# **NOTE:**
# Because in this dataset there is record of only one purhcase for each user, we will have to think about recommending users to items rather than items to users. So for the user-item matrix, this means having in each row all the different items (purchase category) and on columns each user (customer).
#
# The underlying logic: "“Which users are most likely to engage with (or be targeted for) a given product category?”"
#
# - Standard setup: User = Customer_ID, Item = Purchase_Category, Rating = Product_Rating
# - Flipped setup: User = Purchase_Category, Item = Customer_ID, Rating = Product_Rating

# %% [markdown]
# ---
# The objective of this model is to build a personalized recommender system using SVD++ from Surprise, and evaluate performance on an e-commerce dataset by leveraging both standard product ratings and a custom rating formula. The model outputs are then later evaluated using both individual user and group fairness metrics. The process is as follows:
#
# 1. Flipped User-Item Structure: Instead of the typical user → item setup, you flipped the structure:
#     - User = Product Category
#     - Item = Customer
#     - This allowes to create recommendations of customers to product categories, which can tehn be switched to get the top 10 predictions for each user. This was done, because the dataset only has 1 user-item interaction for each customer (= 1 rating per customer).
#
# 2. Standard Model Training
#     - A baseline SVD++ model is trained using just the raw product ratings (Product_Rating) as the prediction target.
#     - Surprise's Trainset and testset structures were used for model fitting and evaluation.
#     - The model evaluated happens using:
#         - RMSE (Root Mean Squared Error)
#         - MAE (Mean Absolute Error)
#
# 3. Hyperparameter Tuning (Grid Search)
#     - Performing GridSearchCV over multiple parameter combinations (n_factors, n_epochs, lr_all, reg_all).
#     - Selecting the best model based on lowest RMSE.
#
# 4. Custom Rating Design
#     - Introducing a custom rating that combines:
#         - Product rating (50%)
#         - Customer satisfaction (30%)
#         - Brand loyalty (20%)
#     - This better reflects overall customer sentiment and product quality.
#
# 5. New SVD++ Model on Custom Ratings
#     - Repeating the train-test split and model training using the custom rating.
#     - Adjusting the rating scale to match the new composite score range.
#     - Re-running GridSearchCV to find optimal hyperparameters for the custom rating model.
#     - Builing and evaluating a final SVD++ model using the best hyperparameters.
#
# 6. Top-N Recommendation Generation
#     - Generating top-10 recommended customers per category.
#     - Flipping the normal logic back and generating top-10 recommended categories per customer.

# %% [markdown]
# ---
# Printing product category stats:

# %%
# Compute number of reviews and average rating per product category
category_stats = e_commerce.groupby('Purchase_Category')['Product_Rating'].agg(['count', 'mean']).reset_index()
category_stats.columns = ['Purchase_Category', 'Num_Reviews', 'Avg_Rating']

# Sort by most reviewed categories
category_stats.sort_values(by='Num_Reviews', ascending=False)
# Out:
#             Purchase_Category  Num_Reviews  Avg_Rating
# 6                 Electronics           54    2.888889
# 21          Sports & Outdoors           51    2.882353
# 13            Home Appliances           50    2.940000
# 15      Jewelry & Accessories           50    2.760000
# 22               Toys & Games           47    3.468085
# 0                 Animal Feed           44    3.000000
# 7            Food & Beverages           44    2.704545
# 9        Gardening & Outdoors           44    2.568182
# 20            Software & Apps           43    3.162791
# 19                  Packages)           43    3.046512
# 17         Mobile Accessories           41    3.317073
# 12         Health Supplements           41    3.073171
# 11                Health Care           41    3.097561
# 10                  Groceries           41    2.634146
# 8                   Furniture           41    2.951220
# 2               Baby Products           41    3.463415
# 18            Office Supplies           38    3.157895
# 23  Travel & Leisure (Flights           38    3.578947
# 16               Luxury Goods           37    3.324324
# 4                       Books           37    2.837838
# 14                     Hotels           36    3.277778
# 1               Arts & Crafts           34    2.617647
# 3      Beauty & Personal Care           34    3.264706
# 5                    Clothing           30    2.966667

# %% [markdown]
# It seems that each category has enough reviews so we don't have to drop any of them. However, it's notable to say that the average reviews for each are pretty low. Nothing is above 4.

# %% [markdown]
# Imports the necessary classes from the Surprise library to build, train, and evaluate your SVD++ recommender model:
# - SVDpp: An algorithm used in collaborative filtering for recommendation systems. It works by decomposing the user-item interaction matrix into latent factors (user and item features) and then optimizing them to predict ratings. SVD++ improves upon traditional SVD by also incorporating implicit feedback (e.g., clicks or views), making it more effective in sparse datasets.  The implicit feedback is automatically handled by the model.
# - Dataset: A class in Surprise that provides methods to load data from various sources (e.g., pandas DataFrame, CSV files, etc.) and prepares it in a format that is compatible with Surprise's algorithms. It structures the data as a user-item interaction matrix.
# - Reader: A utility class in Surprise that defines how the data should be interpreted when loaded. For example, it allows you to specify the rating scale (e.g., 1 to 5) and the structure of your data (e.g., columns for user ID, item ID, and rating). It's necessary to set up Surprise with the correct data format.
# - Trainset: A class in Surprise that holds the training data used by the recommendation system algorithm. It is created after the dataset is split (usually with train_test_split) and provides the necessary data structure for training the model (e.g., SVD++).
# - accuracy: A module in Surprise that provides evaluation metrics (such as RMSE, MAE) to assess model performance. These metrics compare the predicted ratings with the actual ratings in the test set, helping you gauge the model's effectiveness.

# %%
from surprise import SVDpp, Dataset, Reader, accuracy

# %% [markdown]
# Defining the User-Item Structure -  flipping the logic to treat categories as users and customers as items, so that the model recommends customers for each product category (because each customer only rates one category):

# %%
# Flip logic: Treat product categories as 'users' and customers as 'items'
ratings_df = e_commerce[['Purchase_Category', 'Customer_ID', 'Product_Rating']].copy()
ratings_df.columns = ['userID', 'itemID', 'rating']

# %% [markdown]
# Performing a stratified 80/20 train-test split for each category so that each category is fairly represented in both sets:

# %%
from sklearn.model_selection import train_test_split

# Manually split by product category (userID)
train_df = pd.DataFrame(columns=ratings_df.columns)
test_df = pd.DataFrame(columns=ratings_df.columns)

for category in ratings_df['userID'].unique():
    category_ratings = ratings_df[ratings_df['userID'] == category]
    train, test = train_test_split(category_ratings, test_size=0.2, random_state=42)
    train_df = pd.concat([train_df, train])
    test_df = pd.concat([test_df, test])

# %% [markdown]
# Results will be that each category will be represented in both sets (no cold-start issue for categories)
# - train_df containing 80% of each category's ratings
# - test_df containing 20% of each category's ratings
#
# Confirming that the train-test split stayed close to 80/20 for each category:

# %%
# Validate that each category has an ~80/20 split
full_counts = ratings_df['userID'].value_counts().sort_index()
train_counts = train_df['userID'].value_counts().sort_index()
test_counts = test_df['userID'].value_counts().sort_index()

verification_df = pd.DataFrame({
    'Total_Ratings': full_counts,
    'Train_Ratings': train_counts,
    'Test_Ratings': test_counts
})

verification_df['Train_%'] = (verification_df['Train_Ratings'] / verification_df['Total_Ratings'] * 100).round(1)
verification_df['Test_%'] = (verification_df['Test_Ratings'] / verification_df['Total_Ratings'] * 100).round(1)

display(verification_df)

issues = verification_df[(verification_df['Train_%'] < 75) | (verification_df['Train_%'] > 85)]
if not issues.empty:
    print("Categories with unexpected train/test split:")
    display(issues)
else:
    print("All categories have a valid 80/20 train/test split.")
# Out:
#                            Total_Ratings  Train_Ratings  Test_Ratings  \
# userID
# Animal Feed                           44             35             9
# Arts & Crafts                         34             27             7
# Baby Products                         41             32             9
# Beauty & Personal Care                34             27             7
# Books                                 37             29             8
# Clothing                              30             24             6
# Electronics                           54             43            11
# Food & Beverages                      44             35             9
# Furniture                             41             32             9
# Gardening & Outdoors                  44             35             9
# Groceries                             41             32             9
# Health Care                           41             32             9
# Health Supplements                    41             32             9
# Home Appliances                       50             40            10
# Hotels                                36             28             8
# Jewelry & Accessories                 50             40            10
# Luxury Goods                          37             29             8
# Mobile Accessories                    41             32             9
# Office Supplies                       38             30             8
# Packages)                             43             34             9
# Software & Apps                       43             34             9
# Sports & Outdoors                     51             40            11
# Toys & Games                          47             37            10
# Travel & Leisure (Flights             38             30             8
#
#                            Train_%  Test_%
# userID
# Animal Feed                   79.5    20.5
# Arts & Crafts                 79.4    20.6
# Baby Products                 78.0    22.0
# Beauty & Personal Care        79.4    20.6
# Books                         78.4    21.6
# Clothing                      80.0    20.0
# Electronics                   79.6    20.4
# Food & Beverages              79.5    20.5
# Furniture                     78.0    22.0
# Gardening & Outdoors          79.5    20.5
# Groceries                     78.0    22.0
# Health Care                   78.0    22.0
# Health Supplements            78.0    22.0
# Home Appliances               80.0    20.0
# Hotels                        77.8    22.2
# Jewelry & Accessories         80.0    20.0
# Luxury Goods                  78.4    21.6
# Mobile Accessories            78.0    22.0
# Office Supplies               78.9    21.1
# Packages)                     79.1    20.9
# Software & Apps               79.1    20.9
# Sports & Outdoors             78.4    21.6
# Toys & Games                  78.7    21.3
# Travel & Leisure (Flights     78.9    21.1
# All categories have a valid 80/20 train/test split.

# %% [markdown]
# Defining rating scale and format data:

# %%
# Define rating scale
reader = Reader(rating_scale=(1, 5))

# Build Surprise trainset object from train_df
trainset = Dataset.load_from_df(train_df[['userID', 'itemID', 'rating']], reader).build_full_trainset()

# Format test_df as Surprise testset (list of tuples)
testset = list(test_df[['userID', 'itemID', 'rating']].itertuples(index=False, name=None))

# %% [markdown]
# The code above converts the ratings_df into a Surprise-compatible format using the Reader object.
#
# Moving to prepare train and test sets for Surprise:

# %%
# Convert training and testing DataFrames into Surprise formats
"""
The training set is converted using Surprise's 'build_full_trainset()', which transforms the DataFrame into a special Trainset object used for model fitting.
The test set is converted into a list of (userID, itemID, rating) tuples, which is the required input format for the model.test() method during evaluation."
"""

trainset = Dataset.load_from_df(train_df[['userID', 'itemID', 'rating']], reader).build_full_trainset()
testset = list(test_df[['userID', 'itemID', 'rating']].itertuples(index=False, name=None))

# %% [markdown]
# - trainset: Surprise’s internal object used to train models.
# - testset: List of tuples in (userID, itemID, rating) format, needed to evaluate the model manually using .test().
#
# Train and Predict with SVD++:

# %%
# Initialize the SVD++ model
svd_model = SVDpp()

# Train the model on the training set
svd_model.fit(trainset)

# Predict on the test set
svd_predictions = svd_model.test(testset)

# %% [markdown]
# Evaluating model performance:

# %%
# Calculate and print RMSE
svd_rmse = accuracy.rmse(svd_predictions)

# Calculate and print MAE
svd_mae = accuracy.mae(svd_predictions)
# Out:
# RMSE: 1.3937
# MAE:  1.2166

# %% [markdown]
# It seems that the model is not performing so good. An RMSE of 1.39 and MAE of 1.21 are relatively high when the ratings are on a 1–5 scale, meaning the model predictions are off by more than a full rating point on average.
#
# Performing a grid search to find the best hyperparameters for the SVD++ model using the product ratings and cross-validation:

# %%
from surprise.model_selection import GridSearchCV
"""GridSearchCV a utility in the Surprise library that performs hyperparameter tuning for collaborative filtering models (like SVD++, KNN, etc.) using cross-validation. 
It helps find the best combination of hyperparameters for the model by evaluating multiple combinations of parameters and selecting the one that gives the best performance."""

# Defineing parameter grid
param_grid = {
    'n_factors': [20, 50, 100],
    'n_epochs': [20, 40, 60],
    'lr_all': [0.003, 0.005, 0.01],
    'reg_all': [0.02, 0.05, 0.1]
}

# Running the grid search with 3-fold cross-validation
gs = GridSearchCV(SVDpp, param_grid, measures=['rmse'], cv=3, joblib_verbose=1)
gs.fit(Dataset.load_from_df(ratings_df, reader))

# Displaing the best RMSE and corresponding hyperparameters
print("Best RMSE:", gs.best_score['rmse'])
print("Best Parameters:", gs.best_params['rmse'])
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:   18.1s
# Best RMSE: 1.4556225240912581
# Best Parameters: {'n_factors': 100, 'n_epochs': 60, 'lr_all': 0.01, 'reg_all': 0.1}

# %% [markdown]
# The RMSE from the GridSearch is higher than with the baseline model. Defining custom rating that better reflects user preferences by blending product rating, customer satisfaction, and brand loyalty might help with the model performance. The weights reflect their relative importance:

# %%
#Creating a custom rating that incorporates product ratings, customer satisfaction, and brand loyalty, with the weights reflecting teh relative importance of each factor
e_commerce['custom_rating'] = (
    0.5 * e_commerce['Product_Rating'] +
    0.3 * e_commerce['Customer_Satisfaction'] +
    0.2 * e_commerce['Brand_Loyalty']
)

(e_commerce['custom_rating'])
# Out:
# 0      5.6
# 1      2.6
# 2      5.6
# 3      1.4
# 4      5.6
#       ...
# 995    3.6
# 996    4.1
# 997    2.5
# 998    4.3
# 999    5.0
# Name: custom_rating, Length: 1000, dtype: float64

# %% [markdown]
# Preparing Surprise Dataset for custom rating:

# %%
# Create flipped user-item dataset using custom ratings
new_ratings_df = e_commerce[['Purchase_Category', 'Customer_ID', 'custom_rating']].copy()
new_ratings_df.columns = ['userID', 'itemID', 'rating']  # flipped

# Define the rating scale for custom scores
new_reader = Reader(rating_scale=(1, 6.5))
new_data = Dataset.load_from_df(new_ratings_df, new_reader)

# %%
new_ratings_df.head()
# Out:
#                  userID       itemID  rating
# 0  Gardening & Outdoors  37-611-6911     5.6
# 1      Food & Beverages  29-392-9296     2.6
# 2       Office Supplies  84-649-5117     5.6
# 3       Home Appliances  48-980-6078     1.4
# 4             Furniture  91-170-9072     5.6

# %% [markdown]
# Performing an 80/20 stratisfied split across all product categories with using the custom rating to ensure balanced evaluation in training and testing:

# %%
# Manually split by category to maintain class balance
new_train_df = pd.DataFrame(columns=new_ratings_df.columns)
new_test_df = pd.DataFrame(columns=new_ratings_df.columns)

for new_category in new_ratings_df['userID'].unique():
    new_category_ratings = new_ratings_df[new_ratings_df['userID'] == new_category]
    train, test = train_test_split(new_category_ratings, test_size=0.2, random_state=42)
    new_train_df = pd.concat([new_train_df, train])
    new_test_df = pd.concat([new_test_df, test])
# Out:
# C:\Users\vahav\AppData\Local\Temp\ipykernel_31124\1612853495.py:8: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   new_train_df = pd.concat([new_train_df, train])
# C:\Users\vahav\AppData\Local\Temp\ipykernel_31124\1612853495.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   new_test_df = pd.concat([new_test_df, test])

# %% [markdown]
# Formatting train/test split for Surprise:

# %%
# Build Surprise-compatible trainset and testset
new_trainset = Dataset.load_from_df(new_train_df[['userID', 'itemID', 'rating']], new_reader).build_full_trainset()
new_testset = list(new_test_df[['userID', 'itemID', 'rating']].itertuples(index=False, name=None))

# %% [markdown]
# Training an initial SVD++ model on the custom ratings, and evaluating its performance using RMSE and MAE:

# %%
# Train SVD++ model
new_svd_model = SVDpp()
new_svd_model.fit(new_trainset)

# Predict and evaluate on test set
new_svd_predictions = new_svd_model.test(new_testset)
new_svd_rmse = accuracy.rmse(new_svd_predictions)
new_svd_mae = accuracy.mae(new_svd_predictions)
# Out:
# RMSE: 1.1371
# MAE:  0.9046

# %% [markdown]
# Optimizing and retraining the SVD++ model using the best hyperparameters found with custom ratings:

# %%
# Run hyperparameter tuning on custom rating dataset
gs = GridSearchCV(SVDpp, param_grid, measures=['rmse'], cv=3, joblib_verbose=1)
gs.fit(new_data)

# Train final model using best params
best_params = gs.best_params['rmse']
final_svdpp_model = SVDpp(**best_params, random_state=42)
final_svdpp_model.fit(new_trainset)
final_svdpp_predictions = final_svdpp_model.test(new_testset)
final_svd_rmse = accuracy.rmse(final_svdpp_predictions)
final_svd_mae = accuracy.mae(final_svdpp_predictions)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:   18.5s
# RMSE: 1.1357
# MAE:  0.9063

# %% [markdown]
# Looping over all combinations of categories and customers, storing and ranking the top 10 customers per product category based on predicted satisfaction:

# %%
from collections import defaultdict

"""
This block predicts the top 10 customers per product category
based on the final tuned SVD++ model.
"""
# Get all unique product categories and customers
categories = new_ratings_df['userID'].unique()    # product categories
customers = new_ratings_df['itemID'].unique()     # customer IDs

# Predict for all (category, customer) pairs
top_10_customers_per_category = defaultdict(list)

for category in categories:
    for customer in customers:
        prediction = final_svdpp_model.predict(uid=category, iid=customer)
        top_10_customers_per_category[category].append((customer, prediction.est))

# Keep top-10 per category
for category in top_10_customers_per_category:
    top_10_customers_per_category[category] = sorted(
        top_10_customers_per_category[category],
        key=lambda x: x[1], reverse=True
    )[:10]

# Print results
for category, top_customers in top_10_customers_per_category.items():
    print(f"\nTop 10 customers for category: {category}")
    for idx, (cust, rating) in enumerate(top_customers, 1):
        print(f"{idx}. Customer ID: {cust} — Predicted Rating: {rating:.2f}")
# Out:
# Top 10 customers for category: Gardening & Outdoors
# 1. Customer ID: 38-912-1128 — Predicted Rating: 4.27
# 2. Customer ID: 37-611-6911 — Predicted Rating: 4.08
# 3. Customer ID: 89-730-1134 — Predicted Rating: 3.96
# 4. Customer ID: 71-876-9118 — Predicted Rating: 3.94
# 5. Customer ID: 67-676-5945 — Predicted Rating: 3.93
# 6. Customer ID: 86-068-2133 — Predicted Rating: 3.92
# 7. Customer ID: 75-964-5589 — Predicted Rating: 3.86
# 8. Customer ID: 16-583-2801 — Predicted Rating: 3.86
# 9. Customer ID: 20-939-3906 — Predicted Rating: 3.83
# 10. Customer ID: 90-144-9193 — Predicted Rating: 3.82
#
# Top 10 customers for category: Food & Beverages
# 1. Customer ID: 23-949-1954 — Predicted Rating: 4.11
# 2. Customer ID: 76-382-7162 — Predicted Rating: 4.09
# 3. Customer ID: 04-213-4617 — Predicted Rating: 4.01
# 4. Customer ID: 48-271-1908 — Predicted Rating: 3.99
# 5. Customer ID: 36-340-8494 — Predicted Rating: 3.98
# 6. Customer ID: 19-383-9741 — Predicted Rating: 3.98
# 7. Customer ID: 41-215-6092 — Predicted Rating: 3.94
# 8. Customer ID: 46-578-1425 — Predicted Rating: 3.94
# 9. Customer ID: 03-991-2098 — Predicted Rating: 3.93
# 10. Customer ID: 62-892-2088 — Predicted Rating: 3.92
#
# Top 10 customers for category: Office Supplies
# 1. Customer ID: 38-912-1128 — Predicted Rating: 4.34
# 2. Customer ID: 84-649-5117 — Predicted Rating: 4.19
# 3. Customer ID: 21-313-7424 — Predicted Rating: 4.15
# 4. Customer ID: 48-315-0196 — Predicted Rating: 4.15
# 5. Customer ID: 22-234-9315 — Predicted Rating: 4.14
# 6. Customer ID: 06-647-3248 — Predicted Rating: 4.12
# 7. Customer ID: 63-631-8261 — Predicted Rating: 4.10
# 8. Customer ID: 20-648-1010 — Predicted Rating: 4.10
# 9. Customer ID: 61-627-1822 — Predicted Rating: 4.10
# 10. Customer ID: 17-551-9779 — Predicted Rating: 4.09
#
# Top 10 customers for category: Home Appliances
# 1. Customer ID: 01-404-3425 — Predicted Rating: 4.26
# 2. Customer ID: 55-237-7991 — Predicted Rating: 4.23
# 3. Customer ID: 09-258-0424 — Predicted Rating: 4.18
# 5. Customer ID: 87-079-0237 — Predicted Rating: 4.22
# 6. Customer ID: 62-644-8183 — Predicted Rating: 4.22
# 7. Customer ID: 26-672-1285 — Predicted Rating: 4.18
# 8. Customer ID: 06-647-3248 — Predicted Rating: 4.17
# 9. Customer ID: 41-854-0707 — Predicted Rating: 4.16
# 10. Customer ID: 34-095-3364 — Predicted Rating: 4.16
#
# Top 10 customers for category: Travel & Leisure (Flights
# 1. Customer ID: 67-939-2463 — Predicted Rating: 4.77
# 2. Customer ID: 33-787-2143 — Predicted Rating: 4.47
# 3. Customer ID: 73-846-1423 — Predicted Rating: 4.43
# 4. Customer ID: 64-846-7450 — Predicted Rating: 4.42
# 5. Customer ID: 88-428-8409 — Predicted Rating: 4.39
# 6. Customer ID: 16-730-2056 — Predicted Rating: 4.38
# 7. Customer ID: 98-376-8787 — Predicted Rating: 4.37
# 8. Customer ID: 71-817-5422 — Predicted Rating: 4.36
# 9. Customer ID: 53-070-2625 — Predicted Rating: 4.34
# 10. Customer ID: 83-670-9273 — Predicted Rating: 4.33
#
# Top 10 customers for category: Jewelry & Accessories
# 1. Customer ID: 53-042-5685 — Predicted Rating: 4.12
# 2. Customer ID: 75-518-2831 — Predicted Rating: 4.06
# 3. Customer ID: 66-772-9922 — Predicted Rating: 3.98
# 4. Customer ID: 27-463-5671 — Predicted Rating: 3.95
# 5. Customer ID: 71-817-5422 — Predicted Rating: 3.93
# 6. Customer ID: 72-830-1211 — Predicted Rating: 3.93
# 7. Customer ID: 23-949-1954 — Predicted Rating: 3.86
# 8. Customer ID: 63-684-4073 — Predicted Rating: 3.86
# 9. Customer ID: 47-356-9730 — Predicted Rating: 3.85
# 10. Customer ID: 80-830-3184 — Predicted Rating: 3.84

# %% [markdown]
# Flipping the logic back and building personalized recommendations for each customer by ranking product categories based on predicted satisfaction:

# %%
# Recommend top categories per customer
SVDpp_top_10_categories_per_customer = defaultdict(list)

for customer in customers:
    for category in categories:
        prediction = final_svdpp_model.predict(uid=category, iid=customer)
        SVDpp_top_10_categories_per_customer[customer].append((category, prediction.est))

# Keep top 10 categories per customer
for customer in SVDpp_top_10_categories_per_customer:
    SVDpp_top_10_categories_per_customer[customer] = sorted(
        SVDpp_top_10_categories_per_customer[customer],
        key=lambda x: x[1], reverse=True
    )[:10]

# Print recommendations
for customer, recs in SVDpp_top_10_categories_per_customer.items():
    print("=" * 60)
    print(f"Customer ID: {customer}")
    print("Top 10 Recommended Product Categories:")
    print("-" * 60)
    for idx, (category, rating) in enumerate(recs, 1):
        print(f"{idx:>2}. {category:<35} | Predicted Rating: {rating:.2f}")
    print("=" * 60 + "\n")
# Out:
# ============================================================
# Customer ID: 37-611-6911
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Baby Products                       | Predicted Rating: 4.58
#  2. Travel & Leisure (Flights           | Predicted Rating: 4.23
#  3. Hotels                              | Predicted Rating: 4.22
#  4. Clothing                            | Predicted Rating: 4.18
#  5. Toys & Games                        | Predicted Rating: 4.11
#  6. Luxury Goods                        | Predicted Rating: 4.08
#  7. Beauty & Personal Care              | Predicted Rating: 4.08
#  8. Gardening & Outdoors                | Predicted Rating: 4.08
#  9. Arts & Crafts                       | Predicted Rating: 3.90
# 10. Furniture                           | Predicted Rating: 3.89
# ============================================================
#
# ============================================================
# Customer ID: 29-392-9296
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 3.90
#  2. Hotels                              | Predicted Rating: 3.89
#  3. Mobile Accessories                  | Predicted Rating: 3.86
#  4. Baby Products                       | Predicted Rating: 3.85
#  5. Electronics                         | Predicted Rating: 3.84
#  6. Health Care                         | Predicted Rating: 3.80
#  7. Packages)                           | Predicted Rating: 3.78
#  8. Animal Feed                         | Predicted Rating: 3.77
#  9. Software & Apps                     | Predicted Rating: 3.77
# 10. Beauty & Personal Care              | Predicted Rating: 3.77
# ============================================================
#
# ============================================================
# Customer ID: 84-649-5117
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.42
#  2. Baby Products                       | Predicted Rating: 4.25
#  3. Office Supplies                     | Predicted Rating: 4.19
#  4. Travel & Leisure (Flights           | Predicted Rating: 4.08
#  5. Luxury Goods                        | Predicted Rating: 4.08
#  6. Sports & Outdoors                   | Predicted Rating: 4.06
#  7. Mobile Accessories                  | Predicted Rating: 4.04
#  8. Software & Apps                     | Predicted Rating: 4.02
#  9. Packages)                           | Predicted Rating: 4.01
# 10. Hotels                              | Predicted Rating: 4.00
# ============================================================
#
# ============================================================
# Customer ID: 48-980-6078
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.11
#  2. Hotels                              | Predicted Rating: 4.00
#  3. Electronics                         | Predicted Rating: 3.85
#  4. Software & Apps                     | Predicted Rating: 3.85
#  5. Travel & Leisure (Flights           | Predicted Rating: 3.84
#  6. Health Care                         | Predicted Rating: 3.83
#  7. Luxury Goods                        | Predicted Rating: 3.77
#  8. Health Supplements                  | Predicted Rating: 3.75
#  9. Packages)                           | Predicted Rating: 3.72
# 10. Baby Products                       | Predicted Rating: 3.71
# ============================================================
#
# ============================================================
# Customer ID: 91-170-9072
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Baby Products                       | Predicted Rating: 4.37
#  2. Furniture                           | Predicted Rating: 4.34
#  3. Toys & Games                        | Predicted Rating: 4.22
#  4. Hotels                              | Predicted Rating: 4.13
#  5. Beauty & Personal Care              | Predicted Rating: 4.13
#  6. Packages)                           | Predicted Rating: 4.05
#  7. Travel & Leisure (Flights           | Predicted Rating: 4.00
#  8. Sports & Outdoors                   | Predicted Rating: 3.99
#  9. Home Appliances                     | Predicted Rating: 3.96
# 10. Clothing                            | Predicted Rating: 3.88
# ============================================================
#
# ============================================================
# Customer ID: 82-561-4233
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.04
#  2. Baby Products                       | Predicted Rating: 4.02
#  3. Clothing                            | Predicted Rating: 3.99
#  4. Furniture                           | Predicted Rating: 3.95
#  5. Toys & Games                        | Predicted Rating: 3.93
#  6. Mobile Accessories                  | Predicted Rating: 3.92
#  7. Electronics                         | Predicted Rating: 3.91
#  8. Animal Feed                         | Predicted Rating: 3.81
#  9. Hotels                              | Predicted Rating: 3.78
# 10. Beauty & Personal Care              | Predicted Rating: 3.76
# ============================================================
#
# ============================================================
# Customer ID: 90-144-9193
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Baby Products                       | Predicted Rating: 4.31
#  2. Furniture                           | Predicted Rating: 4.07
#  3. Toys & Games                        | Predicted Rating: 4.05
#  4. Beauty & Personal Care              | Predicted Rating: 4.00
#  5. Hotels                              | Predicted Rating: 3.98
#  6. Animal Feed                         | Predicted Rating: 3.96
#  7. Travel & Leisure (Flights           | Predicted Rating: 3.94
#  8. Luxury Goods                        | Predicted Rating: 3.90
#  9. Mobile Accessories                  | Predicted Rating: 3.89
# 10. Groceries                           | Predicted Rating: 3.86
# ============================================================
#
# ============================================================
# Customer ID: 88-661-4689
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.27
#  2. Baby Products                       | Predicted Rating: 4.21
#  3. Toys & Games                        | Predicted Rating: 4.14
#  4. Books                               | Predicted Rating: 4.07
#  5. Hotels                              | Predicted Rating: 4.04
#  6. Packages)                           | Predicted Rating: 4.04
#  7. Mobile Accessories                  | Predicted Rating: 4.02
#  8. Luxury Goods                        | Predicted Rating: 4.01
#  9. Animal Feed                         | Predicted Rating: 3.93
# 10. Electronics                         | Predicted Rating: 3.88
# ============================================================
#
# ============================================================
# Customer ID: 37-065-3182
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.22
#  2. Travel & Leisure (Flights           | Predicted Rating: 4.09
#  3. Luxury Goods                        | Predicted Rating: 4.07
#  4. Baby Products                       | Predicted Rating: 4.04
#  5. Hotels                              | Predicted Rating: 3.82
#  6. Electronics                         | Predicted Rating: 3.82
#  7. Clothing                            | Predicted Rating: 3.78
#  8. Animal Feed                         | Predicted Rating: 3.76
#  9. Software & Apps                     | Predicted Rating: 3.75
# 10. Office Supplies                     | Predicted Rating: 3.71
# ============================================================
#
# ============================================================
# Customer ID: 84-894-9222
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.05
#  2. Baby Products                       | Predicted Rating: 4.04
#  3. Toys & Games                        | Predicted Rating: 4.02
#  4. Electronics                         | Predicted Rating: 3.99
#  5. Software & Apps                     | Predicted Rating: 3.99
#  6. Hotels                              | Predicted Rating: 3.95
#  7. Health Care                         | Predicted Rating: 3.92
#  8. Food & Beverages                    | Predicted Rating: 3.86
#  9. Animal Feed                         | Predicted Rating: 3.86
# 10. Luxury Goods                        | Predicted Rating: 3.85
# ============================================================
#
# ============================================================
# Customer ID: 44-674-4037
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.01
#  2. Electronics                         | Predicted Rating: 3.98
#  3. Baby Products                       | Predicted Rating: 3.97
#  4. Software & Apps                     | Predicted Rating: 3.96
#  5. Mobile Accessories                  | Predicted Rating: 3.94
#  6. Hotels                              | Predicted Rating: 3.93
#  7. Furniture                           | Predicted Rating: 3.89
#  8. Office Supplies                     | Predicted Rating: 3.89
#  9. Travel & Leisure (Flights           | Predicted Rating: 3.81
# 10. Packages)                           | Predicted Rating: 3.81
# ============================================================
#
# ============================================================
# Customer ID: 78-116-8349
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 4.28
#  2. Toys & Games                        | Predicted Rating: 4.17
#  3. Luxury Goods                        | Predicted Rating: 4.12
#  4. Electronics                         | Predicted Rating: 4.07
#  5. Sports & Outdoors                   | Predicted Rating: 4.06
#  6. Office Supplies                     | Predicted Rating: 4.04
#  7. Baby Products                       | Predicted Rating: 4.04
#  8. Packages)                           | Predicted Rating: 4.02
#  9. Travel & Leisure (Flights           | Predicted Rating: 4.02
# 10. Mobile Accessories                  | Predicted Rating: 3.95
# ============================================================
#
# ============================================================
# Customer ID: 19-933-8095
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.25
#  2. Electronics                         | Predicted Rating: 4.13
#  3. Mobile Accessories                  | Predicted Rating: 4.07
#  4. Hotels                              | Predicted Rating: 3.99
#  5. Software & Apps                     | Predicted Rating: 3.98
#  6. Baby Products                       | Predicted Rating: 3.93
#  7. Beauty & Personal Care              | Predicted Rating: 3.91
#  8. Travel & Leisure (Flights           | Predicted Rating: 3.89
#  9. Health Care                         | Predicted Rating: 3.87
# 10. Luxury Goods                        | Predicted Rating: 3.86
# ============================================================
#
# ============================================================
# Customer ID: 80-684-5072
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Animal Feed                         | Predicted Rating: 4.36
#  2. Software & Apps                     | Predicted Rating: 4.29
#  3. Hotels                              | Predicted Rating: 4.25
#  4. Travel & Leisure (Flights           | Predicted Rating: 4.10
#  5. Health Supplements                  | Predicted Rating: 4.08
#  6. Sports & Outdoors                   | Predicted Rating: 4.07
#  7. Groceries                           | Predicted Rating: 4.02
#  8. Toys & Games                        | Predicted Rating: 4.02
#  9. Baby Products                       | Predicted Rating: 4.01
# 10. Home Appliances                     | Predicted Rating: 4.00
# ============================================================
#
# ============================================================
# Customer ID: 23-302-7502
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.19
#  2. Toys & Games                        | Predicted Rating: 4.16
#  3. Hotels                              | Predicted Rating: 4.05
#  4. Furniture                           | Predicted Rating: 4.00
#  5. Sports & Outdoors                   | Predicted Rating: 3.95
#  6. Clothing                            | Predicted Rating: 3.95
#  7. Mobile Accessories                  | Predicted Rating: 3.94
#  8. Software & Apps                     | Predicted Rating: 3.94
#  9. Arts & Crafts                       | Predicted Rating: 3.91
# 10. Baby Products                       | Predicted Rating: 3.89
# ============================================================
#
# ============================================================
# Customer ID: 90-069-8934
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.18
#  2. Travel & Leisure (Flights           | Predicted Rating: 4.04
#  3. Baby Products                       | Predicted Rating: 3.99
#  4. Electronics                         | Predicted Rating: 3.93
#  5. Hotels                              | Predicted Rating: 3.90
#  6. Software & Apps                     | Predicted Rating: 3.89
#  7. Mobile Accessories                  | Predicted Rating: 3.87
#  8. Clothing                            | Predicted Rating: 3.82
#  9. Animal Feed                         | Predicted Rating: 3.76
# 10. Luxury Goods                        | Predicted Rating: 3.70
# ============================================================
#
# ============================================================
# Customer ID: 45-073-7243
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Furniture                           | Predicted Rating: 4.25
#  2. Software & Apps                     | Predicted Rating: 4.20
#  3. Hotels                              | Predicted Rating: 4.15
#  4. Clothing                            | Predicted Rating: 4.11
#  5. Health Care                         | Predicted Rating: 4.05
#  6. Toys & Games                        | Predicted Rating: 4.00
#  7. Health Supplements                  | Predicted Rating: 3.97
#  8. Electronics                         | Predicted Rating: 3.97
#  9. Travel & Leisure (Flights           | Predicted Rating: 3.92
# 10. Baby Products                       | Predicted Rating: 3.84
# ============================================================
#
# ============================================================
# Customer ID: 89-883-2101
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.29
#  2. Travel & Leisure (Flights           | Predicted Rating: 4.22
#  3. Hotels                              | Predicted Rating: 4.19
#  4. Mobile Accessories                  | Predicted Rating: 4.14
#  5. Clothing                            | Predicted Rating: 4.01
#  6. Electronics                         | Predicted Rating: 3.97
#  7. Software & Apps                     | Predicted Rating: 3.96
#  8. Beauty & Personal Care              | Predicted Rating: 3.95
#  9. Baby Products                       | Predicted Rating: 3.94
# 10. Health Care                         | Predicted Rating: 3.91
# ============================================================
#
# ============================================================
# Customer ID: 00-477-9449
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.12
#  2. Toys & Games                        | Predicted Rating: 4.12
#  3. Baby Products                       | Predicted Rating: 4.07
#  4. Hotels                              | Predicted Rating: 4.01
#  5. Luxury Goods                        | Predicted Rating: 3.96
#  6. Mobile Accessories                  | Predicted Rating: 3.93
#  7. Furniture                           | Predicted Rating: 3.90
#  8. Sports & Outdoors                   | Predicted Rating: 3.90
#  9. Clothing                            | Predicted Rating: 3.89
# 10. Electronics                         | Predicted Rating: 3.85
# ============================================================
#
# ============================================================
# Customer ID: 67-159-7366
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Baby Products                       | Predicted Rating: 4.01
#  2. Software & Apps                     | Predicted Rating: 3.98
#  3. Travel & Leisure (Flights           | Predicted Rating: 3.97
#  4. Hotels                              | Predicted Rating: 3.88
#  5. Luxury Goods                        | Predicted Rating: 3.88
#  6. Health Supplements                  | Predicted Rating: 3.85
#  7. Toys & Games                        | Predicted Rating: 3.80
#  8. Office Supplies                     | Predicted Rating: 3.77
#  9. Packages)                           | Predicted Rating: 3.77
# 10. Clothing                            | Predicted Rating: 3.74
# ============================================================
#
# ============================================================
# Customer ID: 85-691-4293
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.12
#  2. Baby Products                       | Predicted Rating: 4.10
#  3. Hotels                              | Predicted Rating: 4.04
#  4. Toys & Games                        | Predicted Rating: 3.96
#  5. Electronics                         | Predicted Rating: 3.81
#  6. Office Supplies                     | Predicted Rating: 3.77
#  7. Furniture                           | Predicted Rating: 3.77
#  8. Luxury Goods                        | Predicted Rating: 3.76
#  9. Beauty & Personal Care              | Predicted Rating: 3.72
# 10. Books                               | Predicted Rating: 3.68
# ============================================================
#
# ============================================================
# Customer ID: 56-085-0464
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.10
#  2. Software & Apps                     | Predicted Rating: 4.02
#  3. Hotels                              | Predicted Rating: 3.99
#  4. Travel & Leisure (Flights           | Predicted Rating: 3.84
#  5. Baby Products                       | Predicted Rating: 3.79
#  6. Packages)                           | Predicted Rating: 3.79
#  7. Luxury Goods                        | Predicted Rating: 3.79
#  8. Arts & Crafts                       | Predicted Rating: 3.72
#  9. Furniture                           | Predicted Rating: 3.72
# 10. Groceries                           | Predicted Rating: 3.72
# ============================================================
#
# ============================================================
# Customer ID: 33-264-2822
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 3.99
#  2. Travel & Leisure (Flights           | Predicted Rating: 3.96
#  3. Packages)                           | Predicted Rating: 3.95
#  4. Toys & Games                        | Predicted Rating: 3.91
#  5. Sports & Outdoors                   | Predicted Rating: 3.89
#  6. Software & Apps                     | Predicted Rating: 3.83
#  7. Mobile Accessories                  | Predicted Rating: 3.80
#  8. Health Supplements                  | Predicted Rating: 3.79
#  9. Clothing                            | Predicted Rating: 3.78
# 10. Animal Feed                         | Predicted Rating: 3.77
# ============================================================
#
# ============================================================
# Customer ID: 95-478-2650
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.25
#  2. Luxury Goods                        | Predicted Rating: 4.14
#  3. Baby Products                       | Predicted Rating: 4.11
#  4. Beauty & Personal Care              | Predicted Rating: 4.07
#  5. Hotels                              | Predicted Rating: 4.06
#  6. Software & Apps                     | Predicted Rating: 4.02
#  7. Toys & Games                        | Predicted Rating: 3.99
#  8. Clothing                            | Predicted Rating: 3.96
#  9. Electronics                         | Predicted Rating: 3.94
# 10. Furniture                           | Predicted Rating: 3.90
# ============================================================
#
# ============================================================
# Customer ID: 04-349-6759
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.33
#  2. Travel & Leisure (Flights           | Predicted Rating: 4.12
#  3. Baby Products                       | Predicted Rating: 4.04
#  4. Electronics                         | Predicted Rating: 4.02
#  5. Hotels                              | Predicted Rating: 4.01
#  6. Mobile Accessories                  | Predicted Rating: 4.00
#  7. Furniture                           | Predicted Rating: 3.99
#  8. Clothing                            | Predicted Rating: 3.95
#  9. Beauty & Personal Care              | Predicted Rating: 3.95
# 10. Health Care                         | Predicted Rating: 3.87
# ============================================================
#
# ============================================================
# Customer ID: 21-755-8745
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.06
#  2. Hotels                              | Predicted Rating: 3.98
#  3. Baby Products                       | Predicted Rating: 3.97
#  4. Software & Apps                     | Predicted Rating: 3.96
#  5. Mobile Accessories                  | Predicted Rating: 3.95
#  6. Electronics                         | Predicted Rating: 3.90
#  7. Office Supplies                     | Predicted Rating: 3.86
#  8. Animal Feed                         | Predicted Rating: 3.85
#  9. Health Care                         | Predicted Rating: 3.85
# 10. Beauty & Personal Care              | Predicted Rating: 3.80
# ============================================================
#
# ============================================================
# Customer ID: 29-625-7057
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 4.07
#  2. Travel & Leisure (Flights           | Predicted Rating: 4.02
#  3. Toys & Games                        | Predicted Rating: 4.01
#  4. Baby Products                       | Predicted Rating: 4.01
#  5. Mobile Accessories                  | Predicted Rating: 3.96
#  6. Furniture                           | Predicted Rating: 3.92
#  7. Office Supplies                     | Predicted Rating: 3.82
#  8. Software & Apps                     | Predicted Rating: 3.76
#  9. Packages)                           | Predicted Rating: 3.75
# 10. Electronics                         | Predicted Rating: 3.72
# ============================================================
#
# ============================================================
# Customer ID: 58-623-8404
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Luxury Goods                        | Predicted Rating: 4.00
#  2. Electronics                         | Predicted Rating: 3.83
#  3. Mobile Accessories                  | Predicted Rating: 3.83
#  4. Toys & Games                        | Predicted Rating: 3.81
#  5. Travel & Leisure (Flights           | Predicted Rating: 3.80
#  6. Arts & Crafts                       | Predicted Rating: 3.77
#  7. Baby Products                       | Predicted Rating: 3.75
#  8. Hotels                              | Predicted Rating: 3.72
#  9. Home Appliances                     | Predicted Rating: 3.72
# 10. Groceries                           | Predicted Rating: 3.71
# ============================================================
#
# ============================================================
# Customer ID: 56-506-4709
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.08
#  2. Packages)                           | Predicted Rating: 3.93
#  3. Hotels                              | Predicted Rating: 3.93
#  4. Mobile Accessories                  | Predicted Rating: 3.92
#  5. Software & Apps                     | Predicted Rating: 3.88
#  6. Toys & Games                        | Predicted Rating: 3.80
#  7. Arts & Crafts                       | Predicted Rating: 3.79
#  8. Baby Products                       | Predicted Rating: 3.78
#  9. Animal Feed                         | Predicted Rating: 3.75
# 10. Luxury Goods                        | Predicted Rating: 3.75
# ============================================================
#
# ============================================================
# Customer ID: 25-839-8670
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.16
#  2. Software & Apps                     | Predicted Rating: 4.09
#  3. Toys & Games                        | Predicted Rating: 3.99
#  4. Luxury Goods                        | Predicted Rating: 3.95
#  5. Clothing                            | Predicted Rating: 3.94
#  6. Baby Products                       | Predicted Rating: 3.91
#  7. Hotels                              | Predicted Rating: 3.88
#  8. Mobile Accessories                  | Predicted Rating: 3.85
#  9. Furniture                           | Predicted Rating: 3.79
# 10. Animal Feed                         | Predicted Rating: 3.79
# ============================================================
#
# ============================================================
# Customer ID: 89-194-0596
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Baby Products                       | Predicted Rating: 4.04
#  2. Hotels                              | Predicted Rating: 4.00
#  3. Beauty & Personal Care              | Predicted Rating: 3.96
#  4. Electronics                         | Predicted Rating: 3.95
#  5. Luxury Goods                        | Predicted Rating: 3.91
#  6. Clothing                            | Predicted Rating: 3.90
#  7. Travel & Leisure (Flights           | Predicted Rating: 3.90
#  8. Toys & Games                        | Predicted Rating: 3.89
#  9. Furniture                           | Predicted Rating: 3.88
# 10. Arts & Crafts                       | Predicted Rating: 3.84
# ============================================================
#
# ============================================================
# Customer ID: 55-163-1389
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.22
#  2. Toys & Games                        | Predicted Rating: 4.05
#  3. Baby Products                       | Predicted Rating: 3.99
#  4. Mobile Accessories                  | Predicted Rating: 3.95
#  5. Software & Apps                     | Predicted Rating: 3.89
#  6. Food & Beverages                    | Predicted Rating: 3.88
#  7. Furniture                           | Predicted Rating: 3.84
#  8. Electronics                         | Predicted Rating: 3.82
#  9. Packages)                           | Predicted Rating: 3.81
# 10. Beauty & Personal Care              | Predicted Rating: 3.80
# ============================================================
#
# ============================================================
# Customer ID: 28-225-4286
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.32
#  2. Furniture                           | Predicted Rating: 4.03
#  3. Hotels                              | Predicted Rating: 3.96
#  4. Clothing                            | Predicted Rating: 3.96
#  5. Books                               | Predicted Rating: 3.86
#  6. Baby Products                       | Predicted Rating: 3.85
#  7. Packages)                           | Predicted Rating: 3.84
#  8. Electronics                         | Predicted Rating: 3.84
#  9. Software & Apps                     | Predicted Rating: 3.83
# 10. Health Care                         | Predicted Rating: 3.76
# ============================================================
#
# ============================================================
# Customer ID: 14-305-8712
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.08
#  2. Hotels                              | Predicted Rating: 4.02
#  3. Travel & Leisure (Flights           | Predicted Rating: 3.98
#  4. Baby Products                       | Predicted Rating: 3.96
#  5. Software & Apps                     | Predicted Rating: 3.88
#  6. Mobile Accessories                  | Predicted Rating: 3.84
#  7. Luxury Goods                        | Predicted Rating: 3.83
#  8. Electronics                         | Predicted Rating: 3.82
#  9. Clothing                            | Predicted Rating: 3.81
# 10. Furniture                           | Predicted Rating: 3.79
# ============================================================
#
# ============================================================
# Customer ID: 85-738-6864
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 4.04
#  2. Toys & Games                        | Predicted Rating: 4.02
#  3. Mobile Accessories                  | Predicted Rating: 3.97
#  4. Travel & Leisure (Flights           | Predicted Rating: 3.95
#  5. Baby Products                       | Predicted Rating: 3.94
#  6. Luxury Goods                        | Predicted Rating: 3.88
#  7. Groceries                           | Predicted Rating: 3.83
#  8. Software & Apps                     | Predicted Rating: 3.83
#  9. Clothing                            | Predicted Rating: 3.76
# 10. Office Supplies                     | Predicted Rating: 3.66
# ============================================================
#
# ============================================================
# Customer ID: 17-198-5155
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Electronics                         | Predicted Rating: 4.29
#  2. Baby Products                       | Predicted Rating: 4.22
#  3. Toys & Games                        | Predicted Rating: 4.19
#  4. Hotels                              | Predicted Rating: 4.17
#  5. Travel & Leisure (Flights           | Predicted Rating: 4.07
#  6. Arts & Crafts                       | Predicted Rating: 3.96
#  7. Packages)                           | Predicted Rating: 3.88
#  8. Clothing                            | Predicted Rating: 3.88
#  9. Mobile Accessories                  | Predicted Rating: 3.81
# 10. Furniture                           | Predicted Rating: 3.81
# ============================================================
#
# ============================================================
# Customer ID: 15-354-9904
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 4.47
#  2. Groceries                           | Predicted Rating: 4.21
#  3. Travel & Leisure (Flights           | Predicted Rating: 4.19
#  4. Luxury Goods                        | Predicted Rating: 4.07
#  5. Toys & Games                        | Predicted Rating: 4.06
#  6. Mobile Accessories                  | Predicted Rating: 4.04
#  7. Furniture                           | Predicted Rating: 4.04
#  8. Electronics                         | Predicted Rating: 3.92
#  9. Baby Products                       | Predicted Rating: 3.92
# 10. Software & Apps                     | Predicted Rating: 3.90
# ============================================================
#
# ============================================================
# Customer ID: 35-198-9248
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.48
#  2. Baby Products                       | Predicted Rating: 4.39
#  3. Mobile Accessories                  | Predicted Rating: 4.04
#  4. Furniture                           | Predicted Rating: 4.02
#  5. Luxury Goods                        | Predicted Rating: 3.95
#  6. Beauty & Personal Care              | Predicted Rating: 3.93
#  7. Office Supplies                     | Predicted Rating: 3.92
#  8. Hotels                              | Predicted Rating: 3.87
#  9. Travel & Leisure (Flights           | Predicted Rating: 3.83
# 10. Packages)                           | Predicted Rating: 3.82
# ============================================================
#
# ============================================================
# Customer ID: 03-950-6074
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.05
#  2. Software & Apps                     | Predicted Rating: 3.94
#  3. Toys & Games                        | Predicted Rating: 3.94
#  4. Beauty & Personal Care              | Predicted Rating: 3.90
#  5. Electronics                         | Predicted Rating: 3.89
#  6. Mobile Accessories                  | Predicted Rating: 3.89
#  7. Baby Products                       | Predicted Rating: 3.88
#  8. Packages)                           | Predicted Rating: 3.87
#  9. Hotels                              | Predicted Rating: 3.87
# 10. Luxury Goods                        | Predicted Rating: 3.85
# ============================================================
#
# ============================================================
# Customer ID: 19-999-0134
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 4.00
#  2. Furniture                           | Predicted Rating: 3.98
#  3. Baby Products                       | Predicted Rating: 3.94
#  4. Luxury Goods                        | Predicted Rating: 3.90
#  5. Toys & Games                        | Predicted Rating: 3.89
#  6. Travel & Leisure (Flights           | Predicted Rating: 3.87
#  7. Software & Apps                     | Predicted Rating: 3.80
#  8. Clothing                            | Predicted Rating: 3.78
#  9. Arts & Crafts                       | Predicted Rating: 3.77
# 10. Mobile Accessories                  | Predicted Rating: 3.74
# ============================================================
#
# ============================================================
# Customer ID: 57-989-1487
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.03
#  2. Hotels                              | Predicted Rating: 4.03
#  3. Electronics                         | Predicted Rating: 3.90
#  4. Baby Products                       | Predicted Rating: 3.87
#  5. Mobile Accessories                  | Predicted Rating: 3.85
#  6. Office Supplies                     | Predicted Rating: 3.83
#  7. Travel & Leisure (Flights           | Predicted Rating: 3.80
#  8. Luxury Goods                        | Predicted Rating: 3.77
#  9. Animal Feed                         | Predicted Rating: 3.77
# 10. Beauty & Personal Care              | Predicted Rating: 3.75
# ============================================================
#
# ============================================================
# Customer ID: 07-816-2673
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 4.21
#  2. Toys & Games                        | Predicted Rating: 3.97
#  3. Baby Products                       | Predicted Rating: 3.88
#  4. Software & Apps                     | Predicted Rating: 3.83
#  5. Travel & Leisure (Flights           | Predicted Rating: 3.82
#  6. Clothing                            | Predicted Rating: 3.79
#  7. Electronics                         | Predicted Rating: 3.77
#  8. Beauty & Personal Care              | Predicted Rating: 3.75
#  9. Packages)                           | Predicted Rating: 3.71
# 10. Luxury Goods                        | Predicted Rating: 3.69
# ============================================================
#
# ============================================================
# Customer ID: 70-761-3550
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 3.92
#  2. Electronics                         | Predicted Rating: 3.76
#  3. Baby Products                       | Predicted Rating: 3.75
#  4. Travel & Leisure (Flights           | Predicted Rating: 3.73
#  5. Packages)                           | Predicted Rating: 3.70
#  6. Health Supplements                  | Predicted Rating: 3.70
#  7. Health Care                         | Predicted Rating: 3.68
#  8. Toys & Games                        | Predicted Rating: 3.67
#  9. Luxury Goods                        | Predicted Rating: 3.66
# 10. Mobile Accessories                  | Predicted Rating: 3.62
# ============================================================
#
# ============================================================
# Customer ID: 38-242-3251
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.03
#  2. Luxury Goods                        | Predicted Rating: 4.00
#  3. Hotels                              | Predicted Rating: 3.98
#  4. Toys & Games                        | Predicted Rating: 3.97
#  5. Baby Products                       | Predicted Rating: 3.92
#  6. Beauty & Personal Care              | Predicted Rating: 3.88
#  7. Home Appliances                     | Predicted Rating: 3.86
#  8. Software & Apps                     | Predicted Rating: 3.85
#  9. Furniture                           | Predicted Rating: 3.84
# 10. Clothing                            | Predicted Rating: 3.82
# ============================================================
#
# ============================================================
# Customer ID: 95-525-0842
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Electronics                         | Predicted Rating: 3.94
#  2. Health Care                         | Predicted Rating: 3.93
#  3. Travel & Leisure (Flights           | Predicted Rating: 3.91
#  4. Software & Apps                     | Predicted Rating: 3.90
#  5. Toys & Games                        | Predicted Rating: 3.88
#  6. Luxury Goods                        | Predicted Rating: 3.82
#  7. Baby Products                       | Predicted Rating: 3.79
#  8. Clothing                            | Predicted Rating: 3.74
#  9. Office Supplies                     | Predicted Rating: 3.74
# 10. Hotels                              | Predicted Rating: 3.72
# ============================================================
#
# ============================================================
# Customer ID: 37-101-4922
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.22
#  2. Software & Apps                     | Predicted Rating: 4.06
#  3. Electronics                         | Predicted Rating: 4.05
#  4. Hotels                              | Predicted Rating: 4.00
#  5. Mobile Accessories                  | Predicted Rating: 3.99
#  6. Beauty & Personal Care              | Predicted Rating: 3.98
#  7. Furniture                           | Predicted Rating: 3.95
#  8. Clothing                            | Predicted Rating: 3.90
#  9. Arts & Crafts                       | Predicted Rating: 3.87
# 10. Health Supplements                  | Predicted Rating: 3.85
# ============================================================
#
# ============================================================
# Customer ID: 37-128-5425
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 4.18
#  2. Toys & Games                        | Predicted Rating: 4.12
#  3. Clothing                            | Predicted Rating: 3.98
#  4. Luxury Goods                        | Predicted Rating: 3.97
#  5. Sports & Outdoors                   | Predicted Rating: 3.95
#  6. Furniture                           | Predicted Rating: 3.91
#  7. Software & Apps                     | Predicted Rating: 3.90
#  8. Baby Products                       | Predicted Rating: 3.89
#  9. Beauty & Personal Care              | Predicted Rating: 3.87
# 10. Travel & Leisure (Flights           | Predicted Rating: 3.82
# ============================================================
#
# ============================================================
# Customer ID: 27-439-9545
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 3.90
#  2. Furniture                           | Predicted Rating: 3.82
#  3. Software & Apps                     | Predicted Rating: 3.80
#  4. Packages)                           | Predicted Rating: 3.79
#  5. Hotels                              | Predicted Rating: 3.76
#  6. Office Supplies                     | Predicted Rating: 3.72
#  7. Baby Products                       | Predicted Rating: 3.71
#  8. Luxury Goods                        | Predicted Rating: 3.70
#  9. Beauty & Personal Care              | Predicted Rating: 3.70
# 10. Toys & Games                        | Predicted Rating: 3.60
# ============================================================
#
# ============================================================
# Customer ID: 37-126-7954
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.21
#  2. Hotels                              | Predicted Rating: 4.10
#  3. Baby Products                       | Predicted Rating: 4.10
#  4. Mobile Accessories                  | Predicted Rating: 4.01
#  5. Electronics                         | Predicted Rating: 3.91
#  6. Travel & Leisure (Flights           | Predicted Rating: 3.82
#  7. Luxury Goods                        | Predicted Rating: 3.80
#  8. Clothing                            | Predicted Rating: 3.75
#  9. Beauty & Personal Care              | Predicted Rating: 3.74
# 10. Groceries                           | Predicted Rating: 3.74
# ============================================================
#
# ============================================================
# Customer ID: 82-990-0504
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Office Supplies                     | Predicted Rating: 3.91
#  2. Baby Products                       | Predicted Rating: 3.91
#  3. Toys & Games                        | Predicted Rating: 3.88
#  4. Electronics                         | Predicted Rating: 3.85
#  5. Beauty & Personal Care              | Predicted Rating: 3.84
#  6. Health Care                         | Predicted Rating: 3.80
#  7. Travel & Leisure (Flights           | Predicted Rating: 3.75
#  8. Packages)                           | Predicted Rating: 3.75
#  9. Furniture                           | Predicted Rating: 3.72
# 10. Home Appliances                     | Predicted Rating: 3.68
# ============================================================
#
# ============================================================
# Customer ID: 21-734-0212
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Home Appliances                     | Predicted Rating: 4.06
#  2. Toys & Games                        | Predicted Rating: 3.98
#  3. Baby Products                       | Predicted Rating: 3.92
#  4. Furniture                           | Predicted Rating: 3.92
#  5. Hotels                              | Predicted Rating: 3.90
#  6. Software & Apps                     | Predicted Rating: 3.90
#  7. Beauty & Personal Care              | Predicted Rating: 3.88
#  8. Clothing                            | Predicted Rating: 3.86
#  9. Health Supplements                  | Predicted Rating: 3.84
# 10. Travel & Leisure (Flights           | Predicted Rating: 3.79
# ============================================================
#
# ============================================================
# Customer ID: 76-148-9413
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Baby Products                       | Predicted Rating: 4.04
#  2. Toys & Games                        | Predicted Rating: 4.02
#  3. Hotels                              | Predicted Rating: 3.99
#  4. Packages)                           | Predicted Rating: 3.88
#  5. Clothing                            | Predicted Rating: 3.87
#  6. Travel & Leisure (Flights           | Predicted Rating: 3.85
#  7. Beauty & Personal Care              | Predicted Rating: 3.82
#  8. Mobile Accessories                  | Predicted Rating: 3.81
#  9. Furniture                           | Predicted Rating: 3.80
# 10. Luxury Goods                        | Predicted Rating: 3.73
# ============================================================
#
# ============================================================
# Customer ID: 53-639-3774
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 3.96
#  2. Baby Products                       | Predicted Rating: 3.85
#  3. Clothing                            | Predicted Rating: 3.83
#  4. Hotels                              | Predicted Rating: 3.82
#  5. Electronics                         | Predicted Rating: 3.81
#  6. Mobile Accessories                  | Predicted Rating: 3.81
#  7. Office Supplies                     | Predicted Rating: 3.80
#  8. Packages)                           | Predicted Rating: 3.79
#  9. Luxury Goods                        | Predicted Rating: 3.79
# 10. Home Appliances                     | Predicted Rating: 3.77
# ============================================================
#
# ============================================================
# Customer ID: 20-817-9584
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.15
#  2. Hotels                              | Predicted Rating: 4.05
#  3. Software & Apps                     | Predicted Rating: 4.03
# ...
#  1. Toys & Games                        | Predicted Rating: 4.10
#  2. Baby Products                       | Predicted Rating: 4.09
#  3. Luxury Goods                        | Predicted Rating: 4.06
#  4. Software & Apps                     | Predicted Rating: 3.97
#  5. Clothing                            | Predicted Rating: 3.94
#  6. Hotels                              | Predicted Rating: 3.92
#  7. Arts & Crafts                       | Predicted Rating: 3.85
#  8. Travel & Leisure (Flights           | Predicted Rating: 3.81
#  9. Health Supplements                  | Predicted Rating: 3.78
# 10. Electronics                         | Predicted Rating: 3.76
# ============================================================
#
# ============================================================
# Customer ID: 06-061-0023
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.08
#  2. Hotels                              | Predicted Rating: 4.02
#  3. Travel & Leisure (Flights           | Predicted Rating: 3.98
#  4. Baby Products                       | Predicted Rating: 3.96
#  5. Software & Apps                     | Predicted Rating: 3.88
#  6. Mobile Accessories                  | Predicted Rating: 3.84
#  7. Luxury Goods                        | Predicted Rating: 3.83
#  8. Electronics                         | Predicted Rating: 3.82
#  9. Clothing                            | Predicted Rating: 3.81
# 10. Furniture                           | Predicted Rating: 3.79
# ============================================================
#
# ============================================================
# Customer ID: 80-487-2550
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.08
#  2. Hotels                              | Predicted Rating: 4.02
#  3. Travel & Leisure (Flights           | Predicted Rating: 3.98
#  4. Baby Products                       | Predicted Rating: 3.96
#  5. Software & Apps                     | Predicted Rating: 3.88
#  6. Mobile Accessories                  | Predicted Rating: 3.84
#  7. Luxury Goods                        | Predicted Rating: 3.83
#  8. Electronics                         | Predicted Rating: 3.82
#  9. Clothing                            | Predicted Rating: 3.81
# 10. Furniture                           | Predicted Rating: 3.79
# ============================================================
#
# ============================================================
# Customer ID: 23-617-2637
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 4.28
#  2. Toys & Games                        | Predicted Rating: 4.27
#  3. Sports & Outdoors                   | Predicted Rating: 4.01
#  4. Clothing                            | Predicted Rating: 3.94
#  5. Baby Products                       | Predicted Rating: 3.91
#  6. Software & Apps                     | Predicted Rating: 3.90
#  7. Luxury Goods                        | Predicted Rating: 3.87
#  8. Home Appliances                     | Predicted Rating: 3.87
#  9. Packages)                           | Predicted Rating: 3.81
# 10. Furniture                           | Predicted Rating: 3.78
# ============================================================
#
# ============================================================
# Customer ID: 60-005-5187
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.21
#  2. Toys & Games                        | Predicted Rating: 4.08
#  3. Beauty & Personal Care              | Predicted Rating: 4.07
#  4. Hotels                              | Predicted Rating: 4.00
#  5. Electronics                         | Predicted Rating: 3.89
#  6. Office Supplies                     | Predicted Rating: 3.87
#  7. Baby Products                       | Predicted Rating: 3.86
#  8. Software & Apps                     | Predicted Rating: 3.85
#  9. Clothing                            | Predicted Rating: 3.78
# 10. Packages)                           | Predicted Rating: 3.77
# ============================================================
#
# ============================================================
# Customer ID: 24-371-5870
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 4.11
#  2. Baby Products                       | Predicted Rating: 4.02
#  3. Travel & Leisure (Flights           | Predicted Rating: 4.00
#  4. Toys & Games                        | Predicted Rating: 3.92
#  5. Clothing                            | Predicted Rating: 3.85
#  6. Mobile Accessories                  | Predicted Rating: 3.81
#  7. Software & Apps                     | Predicted Rating: 3.81
#  8. Furniture                           | Predicted Rating: 3.79
#  9. Office Supplies                     | Predicted Rating: 3.76
# 10. Groceries                           | Predicted Rating: 3.73
# ============================================================
#
# ============================================================
# Customer ID: 02-055-8248
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.08
#  2. Hotels                              | Predicted Rating: 4.02
#  3. Travel & Leisure (Flights           | Predicted Rating: 3.98
#  4. Baby Products                       | Predicted Rating: 3.96
#  5. Software & Apps                     | Predicted Rating: 3.88
#  6. Mobile Accessories                  | Predicted Rating: 3.84
#  7. Luxury Goods                        | Predicted Rating: 3.83
#  8. Electronics                         | Predicted Rating: 3.82
#  9. Clothing                            | Predicted Rating: 3.81
# 10. Furniture                           | Predicted Rating: 3.79
# ============================================================
#
# ============================================================
# Customer ID: 54-238-5459
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Software & Apps                     | Predicted Rating: 4.29
#  2. Travel & Leisure (Flights           | Predicted Rating: 4.26
#  3. Hotels                              | Predicted Rating: 4.21
#  4. Luxury Goods                        | Predicted Rating: 4.08
#  5. Toys & Games                        | Predicted Rating: 4.03
#  6. Mobile Accessories                  | Predicted Rating: 3.89
#  7. Home Appliances                     | Predicted Rating: 3.86
#  8. Arts & Crafts                       | Predicted Rating: 3.83
#  9. Baby Products                       | Predicted Rating: 3.82
# 10. Groceries                           | Predicted Rating: 3.81
# ============================================================
#
# ============================================================
# Customer ID: 85-922-0190
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Software & Apps                     | Predicted Rating: 4.12
#  2. Toys & Games                        | Predicted Rating: 4.07
#  3. Travel & Leisure (Flights           | Predicted Rating: 3.99
#  4. Groceries                           | Predicted Rating: 3.85
#  5. Baby Products                       | Predicted Rating: 3.85
#  6. Luxury Goods                        | Predicted Rating: 3.85
#  7. Mobile Accessories                  | Predicted Rating: 3.79
#  8. Electronics                         | Predicted Rating: 3.78
#  9. Hotels                              | Predicted Rating: 3.78
# 10. Clothing                            | Predicted Rating: 3.74
# ============================================================
#
# ============================================================
# Customer ID: 48-271-1908
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.34
#  2. Baby Products                       | Predicted Rating: 4.25
#  3. Beauty & Personal Care              | Predicted Rating: 4.01
#  4. Mobile Accessories                  | Predicted Rating: 4.00
#  5. Office Supplies                     | Predicted Rating: 3.99
#  6. Luxury Goods                        | Predicted Rating: 3.99
#  7. Health Supplements                  | Predicted Rating: 3.99
#  8. Clothing                            | Predicted Rating: 3.99
#  9. Food & Beverages                    | Predicted Rating: 3.99
# 10. Travel & Leisure (Flights           | Predicted Rating: 3.96
# ============================================================
#
# ============================================================
# Customer ID: 46-978-3874
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.08
#  2. Hotels                              | Predicted Rating: 4.02
#  3. Travel & Leisure (Flights           | Predicted Rating: 3.98
#  4. Baby Products                       | Predicted Rating: 3.96
#  5. Software & Apps                     | Predicted Rating: 3.88
#  6. Mobile Accessories                  | Predicted Rating: 3.84
#  7. Luxury Goods                        | Predicted Rating: 3.83
#  8. Electronics                         | Predicted Rating: 3.82
#  9. Clothing                            | Predicted Rating: 3.81
# 10. Furniture                           | Predicted Rating: 3.79
# ============================================================
#
# ============================================================
# Customer ID: 53-595-7635
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.00
#  2. Hotels                              | Predicted Rating: 3.94
#  3. Software & Apps                     | Predicted Rating: 3.90
#  4. Sports & Outdoors                   | Predicted Rating: 3.88
#  5. Health Supplements                  | Predicted Rating: 3.85
#  6. Baby Products                       | Predicted Rating: 3.83
#  7. Packages)                           | Predicted Rating: 3.77
#  8. Animal Feed                         | Predicted Rating: 3.73
#  9. Beauty & Personal Care              | Predicted Rating: 3.71
# 10. Mobile Accessories                  | Predicted Rating: 3.70
# ============================================================
#
# ============================================================
# Customer ID: 08-185-6608
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.08
#  2. Hotels                              | Predicted Rating: 4.02
#  3. Travel & Leisure (Flights           | Predicted Rating: 3.98
#  4. Baby Products                       | Predicted Rating: 3.96
#  5. Software & Apps                     | Predicted Rating: 3.88
#  6. Mobile Accessories                  | Predicted Rating: 3.84
#  7. Luxury Goods                        | Predicted Rating: 3.83
#  8. Electronics                         | Predicted Rating: 3.82
#  9. Clothing                            | Predicted Rating: 3.81
# 10. Furniture                           | Predicted Rating: 3.79
# ============================================================
#
# ============================================================
# Customer ID: 20-562-2569
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.08
#  2. Hotels                              | Predicted Rating: 4.02
#  3. Travel & Leisure (Flights           | Predicted Rating: 3.98
#  4. Baby Products                       | Predicted Rating: 3.96
#  5. Software & Apps                     | Predicted Rating: 3.88
#  6. Mobile Accessories                  | Predicted Rating: 3.84
#  7. Luxury Goods                        | Predicted Rating: 3.83
#  8. Electronics                         | Predicted Rating: 3.82
#  9. Clothing                            | Predicted Rating: 3.81
# 10. Furniture                           | Predicted Rating: 3.79
# ============================================================
#
# ============================================================
# Customer ID: 41-366-4205
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.26
#  2. Furniture                           | Predicted Rating: 4.11
#  3. Packages)                           | Predicted Rating: 4.09
#  4. Toys & Games                        | Predicted Rating: 4.01
#  5. Mobile Accessories                  | Predicted Rating: 3.95
#  6. Hotels                              | Predicted Rating: 3.91
#  7. Beauty & Personal Care              | Predicted Rating: 3.89
#  8. Software & Apps                     | Predicted Rating: 3.84
#  9. Health Care                         | Predicted Rating: 3.83
# 10. Baby Products                       | Predicted Rating: 3.81
# ============================================================
#
# ============================================================
# Customer ID: 77-241-7621
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 4.24
#  2. Travel & Leisure (Flights           | Predicted Rating: 3.96
#  3. Software & Apps                     | Predicted Rating: 3.95
#  4. Furniture                           | Predicted Rating: 3.89
#  5. Animal Feed                         | Predicted Rating: 3.84
#  6. Toys & Games                        | Predicted Rating: 3.84
#  7. Baby Products                       | Predicted Rating: 3.83
#  8. Mobile Accessories                  | Predicted Rating: 3.81
#  9. Electronics                         | Predicted Rating: 3.80
# 10. Packages)                           | Predicted Rating: 3.76
# ============================================================
#
# ============================================================
# Customer ID: 53-091-2176
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.08
#  2. Hotels                              | Predicted Rating: 4.02
#  3. Travel & Leisure (Flights           | Predicted Rating: 3.98
#  4. Baby Products                       | Predicted Rating: 3.96
#  5. Software & Apps                     | Predicted Rating: 3.88
#  6. Mobile Accessories                  | Predicted Rating: 3.84
#  7. Luxury Goods                        | Predicted Rating: 3.83
#  8. Electronics                         | Predicted Rating: 3.82
#  9. Clothing                            | Predicted Rating: 3.81
# 10. Furniture                           | Predicted Rating: 3.79
# ============================================================
#
# ============================================================
# Customer ID: 48-203-9118
# Top 10 Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.08
#  2. Hotels                              | Predicted Rating: 4.02
#  3. Travel & Leisure (Flights           | Predicted Rating: 3.98
#  4. Baby Products                       | Predicted Rating: 3.96
#  5. Software & Apps                     | Predicted Rating: 3.88
#  6. Mobile Accessories                  | Predicted Rating: 3.84
#  7. Luxury Goods                        | Predicted Rating: 3.83
#  8. Electronics                         | Predicted Rating: 3.82
#  9. Clothing                            | Predicted Rating: 3.81
# 10. Furniture                           | Predicted Rating: 3.79
# ============================================================

# %% [markdown]
# ---
# ---
# Model 2: Item-based KNN (Hybrid model; Collaborative & Content-based)
# ---
#
# A hybrid recommender system is a type of recommendation model that integrates two (or more) different recommendation strategies to leverage their complementary strengths. The goal is to provide more accurate, diverse, and fair recommendations by compensating for the limitations of individual models.
#
# In this implementation, the hybrid model combines:
#
# - Collaborative Filtering, which is based on the idea that users with similar rating behaviors will also like similar items.
# - Content-Based Filtering, which builds a feature vector for each item (customer) and computes feature-based cosine similarity between them.
#
# This enables the model to recommend items (customers) to users (purchase category) based on similar user characteristics, even if rating data is sparse.

# %% [markdown]
# ---
# The objective of this model is to build a recommendation system using an hybrid item-based KNN model that allows for personalize recommendations by considering both behavioral similarity (purchase patterns) and customer profiles (demographics, preferences, etc.). Similarly as with the SVD++ model:
# - Product categories are treated as users
# - Customers are treated as items
# - Ratings are derived from custom scores, and predictions are based on a hybrid of rating similarity and user features
#
# The process of the KNN model is as follows:
# 1. Flipping User-Item Matrix:
#     - Creating a user-item matrix where:
#         - Rows = product categories (Purchase_Category)
#         - Columns = customers (Customer_ID)
#         - Values = custom ratings (combination of product rating, satisfaction, loyalty)
#         - Missing values filled with 0 for matrix computation.
#
# 2. Train-Test Split (Row-Wise)
#     - For each product category (row), split its available ratings into: 80% training and 20% testing
#     - This ensures fair category-level evaluation.
#
# 3. Customer Feature Engineering
#     - Extracting customer-level features including demographics, behavioral traits, engagement, satisfaction, etc.
#     - Applying one-hot encoding to categorical features.
#     - Preparing these for use in feature-based similarity calculations.
#
# 4. Hybrid Similarity Matrix
#     - Computing two types of cosine similarity between customers:
#         - Rating-based: From customer rating patterns in the training matrix.
#         - Feature-based: From encoded customer features.
#     - Combining these into a hybrid similarity matrix:
#         - Hybrid Similarity = 𝛼 ⋅ Rating Similarity + (1 − 𝛼) ⋅ Feature Similarity, where 𝛼 = 0.5 (equal weights).
#
# 5. Prediction Function
#     - Defining predict_rating_hybrid():
#         - For a given (product category, customer) pair,
#         - Find the k-most similar customers,
#         - Use their ratings (if available) to compute a weighted average prediction.
#
# 6. Model Evaluation
#     - Evaluating the model using Root Mean Squared Error (RMSE) and Mean Absolute Error (MAE)
#
# 7. Recommendation Generation
#     - Generating two top-N recommendation lists:
#         - Top 10 customers per product category (which customers to target)
#         - Top 10 product categories per customer (what customers might like most)

# %% [markdown]
# ---
# Creating the User-Item Matrix for recommendations, where the rating is the custom rating. This matrix becomes the base for train-test splitting and similarity calculations:

# %%
# Create the user-item matrix
# Rows: Purchase categories (as users), Columns: Customers (as items)
user_item_matrix = e_commerce.pivot_table(index='Purchase_Category', columns='Customer_ID', values='custom_rating')
user_item_matrix = user_item_matrix.fillna(0)

user_item_matrix.head()
# Out:
# Customer_ID             00-107-4749  00-149-4481  00-264-3797  00-265-0556  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             00-275-9990  00-285-9607  00-335-5034  00-477-9449  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             00-496-3067  00-520-4376  00-733-8770  01-023-2094  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          2.4          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          6.5          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             01-089-2223  01-404-3425  01-484-8220  01-799-2615  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             01-925-4021  02-004-0620  02-055-8248  02-100-4320  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          4.6
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             02-653-5884  02-676-9312  02-677-6735  02-711-1034  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   4.6          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          2.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             02-725-7664  02-911-0447  03-023-9932  03-102-0288  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             03-180-9200  03-422-8710  03-623-6767  03-669-7519  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             03-827-4021  03-874-9055  03-950-6074  03-977-8103  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          3.9
#
# Customer_ID             03-991-2098  03-992-3728  04-052-5592  04-213-4617  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             04-349-6759  04-352-1558  04-465-1819  04-468-5487  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             04-545-9162  04-563-9091  04-609-7885  04-660-2742  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          5.1
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             04-809-8989  04-829-7037  04-832-3559  05-067-9686  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          5.4          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          3.2          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             05-167-0833  05-465-8765  05-506-7216  05-546-5128  \
# Purchase_Category
# Animal Feed                     0.0          0.0          1.7          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             05-710-6109  05-857-1572  05-975-6985  06-008-2805  \
# Purchase_Category
# Animal Feed                     0.0          3.4          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             06-061-0023  06-160-8063  06-237-7338  06-357-6548  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             06-594-3417  06-638-0433  06-647-3248  06-764-5496  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             06-767-5206  07-024-4995  07-211-9364  07-314-2945  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             07-323-0255  07-395-5818  07-402-7433  07-479-3919  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             07-560-6637  07-751-9620  07-816-2673  07-834-3350  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             07-958-2231  07-966-8728  08-117-9893  08-185-6608  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   5.2          0.0          3.0          4.6
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             08-297-3351  08-584-8296  08-614-6177  08-652-2085  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          4.9
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             08-733-0300  08-755-1170  08-806-0588  08-977-4418  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           3.3          0.0          0.0          0.0
#
# Customer_ID             09-216-1957  09-258-0424  09-332-0236  09-346-4992  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          4.9          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             09-369-0588  09-443-7536  09-513-4923  09-737-8354  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          2.4
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             09-775-4058  09-783-7921  09-948-3150  10-079-8237  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             10-232-0685  10-247-0192  10-300-8072  10-328-5732  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             91-724-4633  91-761-9492  91-789-3191  91-810-3612  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             91-857-0797  92-142-4328  92-142-9480  92-908-5062  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   2.7          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             92-946-7398  93-093-0556  93-356-8589  93-413-4758  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          4.3          0.0
# Baby Products                   5.5          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             93-455-0576  93-473-7248  93-649-9356  93-675-1619  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          3.7
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          4.6          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             93-810-4051  93-867-8303  93-957-6269  93-989-8649  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          2.5          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             94-120-9525  94-212-7169  94-288-4423  94-408-2581  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          4.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             94-495-3402  94-682-4886  94-692-4313  94-746-2001  \
# Purchase_Category
# Animal Feed                     0.0          0.0          4.3          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          3.9          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             94-969-6819  94-985-5336  95-112-6724  95-148-1769  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             95-478-2650  95-525-0842  95-528-2313  95-675-7816  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          2.4          0.0          0.0
#
# Customer_ID             95-876-9757  95-999-0984  96-079-9597  96-121-0629  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             96-140-1936  96-229-1698  96-484-1000  96-496-9833  \
# Purchase_Category
# Animal Feed                     0.0          3.3          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             96-764-3843  96-772-7220  96-915-4091  97-237-3483  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             97-463-0048  97-505-8416  97-715-3606  97-738-8095  \
# Purchase_Category
# Animal Feed                     0.0          0.0          5.4          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             98-130-8811  98-238-6733  98-376-8787  98-535-8497  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             98-559-6096  98-585-4742  98-817-6731  99-080-9462  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          5.7
#
# Customer_ID             99-089-1930  99-316-9993  99-477-8256  99-509-4653  \
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0
#
# Customer_ID             99-581-5577  99-643-9845  99-771-9310  99-945-7193
# Purchase_Category
# Animal Feed                     0.0          0.0          0.0          0.0
# Arts & Crafts                   0.0          0.0          0.0          0.0
# Baby Products                   0.0          0.0          0.0          0.0
# Beauty & Personal Care          0.0          0.0          0.0          0.0
# Books                           0.0          0.0          0.0          0.0

# %% [markdown]
# Performing train-test split by splitting ratings within each category (row) into 80% train and 20% test. This split ensures all categories get evaluated and not just globally split:

# %%
# Split the user-item matrix into train and test matrices row-wise (80/20)
train_matrix = user_item_matrix.copy() * np.nan
test_matrix = user_item_matrix.copy() * np.nan
results = []

for category in user_item_matrix.index:
    ratings = user_item_matrix.loc[category]
    non_zero_ratings = ratings[ratings > 0]
    shuffled_ratings = non_zero_ratings.sample(frac=1, random_state=42)
    cutoff = int(0.8 * len(shuffled_ratings))
    
    train_matrix.loc[category, shuffled_ratings.index[:cutoff]] = shuffled_ratings.values[:cutoff]
    test_matrix.loc[category, shuffled_ratings.index[cutoff:]] = shuffled_ratings.values[cutoff:]
    
    results.append({
        'userID': category,
        'Total_Ratings': len(non_zero_ratings),
        'Train_Ratings': cutoff,
        'Test_Ratings': len(non_zero_ratings) - cutoff,
        'Train_%': (cutoff / len(non_zero_ratings)) * 100,
        'Test_%': ((len(non_zero_ratings) - cutoff) / len(non_zero_ratings)) * 100
    })

train_test_results_df = pd.DataFrame(results)
display(train_test_results_df)
# Out:
#                        userID  Total_Ratings  Train_Ratings  Test_Ratings  \
# 0                 Animal Feed             44             35             9
# 1               Arts & Crafts             34             27             7
# 2               Baby Products             41             32             9
# 3      Beauty & Personal Care             34             27             7
# 4                       Books             37             29             8
# 5                    Clothing             30             24             6
# 6                 Electronics             54             43            11
# 7            Food & Beverages             44             35             9
# 8                   Furniture             41             32             9
# 9        Gardening & Outdoors             44             35             9
# 10                  Groceries             41             32             9
# 11                Health Care             41             32             9
# 12         Health Supplements             41             32             9
# 13            Home Appliances             50             40            10
# 14                     Hotels             36             28             8
# 15      Jewelry & Accessories             50             40            10
# 16               Luxury Goods             37             29             8
# 17         Mobile Accessories             41             32             9
# 18            Office Supplies             38             30             8
# 19                  Packages)             43             34             9
# 20            Software & Apps             43             34             9
# 21          Sports & Outdoors             51             40            11
# 22               Toys & Games             47             37            10
# 23  Travel & Leisure (Flights             38             30             8
#
#       Train_%     Test_%
# 0   79.545455  20.454545
# 1   79.411765  20.588235
# 2   78.048780  21.951220
# 3   79.411765  20.588235
# 4   78.378378  21.621622
# 5   80.000000  20.000000
# 6   79.629630  20.370370
# 7   79.545455  20.454545
# 8   78.048780  21.951220
# 9   79.545455  20.454545
# 10  78.048780  21.951220
# 11  78.048780  21.951220
# 12  78.048780  21.951220
# 13  80.000000  20.000000
# 14  77.777778  22.222222
# 15  80.000000  20.000000
# 16  78.378378  21.621622
# 17  78.048780  21.951220
# 18  78.947368  21.052632
# 19  79.069767  20.930233
# 20  79.069767  20.930233
# 21  78.431373  21.568627
# 22  78.723404  21.276596
# 23  78.947368  21.052632

# %% [markdown]
# Preparing customer feature vectors:

# %%
# Code Block 3: Prepare customer feature DataFrame for similarity computation

# Define the list of features to be used
features = [
    'Customer_ID', 'Age', 'Gender', 'Income_Level', 'Marital_Status', 'Education_Level',
    'Occupation', 'Purchase_Amount', 'Frequency_of_Purchase', 'Purchase_Channel',
    'Brand_Loyalty', 'Product_Rating', 'Time_Spent_on_Product_Research(hours)',
    'Social_Media_Influence', 'Discount_Sensitivity', 'Customer_Satisfaction',
    'Engagement_with_Ads', 'Device_Used_for_Shopping', 'Payment_Method',
    'Time_to_Decision', 'Customer_Loyalty_Program_Member', 'Purchase_Intent',
    'Shipping_Preference'
]

# Filter and copy the relevant columns
customer_features_df = e_commerce[features].copy()

# Convert boolean-like column to integer
customer_features_df['Customer_Loyalty_Program_Member'] = customer_features_df['Customer_Loyalty_Program_Member'].astype(int)

# One-hot encode categorical variables to prepare them for cosine similarity computation
categorical_cols = [
    'Gender', 'Income_Level', 'Marital_Status', 'Education_Level',
    'Occupation', 'Purchase_Channel', 'Social_Media_Influence',
    'Discount_Sensitivity', 'Engagement_with_Ads', 'Device_Used_for_Shopping',
    'Payment_Method', 'Purchase_Intent', 'Shipping_Preference'
]
customer_features_encoded = pd.get_dummies(customer_features_df, columns=categorical_cols, drop_first=True)

# Define numeric columns (left unnormalized for cosine similarity)
numeric_cols = [
    'Age', 'Purchase_Amount', 'Frequency_of_Purchase', 'Brand_Loyalty',
    'Product_Rating', 'Time_Spent_on_Product_Research(hours)', 'Customer_Satisfaction',
    'Time_to_Decision'
]

# %% [markdown]
# The code above prepares customer-level features and applies one-hot encoding to categorical columns. These features will be used for feature-based similarity:

# %%
from sklearn.metrics.pairwise import cosine_similarity

"""
Code Block 5: Compute the hybrid customer similarity matrix.

This block computes two types of cosine similarities between customers:

1. **Rating-based similarity**: 
   - Based on customers’ rating behavior in the training matrix.
   - Cosine similarity is computed between customer rating vectors (columns of train_matrix).

2. **Feature-based similarity**:
   - Based on encoded customer demographic and behavioral features.
   - Cosine similarity is computed from one-hot encoded and numerical features.

These two similarity matrices are then combined into a **hybrid similarity matrix**
using a weighted average controlled by the parameter `alpha` (here set to 0.5, 
implying equal contribution from both rating and feature-based similarities).
"""

# Step 1: Rating-based similarity
train_matrix_filled = train_matrix.fillna(0)
rating_similarity_df = pd.DataFrame(
    cosine_similarity(train_matrix_filled.T),
    index=train_matrix.columns,
    columns=train_matrix.columns
)

# Step 2: Feature-based similarity
if 'Customer_ID' in customer_features_encoded.columns:
    customer_features_encoded = customer_features_encoded.set_index('Customer_ID')

feature_similarity_df = pd.DataFrame(
    cosine_similarity(customer_features_encoded),
    index=customer_features_encoded.index,
    columns=customer_features_encoded.index
)

# Step 3: Combine the similarities
alpha = 0.5
hybrid_similarity_df = alpha * rating_similarity_df + (1 - alpha) * feature_similarity_df

# Inspect the resulting matrix
print(hybrid_similarity_df)
# Out:
# Customer_ID  00-107-4749  00-149-4481  00-264-3797  00-265-0556  00-275-9990  \
# Customer_ID
# 00-107-4749     1.000000     0.493622     0.499035     0.493852     0.495479
# 00-149-4481     0.493622     1.000000     0.493561     0.479111     0.499497
# 00-264-3797     0.499035     0.493561     1.000000     0.492313     0.494966
# 00-265-0556     0.493852     0.479111     0.492313     1.000000     0.483872
# 00-275-9990     0.495479     0.499497     0.494966     0.483872     1.000000
# ...                  ...          ...          ...          ...          ...
# 99-509-4653     0.497991     0.498549     0.497689     0.487817     0.499330
# 99-581-5577     0.493168     0.499885     0.492900     0.478838     0.499519
# 99-643-9845     0.498853     0.994324     0.499021     0.493230     0.496012
# 99-771-9310     0.496109     0.499531     0.496040     0.484152     0.499778
# 99-945-7193     0.496304     0.499263     0.495791     0.485518     0.499822
#
# Customer_ID  00-285-9607  00-335-5034  00-477-9449  00-496-3067  00-520-4376  \
# Customer_ID
# 00-107-4749     0.495601     0.495997     0.494993     0.497888     0.479814
# 00-149-4481     0.499668     0.499662     0.499790     0.498478     0.455749
# 00-264-3797     0.495126     0.995550     0.494771     0.497843     0.478559
# 00-265-0556     0.483037     0.483025     0.482199     0.488282     0.485978
# 00-275-9990     0.499778     0.499717     0.499833     0.499276     0.460034
# ...                  ...          ...          ...          ...          ...
# 99-509-4653     0.499267     0.499476     0.499160     0.499818     0.467717
# 99-581-5577     0.499476     0.499481     0.499670     0.498183     0.453522
# 99-643-9845     0.496234     0.496207     0.495832     0.498480     0.479324
# 99-771-9310     0.499822     0.499801     0.499839     0.499579     0.461736
# 99-945-7193     0.499715     0.499667     0.499676     0.499546     0.463372
#
# Customer_ID  00-733-8770  01-023-2094  01-089-2223  01-404-3425  01-484-8220  \
# Customer_ID
# 00-107-4749     0.456716     0.493929     0.499553     0.497072     0.497563
# 00-149-4481     0.421803     0.499856     0.495558     0.499165     0.499013
# 00-264-3797     0.457148     0.493945     0.499253     0.996626     0.497193
# 00-265-0556     0.476793     0.479702     0.492854     0.486300     0.486075
# 00-275-9990     0.429470     0.499533     0.997138     0.499746     0.499400
# ...                  ...          ...          ...          ...          ...
# 99-509-4653     0
# ...                  ...          ...          ...          ...          ...
# 99-509-4653     0.499769     0.499671     0.481526     0.499674     0.499261
# 99-581-5577     0.497340     0.497965     0.469959     0.499256     0.499429
# 99-643-9845     0.498774     0.498351     0.488877     0.496889     0.496098
# 99-771-9310     0.499120     0.499249     0.476408     0.499942     0.499574
# 99-945-7193     0.498946     0.499497     0.478116     0.499602     0.499838
#
# Customer_ID  98-238-6733  98-376-8787  98-535-8497  98-559-6096  98-585-4742  \
# Customer_ID
# 00-107-4749     0.496114     0.488630     0.493886     0.496097     0.494520
# 00-149-4481     0.499572     0.468331     0.480291     0.499299     0.479863
# 00-264-3797     0.495931     0.488649     0.493794     0.495265     0.494502
# 00-265-0556     0.483688     0.494022     0.496865     0.484910     0.497407
# 00-275-9990     0.499688     0.473023     0.484077     0.499835     0.483552
# ...                  ...          ...          ...          ...          ...
# 99-509-4653     0.499492     0.479294     0.488163     0.499465     0.488162
# 99-581-5577     0.499284     0.466861     0.479195     0.499376     0.478819
# 99-643-9845     0.496831     0.488685     0.495177     0.496087     0.495034
# 99-771-9310     0.499841     0.474511     0.485216     0.499643     0.484923
# 99-945-7193     0.499673     0.475186     0.485775     0.499828     0.485300
#
# Customer_ID  98-817-6731  99-080-9462  99-089-1930  99-316-9993  99-477-8256  \
# Customer_ID
# 00-107-4749     0.978288     0.493996     0.499223     0.498416     0.495238
# 00-149-4481     0.450290     0.499837     0.497001     0.994989     0.499755
# 00-264-3797     0.476503     0.493495     0.498863     0.498306     0.494727
# 00-265-0556     0.489833     0.479817     0.490203     0.493281     0.482463
# 00-275-9990     0.456383     0.499624     0.498056     0.496731     0.499823
# ...                  ...          ...          ...          ...          ...
# 99-509-4653     0.464635     0.498738     0.499542     0.498134     0.499260
# 99-581-5577     0.448903     0.499889     0.496555     0.494498     0.499765
# 99-643-9845     0.476027     0.494180     0.498904     0.999508     0.495449
# 99-771-9310     0.457843     0.499447     0.498594     0.497180     0.499716
# 99-945-7193     0.459363     0.499337     0.498478     0.497537     0.499736
#
# Customer_ID  99-509-4653  99-581-5577  99-643-9845  99-771-9310  99-945-7193
# Customer_ID
# 00-107-4749     0.497991     0.493168     0.498853     0.496109     0.496304
# 00-149-4481     0.498549     0.499885     0.994324     0.499531     0.499263
# 00-264-3797     0.497689     0.492900     0.499021     0.496040     0.495791
# 00-265-0556     0.487817     0.478838     0.493230     0.484152     0.485518
# 00-275-9990     0.499330     0.499519     0.496012     0.499778     0.499822
# ...                  ...          ...          ...          ...          ...
# 99-509-4653     1.000000     0.498370     0.497938     0.499551     0.499526
# 99-581-5577     0.498370     0.500000     0.493612     0.499381     0.499192
# 99-643-9845     0.497938     0.493612     1.000000     0.496668     0.496804
# 99-771-9310     0.499551     0.499381     0.496668     0.500000     0.499677
# 99-945-7193     0.499526     0.499192     0.496804     0.499677     1.000000
#
# [1000 rows x 1000 columns]

# %% [markdown]
# Hybrid KNN prediction function:

# %%
def predict_rating_hybrid(user_id, item_id, k=5):
    """
    Predicts a rating for a given (category, customer) pair using KNN
    with a hybrid similarity of rating and feature vectors.
    """
    similar_items = hybrid_similarity_df[item_id].sort_values(ascending=False).iloc[1:k+1]
    category_ratings = train_matrix.loc[user_id, similar_items.index].dropna()
    
    if category_ratings.empty:
        return np.nan
    
    weighted_sum = (similar_items.loc[category_ratings.index] * category_ratings).sum()
    total_weight = similar_items.loc[category_ratings.index].sum()
    
    return weighted_sum / total_weight if total_weight else np.nan

# %% [markdown]
# Evaluating the KNN model performance:

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

test_data = test_matrix.stack().reset_index(name='true_rating')
test_data.columns = ['user_id', 'item_id', 'true_rating']

predictions, actuals = [], []
for row in test_data.itertuples(index=False):
    pred = predict_rating_hybrid(row.user_id, row.item_id, k=5)
    if not np.isnan(pred):
        predictions.append(pred)
        actuals.append(row.true_rating)

if predictions:
    rmse = np.sqrt(mean_squared_error(actuals, predictions))
    mae = mean_absolute_error(actuals, predictions)
    print(f"RMSE: {rmse:.4f}")
    print(f"MAE: {mae:.4f}")
# Out:
# RMSE: 0.9094
# MAE: 0.7163

# %% [markdown]
# For each product category, predicting ratings for all customers and keeping the top 10 customers with the highest predicted scores:

# %%
top_10_customers_per_category = defaultdict(list)

for category in categories:
    for customer in customers:
        pred = predict_rating_hybrid(user_id=category, item_id=customer)
        if not np.isnan(pred):
            top_10_customers_per_category[category].append((customer, pred))

for category in top_10_customers_per_category:
    top_10_customers_per_category[category] = sorted(
        top_10_customers_per_category[category], key=lambda x: x[1], reverse=True
    )[:10]


# Display the recommendations for each purchase category
for category, top_customers in top_10_customers_per_category.items():
    print(f"\nTop 10 customers recommended for product category: {category}")
    for idx, (cust, pred_rating) in enumerate(top_customers, 1):
        print(f"{idx}. Customer ID: {cust} — Predicted Rating: {pred_rating:.2f}")
# Out:
# Top 10 customers recommended for product category: Gardening & Outdoors
# 1. Customer ID: 83-714-9649 — Predicted Rating: 6.30
# 2. Customer ID: 37-611-6911 — Predicted Rating: 5.20
# 3. Customer ID: 84-459-7736 — Predicted Rating: 5.20
# 4. Customer ID: 60-470-3563 — Predicted Rating: 5.20
# 5. Customer ID: 52-726-9328 — Predicted Rating: 5.00
# 6. Customer ID: 29-374-1297 — Predicted Rating: 5.00
# 7. Customer ID: 67-697-2331 — Predicted Rating: 5.00
# 8. Customer ID: 27-017-7173 — Predicted Rating: 3.90
# 9. Customer ID: 86-257-9581 — Predicted Rating: 3.86
# 10. Customer ID: 30-528-9105 — Predicted Rating: 3.78
#
# Top 10 customers recommended for product category: Food & Beverages
# 1. Customer ID: 27-347-7437 — Predicted Rating: 5.40
# 2. Customer ID: 84-894-9222 — Predicted Rating: 5.20
# 3. Customer ID: 71-876-9118 — Predicted Rating: 5.20
# 4. Customer ID: 35-850-8676 — Predicted Rating: 5.20
# 5. Customer ID: 61-926-1691 — Predicted Rating: 4.80
# 6. Customer ID: 22-352-0576 — Predicted Rating: 4.60
# 7. Customer ID: 35-880-9374 — Predicted Rating: 4.60
# 8. Customer ID: 37-611-6911 — Predicted Rating: 4.30
# 9. Customer ID: 70-108-1493 — Predicted Rating: 4.30
# 10. Customer ID: 60-470-3563 — Predicted Rating: 4.30
#
# Top 10 customers recommended for product category: Office Supplies
# 1. Customer ID: 37-611-6911 — Predicted Rating: 5.60
            knn_top_recommendations_per_customer[customer].append((category, pred))

for customer in knn_top_recommendations_per_customer:
    knn_top_recommendations_per_customer[customer] = sorted(
        knn_top_recommendations_per_customer[customer], key=lambda x: x[1], reverse=True
    )[:10]

# Collect and print the recommendations in a clean format
knn_top_categories_data = []

for customer, top_categories in knn_top_recommendations_per_customer.items():
    print("=" * 60)
    print(f"Customer ID: {customer}")
    print("Top Recommended Product Categories:")
    print("-" * 60)
    
    for idx, (category, pred_rating) in enumerate(top_categories, 1):
        knn_top_categories_data.append({
            "Customer ID": customer,
            "Rank": idx,
            "Product Category": category,
            "Predicted Rating": round(pred_rating, 2)
        })
        print(f"{idx:>2}. {category:<35} | Predicted Rating: {pred_rating:.2f}")
    
    print("=" * 60 + "\n")
# Out:
# ============================================================
# Customer ID: 37-611-6911
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Office Supplies                     | Predicted Rating: 5.60
#  2. Gardening & Outdoors                | Predicted Rating: 5.20
#  3. Software & Apps                     | Predicted Rating: 4.70
#  4. Baby Products                       | Predicted Rating: 4.60
#  5. Food & Beverages                    | Predicted Rating: 4.30
# ============================================================
#
# ============================================================
# Customer ID: 29-392-9296
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Food & Beverages                    | Predicted Rating: 3.00
# ============================================================
#
# ============================================================
# Customer ID: 84-649-5117
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Office Supplies                     | Predicted Rating: 3.44
# ============================================================
#
# ============================================================
# Customer ID: 48-980-6078
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Home Appliances                     | Predicted Rating: 3.30
# ============================================================
#
# ============================================================
# Customer ID: 91-170-9072
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Furniture                           | Predicted Rating: 3.76
# ============================================================
#
# ============================================================
# Customer ID: 82-561-4233
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Office Supplies                     | Predicted Rating: 3.24
# ============================================================
#
# ============================================================
# Customer ID: 90-144-9193
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Software & Apps                     | Predicted Rating: 4.80
#  2. Mobile Accessories                  | Predicted Rating: 3.95
# ============================================================
#
# ============================================================
# Customer ID: 88-661-4689
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Books                               | Predicted Rating: 3.08
# ============================================================
#
# ============================================================
# Customer ID: 37-065-3182
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Office Supplies                     | Predicted Rating: 3.40
# ============================================================
#
# ============================================================
# Customer ID: 84-894-9222
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Food & Beverages                    | Predicted Rating: 5.20
#  2. Baby Products                       | Predicted Rating: 4.80
#  3. Office Supplies                     | Predicted Rating: 3.80
#  4. Electronics                         | Predicted Rating: 3.60
# ============================================================
#
# ============================================================
# Customer ID: 44-674-4037
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Mobile Accessories                  | Predicted Rating: 4.82
# ============================================================
#
# ============================================================
# Customer ID: 78-116-8349
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Electronics                         | Predicted Rating: 5.70
#  2. Furniture                           | Predicted Rating: 5.60
#  3. Food & Beverages                    | Predicted Rating: 4.00
#  4. Sports & Outdoors                   | Predicted Rating: 2.70
# ============================================================
#
# ============================================================
# Customer ID: 19-933-8095
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Luxury Goods                        | Predicted Rating: 3.66
# ============================================================
#
# ============================================================
# Customer ID: 80-684-5072
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Animal Feed                         | Predicted Rating: 3.66
# ============================================================
#
# ============================================================
# Customer ID: 23-302-7502
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Care                         | Predicted Rating: 3.88
# ============================================================
#
# ============================================================
# Customer ID: 90-069-8934
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 3.70
# ============================================================
#
# ============================================================
# Customer ID: 45-073-7243
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Furniture                           | Predicted Rating: 4.40
# ============================================================
#
# ============================================================
# Customer ID: 89-883-2101
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Mobile Accessories                  | Predicted Rating: 3.50
# ============================================================
#
# ============================================================
# Customer ID: 00-477-9449
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Packages)                           | Predicted Rating: 3.02
# ============================================================
#
# ============================================================
# Customer ID: 67-159-7366
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Electronics                         | Predicted Rating: 4.04
# ============================================================
#
# ============================================================
# Customer ID: 85-691-4293
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Home Appliances                     | Predicted Rating: 3.30
#  2. Software & Apps                     | Predicted Rating: 2.90
#  3. Toys & Games                        | Predicted Rating: 2.50
#  4. Hotels                              | Predicted Rating: 2.00
#  5. Books                               | Predicted Rating: 1.60
# ============================================================
#
# ============================================================
# Customer ID: 56-085-0464
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Baby Products                       | Predicted Rating: 3.94
# ============================================================
#
# ============================================================
# Customer ID: 33-264-2822
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 5.22
# ============================================================
#
# ============================================================
# Customer ID: 95-478-2650
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Software & Apps                     | Predicted Rating: 4.40
# ============================================================
#
# ============================================================
# Customer ID: 04-349-6759
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Food & Beverages                    | Predicted Rating: 4.00
# ============================================================
#
# ============================================================
# Customer ID: 21-755-8745
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Packages)                           | Predicted Rating: 3.28
# ============================================================
#
# ============================================================
# Customer ID: 29-625-7057
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Luxury Goods                        | Predicted Rating: 3.70
#  2. Travel & Leisure (Flights           | Predicted Rating: 2.40
#  3. Arts & Crafts                       | Predicted Rating: 1.80
# ============================================================
#
# ============================================================
# Customer ID: 58-623-8404
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Electronics                         | Predicted Rating: 2.86
# ============================================================
#
# ============================================================
# Customer ID: 56-506-4709
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Arts & Crafts                       | Predicted Rating: 3.64
# ============================================================
#
# ============================================================
# Customer ID: 25-839-8670
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Supplements                  | Predicted Rating: 2.68
# ============================================================
#
# ============================================================
# Customer ID: 89-194-0596
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Gardening & Outdoors                | Predicted Rating: 2.86
# ============================================================
#
# ============================================================
# Customer ID: 55-163-1389
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Mobile Accessories                  | Predicted Rating: 3.36
# ============================================================
#
# ============================================================
# Customer ID: 28-225-4286
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Mobile Accessories                  | Predicted Rating: 3.90
# ============================================================
#
# ============================================================
# Customer ID: 14-305-8712
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Mobile Accessories                  | Predicted Rating: 4.40
# ============================================================
#
# ============================================================
# Customer ID: 85-738-6864
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Electronics                         | Predicted Rating: 4.90
#  2. Software & Apps                     | Predicted Rating: 4.40
#  3. Mobile Accessories                  | Predicted Rating: 3.80
#  4. Luxury Goods                        | Predicted Rating: 3.30
# ============================================================
#
# ============================================================
# Customer ID: 17-198-5155
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Books                               | Predicted Rating: 3.06
# ============================================================
#
# ============================================================
# Customer ID: 15-354-9904
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Furniture                           | Predicted Rating: 5.60
#  2. Mobile Accessories                  | Predicted Rating: 5.60
#  3. Health Care                         | Predicted Rating: 5.40
#  4. Toys & Games                        | Predicted Rating: 5.30
# ============================================================
#
# ============================================================
# Customer ID: 35-198-9248
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.98
# ============================================================
#
# ============================================================
# Customer ID: 03-950-6074
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Software & Apps                     | Predicted Rating: 4.30
# ============================================================
#
# ============================================================
# Customer ID: 19-999-0134
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Care                         | Predicted Rating: 3.04
# ============================================================
#
# ============================================================
# Customer ID: 57-989-1487
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Software & Apps                     | Predicted Rating: 3.98
# ============================================================
#
# ============================================================
# Customer ID: 07-816-2673
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Food & Beverages                    | Predicted Rating: 3.76
# ============================================================
#
# ============================================================
# Customer ID: 70-761-3550
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Books                               | Predicted Rating: 4.50
# ============================================================
#
# ============================================================
# Customer ID: 38-242-3251
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Arts & Crafts                       | Predicted Rating: 4.80
# ============================================================
#
# ============================================================
# Customer ID: 95-525-0842
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Books                               | Predicted Rating: 3.04
# ============================================================
#
# ============================================================
# Customer ID: 37-101-4922
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Mobile Accessories                  | Predicted Rating: 4.50
# ============================================================
#
# ============================================================
# Customer ID: 37-128-5425
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 6.10
#  2. Mobile Accessories                  | Predicted Rating: 5.60
#  3. Luxury Goods                        | Predicted Rating: 5.10
#  4. Sports & Outdoors                   | Predicted Rating: 4.80
#  5. Home Appliances                     | Predicted Rating: 4.10
# ============================================================
#
# ============================================================
# Customer ID: 27-439-9545
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Care                         | Predicted Rating: 5.70
#  2. Clothing                            | Predicted Rating: 4.60
#  3. Health Supplements                  | Predicted Rating: 3.80
# ============================================================
#
# ============================================================
# Customer ID: 37-126-7954
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Packages)                           | Predicted Rating: 4.40
#  2. Jewelry & Accessories               | Predicted Rating: 4.00
#  3. Software & Apps                     | Predicted Rating: 3.80
# ============================================================
#
# ============================================================
# Customer ID: 82-990-0504
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Groceries                           | Predicted Rating: 3.44
# ============================================================
#
# ============================================================
# Customer ID: 21-734-0212
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 4.20
#  2. Mobile Accessories                  | Predicted Rating: 4.00
#  3. Packages)                           | Predicted Rating: 3.80
#  4. Food & Beverages                    | Predicted Rating: 2.50
# ============================================================
#
# ============================================================
# Customer ID: 76-148-9413
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Arts & Crafts                       | Predicted Rating: 3.32
# ============================================================
#
# ============================================================
# Customer ID: 53-639-3774
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Supplements                  | Predicted Rating: 3.90
#  2. Electronics                         | Predicted Rating: 3.20
#  3. Food & Beverages                    | Predicted Rating: 3.00
#  4. Toys & Games                        | Predicted Rating: 2.80
#  5. Groceries                           | Predicted Rating: 1.80
# ============================================================
#
# ============================================================
# Customer ID: 20-817-9584
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Animal Feed                         | Predicted Rating: 3.70
# ============================================================
#
# ============================================================
# Customer ID: 18-655-3670
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Office Supplies                     | Predicted Rating: 3.40
# ============================================================
#
# ============================================================
# Customer ID: 72-431-5021
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Gardening & Outdoors                | Predicted Rating: 2.90
# ============================================================
#
# ============================================================
# Customer ID: 07-479-3919
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Sports & Outdoors                   | Predicted Rating: 3.50
# ============================================================
#
# ============================================================
# Customer ID: 17-032-6274
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Books                               | Predicted Rating: 4.10
# ============================================================
#
# ============================================================
# Customer ID: 64-166-9097
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Furniture                           | Predicted Rating: 4.06
# ============================================================
#
# ============================================================
# Customer ID: 39-499-3854
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 4.86
# ============================================================
#
# ============================================================
# Customer ID: 39-636-5871
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Baby Products                       | Predicted Rating: 4.50
# ============================================================
#
# ============================================================
# Customer ID: 71-667-2334
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.12
# ============================================================
#
# ============================================================
# Customer ID: 35-192-9050
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Electronics                         | Predicted Rating: 4.80
#  2. Furniture                           | Predicted Rating: 4.50
#  3. Mobile Accessories                  | Predicted Rating: 4.30
#  4. Packages)                           | Predicted Rating: 3.30
# ============================================================
#
# ============================================================
# Customer ID: 91-440-0011
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Sports & Outdoors                   | Predicted Rating: 2.98
# ============================================================
#
# ============================================================
# Customer ID: 20-830-4758
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Luxury Goods                        | Predicted Rating: 3.90
# ============================================================
#
# ============================================================
# Customer ID: 84-337-1016
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Care                         | Predicted Rating: 3.02
# ============================================================
#
# ============================================================
# Customer ID: 09-346-4992
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Electronics                         | Predicted Rating: 3.08
# ============================================================
#
# ============================================================
# Customer ID: 75-083-3608
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Sports & Outdoors                   | Predicted Rating: 4.00
# ============================================================
#
# ============================================================
# Customer ID: 29-779-7209
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Books                               | Predicted Rating: 3.96
# ============================================================
#
# ============================================================
# Customer ID: 12-409-5166
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Baby Products                       | Predicted Rating: 3.70
#  2. Office Supplies                     | Predicted Rating: 3.60
#  3. Toys & Games                        | Predicted Rating: 3.40
#  4. Groceries                           | Predicted Rating: 3.30
# ============================================================
#
# ============================================================
# Customer ID: 07-024-4995
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Furniture                           | Predicted Rating: 3.70
# ============================================================
#
# ============================================================
# Customer ID: 74-478-5950
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Baby Products                       | Predicted Rating: 4.80
#  2. Packages)                           | Predicted Rating: 4.10
#  3. Mobile Accessories                  | Predicted Rating: 3.80
#  4. Jewelry & Accessories               | Predicted Rating: 3.00
# ============================================================
#
# ============================================================
# Customer ID: 31-395-1286
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Supplements                  | Predicted Rating: 3.78
# ============================================================
#
# ============================================================
# Customer ID: 60-838-4334
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Books                               | Predicted Rating: 4.00
# ============================================================
#
# ============================================================
# Customer ID: 71-197-8227
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Electronics                         | Predicted Rating: 3.22
# ============================================================
#
# ============================================================
# Customer ID: 15-530-3861
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Animal Feed                         | Predicted Rating: 4.95
#  2. Luxury Goods                        | Predicted Rating: 4.20
#  3. Packages)                           | Predicted Rating: 3.80
# ============================================================
#
# ============================================================
# Customer ID: 30-567-4471
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Clothing                            | Predicted Rating: 4.36
# ============================================================
#
# ============================================================
# Customer ID: 04-465-1819
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Jewelry & Accessories               | Predicted Rating: 3.62
# ============================================================
#
# ============================================================
# Customer ID: 69-692-0614
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Mobile Accessories                  | Predicted Rating: 4.34
# ============================================================
#
# ============================================================
# Customer ID: 12-839-8066
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Software & Apps                     | Predicted Rating: 4.06
# ============================================================
#
# ============================================================
# Customer ID: 05-465-8765
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Luxury Goods                        | Predicted Rating: 3.60
# ============================================================
#
# ============================================================
# Customer ID: 81-580-3810
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Care                         | Predicted Rating: 5.70
#  2. Hotels                              | Predicted Rating: 5.00
#  3. Gardening & Outdoors                | Predicted Rating: 3.50
# ============================================================
#
# ============================================================
# Customer ID: 74-353-6312
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Groceries                           | Predicted Rating: 2.84
# ============================================================
#
# ============================================================
# Customer ID: 78-824-1887
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.38
# ============================================================
#
# ============================================================
# Customer ID: 31-218-0024
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Groceries                           | Predicted Rating: 3.40
#  2. Toys & Games                        | Predicted Rating: 3.20
#  3. Travel & Leisure (Flights           | Predicted Rating: 3.00
#  4. Sports & Outdoors                   | Predicted Rating: 2.40
# ============================================================
#
# ============================================================
# Customer ID: 15-711-4107
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Gardening & Outdoors                | Predicted Rating: 3.50
#  2. Home Appliances                     | Predicted Rating: 3.50
#  3. Food & Beverages                    | Predicted Rating: 2.90
# ============================================================
#
# ============================================================
# Customer ID: 76-672-1193
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.20
# ============================================================
#
# ============================================================
# Customer ID: 46-503-5589
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Office Supplies                     | Predicted Rating: 3.94
# ============================================================
#
# ============================================================
# Customer ID: 87-499-6916
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Food & Beverages                    | Predicted Rating: 2.90
# ============================================================
#
# ============================================================
# Customer ID: 30-520-8656
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Care                         | Predicted Rating: 4.72
# ============================================================
#
# ============================================================
# Customer ID: 36-323-3504
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 3.90
#  2. Health Supplements                  | Predicted Rating: 3.90
#  3. Toys & Games                        | Predicted Rating: 3.30
# ============================================================
#
# ============================================================
# Customer ID: 93-810-4051
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Beauty & Personal Care              | Predicted Rating: 4.08
# ============================================================
#
# ============================================================
# Customer ID: 66-515-3648
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Care                         | Predicted Rating: 3.58
# ============================================================
#
# ============================================================
# Customer ID: 09-216-1957
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Jewelry & Accessories               | Predicted Rating: 3.38
# ============================================================
#
# ============================================================
# Customer ID: 23-253-2565
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.20
# ============================================================
#
# ============================================================
# Customer ID: 74-509-4985
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Clothing                            | Predicted Rating: 5.40
#  2. Mobile Accessories                  | Predicted Rating: 4.30
#  3. Home Appliances                     | Predicted Rating: 4.30
#  4. Animal Feed                         | Predicted Rating: 3.30
# ============================================================
#
# ============================================================
# Customer ID: 05-857-1572
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Animal Feed                         | Predicted Rating: 3.64
# ============================================================
#
# ============================================================
# Customer ID: 26-521-8328
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Furniture                           | Predicted Rating: 4.06
# ============================================================
#
# ============================================================
# Customer ID: 31-147-6197
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Office Supplies                     | Predicted Rating: 3.86
# ============================================================
#
# ============================================================
# Customer ID: 90-093-0469
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Care                         | Predicted Rating: 3.62
# ============================================================
#
# ============================================================
# Customer ID: 38-935-1865
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Beauty & Personal Care              | Predicted Rating: 3.34
# ============================================================
#
# ============================================================
# Customer ID: 75-953-8663
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 2.94
# ============================================================
#
# ============================================================
# Customer ID: 38-478-2681
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Home Appliances                     | Predicted Rating: 3.54
# ============================================================
#
# ============================================================
# Customer ID: 70-895-5298
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Food & Beverages                    | Predicted Rating: 3.42
# ============================================================
#
# ============================================================
# Customer ID: 02-653-5884
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Arts & Crafts                       | Predicted Rating: 3.98
# ============================================================
#
# ============================================================
# Customer ID: 11-719-8800
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Food & Beverages                    | Predicted Rating: 3.48
# ============================================================
#
# ============================================================
# Customer ID: 59-355-5251
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Animal Feed                         | Predicted Rating: 3.18
# ============================================================
#
# ============================================================
# Customer ID: 82-572-9091
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Luxury Goods                        | Predicted Rating: 6.10
#  2. Travel & Leisure (Flights           | Predicted Rating: 4.90
#  3. Arts & Crafts                       | Predicted Rating: 4.50
#  4. Mobile Accessories                  | Predicted Rating: 4.30
#  5. Food & Beverages                    | Predicted Rating: 3.10
# ============================================================
#
# ============================================================
# Customer ID: 86-044-1071
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 3.12
# ============================================================
#
# ============================================================
# Customer ID: 08-733-0300
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Books                               | Predicted Rating: 4.70
# ============================================================
#
# ============================================================
# Customer ID: 70-108-1493
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Food & Beverages                    | Predicted Rating: 4.30
#  2. Health Care                         | Predicted Rating: 3.70
#  3. Baby Products                       | Predicted Rating: 3.60
#  4. Sports & Outdoors                   | Predicted Rating: 3.30
#  5. Groceries                           | Predicted Rating: 2.70
# ============================================================
#
# ============================================================
# Customer ID: 46-230-8307
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Care                         | Predicted Rating: 2.94
# ============================================================
#
# ============================================================
# Customer ID: 74-431-0242
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Furniture                           | Predicted Rating: 5.60
#  2. Books                               | Predicted Rating: 5.20
#  3. Packages)                           | Predicted Rating: 4.00
#  4. Sports & Outdoors                   | Predicted Rating: 2.70
# ============================================================
#
# ============================================================
# Customer ID: 78-272-6417
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Jewelry & Accessories               | Predicted Rating: 3.58
# ============================================================
#
# ============================================================
# Customer ID: 13-792-4356
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Gardening & Outdoors                | Predicted Rating: 3.02
# ============================================================
#
# ============================================================
# Customer ID: 04-563-9091
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Office Supplies                     | Predicted Rating: 3.40
# ============================================================
#
# ============================================================
# Customer ID: 79-592-5396
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Sports & Outdoors                   | Predicted Rating: 3.00
# ============================================================
#
# ============================================================
# Customer ID: 39-952-4459
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Electronics                         | Predicted Rating: 3.80
# ============================================================
#
# ============================================================
# Customer ID: 67-935-7964
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Office Supplies                     | Predicted Rating: 3.98
# ============================================================
#
# ============================================================
# Customer ID: 26-828-2720
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Baby Products                       | Predicted Rating: 4.60
#  2. Home Appliances                     | Predicted Rating: 4.30
#  3. Office Supplies                     | Predicted Rating: 3.50
#  4. Health Supplements                  | Predicted Rating: 3.10
#  5. Jewelry & Accessories               | Predicted Rating: 1.90
# ============================================================
#
# ============================================================
# Customer ID: 57-410-7415
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Food & Beverages                    | Predicted Rating: 3.30
# ============================================================
#
# ============================================================
# Customer ID: 62-989-8214
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Luxury Goods                        | Predicted Rating: 5.30
#  2. Packages)                           | Predicted Rating: 4.90
#  3. Baby Products                       | Predicted Rating: 4.10
#  4. Health Supplements                  | Predicted Rating: 2.95
# ============================================================
#
# ============================================================
# Customer ID: 73-827-2774
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Baby Products                       | Predicted Rating: 4.60
#  2. Hotels                              | Predicted Rating: 4.30
#  3. Home Appliances                     | Predicted Rating: 4.20
#  4. Mobile Accessories                  | Predicted Rating: 3.50
#  5. Arts & Crafts                       | Predicted Rating: 2.80
# ============================================================
#
# ============================================================
# Customer ID: 19-643-1879
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Packages)                           | Predicted Rating: 4.00
#  2. Hotels                              | Predicted Rating: 3.30
#  3. Software & Apps                     | Predicted Rating: 3.10
#  4. Clothing                            | Predicted Rating: 2.60
#  5. Jewelry & Accessories               | Predicted Rating: 2.50
# ============================================================
#
# ============================================================
# Customer ID: 57-345-3921
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Jewelry & Accessories               | Predicted Rating: 3.34
# ============================================================
#
# ============================================================
# Customer ID: 98-817-6731
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Supplements                  | Predicted Rating: 3.78
# ============================================================
#
# ============================================================
# Customer ID: 31-788-0864
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Beauty & Personal Care              | Predicted Rating: 4.80
# ============================================================
#
# ============================================================
# Customer ID: 27-806-4972
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Care                         | Predicted Rating: 3.32
# ============================================================
#
# ============================================================
# Customer ID: 48-343-1220
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Jewelry & Accessories               | Predicted Rating: 3.58
# ============================================================
#
# ============================================================
# Customer ID: 15-640-6493
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Animal Feed                         | Predicted Rating: 3.66
# ============================================================
#
# ============================================================
# Customer ID: 64-846-7450
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 3.58
# ============================================================
#
# ============================================================
# Customer ID: 58-788-8938
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Supplements                  | Predicted Rating: 2.96
# ============================================================
#
# ============================================================
# Customer ID: 52-240-3825
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Home Appliances                     | Predicted Rating: 4.02
# ============================================================
#
# ============================================================
# Customer ID: 60-618-2561
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 3.84
# ============================================================
#
# ============================================================
# Customer ID: 94-969-6819
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Home Appliances                     | Predicted Rating: 5.20
#  2. Baby Products                       | Predicted Rating: 4.30
#  3. Health Supplements                  | Predicted Rating: 4.30
#  4. Animal Feed                         | Predicted Rating: 3.20
# ============================================================
#
# ============================================================
# Customer ID: 76-982-8107
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Electronics                         | Predicted Rating: 3.50
# ...
#
# ============================================================
# Customer ID: 17-763-9416
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Office Supplies                     | Predicted Rating: 5.10
#  2. Mobile Accessories                  | Predicted Rating: 4.90
#  3. Sports & Outdoors                   | Predicted Rating: 4.10
#  4. Packages)                           | Predicted Rating: 3.65
# ============================================================
#
# ============================================================
# Customer ID: 56-453-8263
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Mobile Accessories                  | Predicted Rating: 4.22
# ============================================================
#
# ============================================================
# Customer ID: 19-560-0717
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 3.96
# ============================================================
#
# ============================================================
# Customer ID: 40-199-1803
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Supplements                  | Predicted Rating: 2.88
# ============================================================
#
# ============================================================
# Customer ID: 09-332-0236
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Baby Products                       | Predicted Rating: 3.63
# ============================================================
#
# ============================================================
# Customer ID: 83-982-5300
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Office Supplies                     | Predicted Rating: 3.78
# ============================================================
#
# ============================================================
# Customer ID: 46-662-1571
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Packages)                           | Predicted Rating: 4.12
# ============================================================
#
# ============================================================
# Customer ID: 20-699-9217
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Packages)                           | Predicted Rating: 3.54
# ============================================================
#
# ============================================================
# Customer ID: 26-150-0209
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 5.40
#  2. Furniture                           | Predicted Rating: 4.90
#  3. Luxury Goods                        | Predicted Rating: 3.60
#  4. Jewelry & Accessories               | Predicted Rating: 3.30
# ============================================================
#
# ============================================================
# Customer ID: 94-985-5336
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Clothing                            | Predicted Rating: 4.24
# ============================================================
#
# ============================================================
# Customer ID: 97-715-3606
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 5.00
#  2. Furniture                           | Predicted Rating: 4.90
#  3. Mobile Accessories                  | Predicted Rating: 4.50
# ============================================================
#
# ============================================================
# Customer ID: 02-100-4320
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Baby Products                       | Predicted Rating: 3.22
# ============================================================
#
# ============================================================
# Customer ID: 16-070-0138
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Luxury Goods                        | Predicted Rating: 3.60
# ============================================================
#
# ============================================================
# Customer ID: 82-474-5074
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 4.06
# ============================================================
#
# ============================================================
# Customer ID: 36-444-5336
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Food & Beverages                    | Predicted Rating: 3.20
# ============================================================
#
# ============================================================
# Customer ID: 54-680-5344
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Office Supplies                     | Predicted Rating: 3.10
# ============================================================
#
# ============================================================
# Customer ID: 16-364-8096
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Animal Feed                         | Predicted Rating: 3.66
# ============================================================
#
# ============================================================
# Customer ID: 62-644-8183
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.34
# ============================================================
#
# ============================================================
# Customer ID: 59-971-0799
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Supplements                  | Predicted Rating: 3.04
# ============================================================
#
# ============================================================
# Customer ID: 64-031-2046
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Beauty & Personal Care              | Predicted Rating: 3.14
# ============================================================
#
# ============================================================
# Customer ID: 87-079-0237
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 4.00
# ============================================================
#
# ============================================================
# Customer ID: 78-091-8662
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Gardening & Outdoors                | Predicted Rating: 2.82
# ============================================================
#
# ============================================================
# Customer ID: 62-720-2922
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Home Appliances                     | Predicted Rating: 3.56
# ============================================================
#
# ============================================================
# Customer ID: 47-528-3961
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Gardening & Outdoors                | Predicted Rating: 3.32
# ============================================================
#
# ============================================================
# Customer ID: 21-808-2293
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 3.88
# ============================================================
#
# ============================================================
# Customer ID: 22-022-9256
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Jewelry & Accessories               | Predicted Rating: 3.70
# ============================================================
#
# ============================================================
# Customer ID: 96-772-7220
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Travel & Leisure (Flights           | Predicted Rating: 3.84
# ============================================================
#
# ============================================================
# Customer ID: 25-866-7286
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Electronics                         | Predicted Rating: 4.14
# ============================================================
#
# ============================================================
# Customer ID: 72-694-4159
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Electronics                         | Predicted Rating: 3.30
# ============================================================
#
# ============================================================
# Customer ID: 10-079-8237
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Mobile Accessories                  | Predicted Rating: 4.24
# ============================================================
#
# ============================================================
# Customer ID: 47-460-8015
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Books                               | Predicted Rating: 4.26
# ============================================================
#
# ============================================================
# Customer ID: 06-061-0023
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Hotels                              | Predicted Rating: 3.32
# ============================================================
#
# ============================================================
# Customer ID: 80-487-2550
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Electronics                         | Predicted Rating: 3.96
# ============================================================
#
# ============================================================
# Customer ID: 23-617-2637
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Software & Apps                     | Predicted Rating: 4.06
# ============================================================
#
# ============================================================
# Customer ID: 60-005-5187
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Electronics                         | Predicted Rating: 4.12
# ============================================================
#
# ============================================================
# Customer ID: 24-371-5870
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Home Appliances                     | Predicted Rating: 3.22
# ============================================================
#
# ============================================================
# Customer ID: 02-055-8248
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Supplements                  | Predicted Rating: 4.18
# ============================================================
#
# ============================================================
# Customer ID: 54-238-5459
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Jewelry & Accessories               | Predicted Rating: 2.74
# ============================================================
#
# ============================================================
# Customer ID: 85-922-0190
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Toys & Games                        | Predicted Rating: 4.66
# ============================================================
#
# ============================================================
# Customer ID: 48-271-1908
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Baby Products                       | Predicted Rating: 4.22
# ============================================================
#
# ============================================================
# Customer ID: 46-978-3874
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Beauty & Personal Care              | Predicted Rating: 4.50
#  2. Gardening & Outdoors                | Predicted Rating: 3.40
#  3. Baby Products                       | Predicted Rating: 3.40
#  4. Health Supplements                  | Predicted Rating: 3.10
# ============================================================
#
# ============================================================
# Customer ID: 53-595-7635
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Clothing                            | Predicted Rating: 4.70
#  2. Animal Feed                         | Predicted Rating: 4.00
#  3. Sports & Outdoors                   | Predicted Rating: 2.90
#  4. Travel & Leisure (Flights           | Predicted Rating: 2.40
#  5. Health Care                         | Predicted Rating: 1.50
# ============================================================
#
# ============================================================
# Customer ID: 08-185-6608
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Baby Products                       | Predicted Rating: 4.12
# ============================================================
#
# ============================================================
# Customer ID: 20-562-2569
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Mobile Accessories                  | Predicted Rating: 4.30
# ============================================================
#
# ============================================================
# Customer ID: 41-366-4205
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Animal Feed                         | Predicted Rating: 5.30
#  2. Furniture                           | Predicted Rating: 4.70
#  3. Hotels                              | Predicted Rating: 4.10
# ============================================================
#
# ============================================================
# Customer ID: 77-241-7621
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Food & Beverages                    | Predicted Rating: 4.00
# ============================================================
#
# ============================================================
# Customer ID: 53-091-2176
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Baby Products                       | Predicted Rating: 4.00
# ============================================================
#
# ============================================================
# Customer ID: 48-203-9118
# Top Recommended Product Categories:
# ------------------------------------------------------------
#  1. Health Care                         | Predicted Rating: 3.58
# ============================================================

# %% [markdown]
# ---
# ---
# Fairness Evaluations
# ---

# %% [markdown]
# Creating a dictionary to store customer demographics:

# %%
customer_demographics = {}

"""
    Constructs a dictionary mapping each Customer ID to their demographic attributes.

    Parameters:
    df (DataFrame): E-commerce dataset with customer demographic columns.

    Returns:
    dict: Dictionary with Customer IDs as keys and demographic attributes as values.
"""

# Fill the customer demographics dictionary
for _, row in e_commerce.iterrows():
    customer_demographics[row['Customer_ID']] = {
        'gender': row['Gender'],
        'age_group': row['Age_Group'],
        'income_level': row['Income_Level'],
        'education_level': row['Education_Level'],
        'occupation': row['Occupation'],
        'marital_status': row['Marital_Status']
    }

# %% [markdown]
# Creating the top 5 predictions for each customer using SVD++

# %%
def get_svdpp_top5_recommendations(user_item_matrix, svdpp_model):
    """
    Generates the top-5 recommended categories for each customer using an SVD++ model.

    Parameters:
    user_item_matrix (DataFrame): Matrix with categories as rows and customers as columns.
    svdpp_model (object): Trained SVD++ recommender model.

    Returns:
    dict: Dictionary where keys are customer IDs and values are lists of tuples 
          containing top-5 recommended categories and their predicted ratings.
    """
    svd_top_5_recs = defaultdict(list)

    # Iterate over all customers
    for customer in user_item_matrix.columns:
        # Predict ratings for all categories for the current customer
        for category in user_item_matrix.index:
            svd_prediction = svdpp_model.predict(uid=category, iid=customer)
            svd_top_5_recs[customer].append((category, svd_prediction.est))
        
        # Sort categories by predicted ratings (descending) and select top-5
        svd_top_5_recs[customer] = sorted(
            svd_top_5_recs[customer],
            key=lambda x: x[1],
            reverse=True
        )[:5]

    return svd_top_5_recs

# %% [markdown]
# Creating the top 5 predictions for each customer using ItemKNN

# %%
def get_knn_top5_recommendations(user_item_matrix, predict_rating_func, k=5):
    """
    Generates the top-5 recommended categories for each customer using an Item-based KNN model.

    Parameters:
    user_item_matrix (DataFrame): Matrix with categories as rows and customers as columns.
    predict_rating_func (function): Function to predict ratings given user_id, item_id, and k neighbors.
    k (int): Number of neighbors to consider for KNN predictions.

    Returns:
    dict: Dictionary with customer IDs as keys and lists of top-5 recommended categories and ratings as values.
    """
    knn_top_5_recs = defaultdict(list)

    # Iterate over all customers
    for customer in user_item_matrix.columns:
        # Predict ratings only for categories not rated by the customer
        for category in user_item_matrix.index:
            if user_item_matrix.loc[category, customer] == 0:
                knn_prediction = predict_rating_hybrid(user_id=category, item_id=customer, k=k)
                if not np.isnan(knn_prediction):
                    knn_top_5_recs[customer].append((category, knn_prediction))
        
        # Sort predictions by rating descending and select top-5
        knn_top_5_recs[customer] = sorted(
            knn_top_5_recs[customer],
            key=lambda x: x[1],
            reverse=True
        )[:5]

    return knn_top_5_recs

# %% [markdown]
# ---
# ---
# **Individual User Fairness**
# ---
# In this analysis, the individual user fairness of the two recommendation system models (SVD++ and Item-KNN) are evaluated using two metrics: Variance and Mean Average Envy (MAE). Both metrics capture distinct aspects of fairness by assessing the consistency and perceived equity of recommendations across individual customers.
#
# 1) **Variance** measures how consistent the predicted ratings are for each individual user across the product categories recommended to them (top-5). A high variance indicates the user is being treated inconsistently — getting some highly rated and some poorly rated items — which could reflect unfairness or instability in their recommendations. A fair recommender should provide consistently high-quality or stable recommendations. This is computed as follows:
#     - Loop over each customer in the top-5 recommendations dictionary (either from SVD++ or KNN).
#     - Compute the variance of the top 5 predicted ratings for each individual.
#
# 2) **Mean Average Envy** evaluates how much each individual user might envy others’ recommendations — if they see others being recommended the same items but with higher predicted ratings. A fair system should not make users feel disadvantaged compared to others. High envy means many others received better recommendations for the same items → potentially unfair model. This is computed as follows:
#     - For each customer i, it loops over all other customers j.
#     - For each pair of users, it compares only the categories they have in common.
#     - For each shared category: Envy 𝑖 → 𝑗 = max(Rating 𝑗 − Rating 𝑖, 0)
#     - Sum envy values across all comparisons, then average over the total number of comparisons made to get the mean average envy for each individual.

# %% [markdown]
# ---
# **1) Variance for Individual Fairness:**
# --

# %%
def calculate_individual_variances(top_5_recommendations):
    """
    Calculates variance in predicted ratings for each individual customer based on recommended categories.

    Parameters:
    top_5_recommendations (dict): Dictionary with customer IDs as keys and 
                                  lists of tuples (category, predicted_rating).

    Returns:
    dict: Dictionary mapping customer_id to their rating variance and number of rated categories.
          Format: {customer_id: {"variance": float, "count": int}}
    """
    individual_stats = {}

    for customer, recommendations in top_5_recommendations.items():
        ratings = [rating for _, rating in recommendations]
        
        variance_value = np.var(ratings) if ratings else 0.0
        count = len(ratings)
        
        individual_stats[customer] = {"variance": variance_value, "count": count}
    
    return individual_stats

# %%
def group_variances_by_age(individual_stats, customer_demographics, age_key="age_group"):
    """
    Groups individual variances by customer age group.

    Parameters:
    individual_stats (dict): Customer variance statistics from `calculate_individual_variances`.
    customer_demographics (dict): Customer demographics dictionary.
    age_key (str): Demographic attribute used to group by age. Default is "age_group".

    Returns:
    list[dict]: List containing variance data grouped by age, ready for DataFrame creation.
                Format: [{"Age Group": str, "Customer ID": str, "Variance": float, "Count": int}, ...]
    """
    rows = []

    for customer, stats in individual_stats.items():
        demographics = customer_demographics.get(customer, {})
        age_group = demographics.get(age_key, "Unknown")

        rows.append({
            "Age Group": age_group,
            "Customer ID": customer,
            "Variance": stats["variance"],
            "Count": stats["count"]
        })
    
    return rows

# %%
def calculate_agegroup_fairness(predictions, customer_demographics, product_categories, age_key="age_group"):
    """
    Calculates average variance of predicted ratings within each age group across categories.

    Parameters:
    predictions (dict): Customer recommendations dictionary (top-5 recommendations per customer).
    customer_demographics (dict): Customer demographics dictionary.
    product_categories (list): List of all product categories.
    age_key (str): Key for age group in demographics. Default "age_group".

    Returns:
    dict: Dictionary mapping age group to their average variance and total rating count.
          Format: {age_group: {"avg_variance": float, "total_count": int}}
    """
    agegroup_cat_ratings = defaultdict(lambda: defaultdict(list))

    for customer, recs in predictions.items():
        demographics = customer_demographics.get(customer, {})
        age_group = demographics.get(age_key, "Unknown")

        for category, rating in recs:
            if category in product_categories:
                agegroup_cat_ratings[age_group][category].append(rating)

    fairness_by_age = {}

    for age_group, categories in agegroup_cat_ratings.items():
        variances = []
        total_count = 0

        for category in product_categories:
            ratings = categories.get(category, [])
            if ratings:
                variances.append(np.var(ratings))
                total_count += len(ratings)

        avg_variance = np.mean(variances) if variances else 0.0

        fairness_by_age[age_group] = {"avg_variance": avg_variance, "total_count": total_count}

    return fairness_by_age

# %%
# --- Generate top-5 recommendations with SVD++ first ---
svd_top_5_recs = get_svdpp_top5_recommendations(user_item_matrix, final_svdpp_model)

# --- Individual variance calculation using SVD++ recommendations ---
svd_individual_stats = calculate_individual_variances(svd_top_5_recs)
svd_rows = group_variances_by_age(svd_individual_stats, customer_demographics)

# --- Create DataFrame for easy readability ---
svd_df = pd.DataFrame(svd_rows).sort_values(by=["Age Group", "Customer ID"])

# --- Display the results ---
print("SVD++ Individual Fairness by Age Group")
print(svd_df.to_string(index=False))
# Out:
# SVD++ Individual Fairness by Age Group
# Age Group Customer ID  Variance  Count
#     18–25 00-265-0556  0.005902      5
#     18–25 00-275-9990  0.026615      5
#     18–25 02-055-8248  0.004591      5
#     18–25 02-677-6735  0.002873      5
#     18–25 03-102-0288  0.001256      5
#     18–25 03-977-8103  0.001810      5
#     18–25 04-468-5487  0.002492      5
#     18–25 04-809-8989  0.004591      5
# --- Individual variance calculation using Item-KNN recommendations ---
knn_individual_stats = calculate_individual_variances(knn_top_5_recs)
knn_rows = group_variances_by_age(knn_individual_stats, customer_demographics)

# --- Create DataFrame for easy readability ---
knn_df = pd.DataFrame(knn_rows).sort_values(by=["Age Group", "Customer ID"])

# --- Display the results ---
print("\nKNN Individual Fairness by Age Group")
print(knn_df.to_string(index=False))
# Out:
# KNN Individual Fairness by Age Group
# Age Group Customer ID  Variance  Count
#     18–25 00-265-0556  0.000000      0
#     18–25 00-275-9990  0.000000      0
#     18–25 02-055-8248  0.000000      0
#     18–25 02-677-6735  0.000000      0
#     18–25 03-102-0288  0.000000      0
#     18–25 03-977-8103  0.000000      0
#     18–25 04-468-5487  0.000000      0
#     18–25 04-809-8989  0.000000      0
#     18–25 05-067-9686  0.000000      0
#     18–25 05-167-0833  0.000000      0
#     18–25 05-546-5128  0.000000      0
#     18–25 05-857-1572  0.000000      0
#     18–25 06-061-0023  0.000000      0
#     18–25 06-160-8063  0.000000      0
#     18–25 07-314-2945  0.000000      0
#     18–25 07-751-9620  0.000000      0
#     18–25 07-966-8728  0.000000      0
#     18–25 08-584-8296  0.135556      3
#     18–25 08-806-0588  0.000000      0
#     18–25 09-775-4058  0.000000      0
#     18–25 09-783-7921  0.000000      0
#     18–25 09-948-3150  0.000000      0
#     18–25 10-430-5821  0.000000      0
#     18–25 11-820-5039  0.000000      0
#     18–25 12-839-8066  0.000000      0
#     18–25 13-571-6506  0.000000      0
#     18–25 13-588-5783  0.000000      0
#     18–25 13-792-4356  0.000000      0
#     18–25 14-025-2335  0.000000      0
#     18–25 14-118-5229  0.000000      0
#     18–25 14-784-5606  0.000000      0
#     18–25 15-152-9751  0.000000      0
#     18–25 15-421-1255  0.000000      0
#     18–25 15-663-7994  0.000000      0
#     18–25 18-452-1635  0.000000      0
#     18–25 18-593-8611  0.000000      0
#     18–25 18-925-1867  0.000000      0
#     18–25 19-184-7665  0.000000      0
#     18–25 19-311-9149  0.015556      3
#     18–25 19-386-9088  0.000000      0
#     18–25 19-925-2376  0.542222      3
#     18–25 20-421-2544  0.000000      0
#     18–25 21-232-1397  0.000000      0
#     18–25 21-734-0212  0.441875      4
#     18–25 21-959-5766  0.000000      0
#     18–25 22-157-2494  0.000000      0
#     18–25 22-860-9860  0.000000      0
#     18–25 23-066-1915  0.000000      0
#     18–25 23-253-2565  0.000000      0
#     18–25 23-537-0742  0.000000      0
#     18–25 24-853-1635  0.046667      3
#     18–25 26-672-1285  0.000000      0
#     18–25 27-010-9462  0.000000      0
#     18–25 27-017-7173  0.022500      2
#     18–25 27-262-6874  0.000000      0
#     18–25 27-439-9545  0.606667      3
#     18–25 27-463-5671  0.000000      0
#     18–25 27-619-9264  0.000000      0
#     18–25 28-832-2885  0.635000      4
#     18–25 29-987-3969  0.000000      0
#     18–25 30-520-8656  0.000000      0
#     18–25 30-735-8744  0.000000      0
#     18–25 31-147-6197  0.000000      0
#     18–25 31-218-0024  0.140000      4
#     18–25 31-783-9785  0.000000      0
#     46–50 87-518-0375  0.000000      0
#     46–50 88-000-9227  0.086667      3
#     46–50 88-051-0567  0.000000      0
#     46–50 88-445-9235  0.000000      0
#     46–50 89-730-1134  0.469110      3
#     46–50 90-888-8726  0.305600      5
#     46–50 90-918-2833  0.000000      0
#     46–50 91-053-3261  0.000000      0
#     46–50 91-440-0011  0.000000      0
#     46–50 91-558-5922  0.000000      0
#     46–50 91-570-2695  0.000000      0
#     46–50 91-603-1565  0.000000      0
#     46–50 94-495-3402  1.651874      4
#     46–50 97-237-3483  0.000000      0
#     46–50 99-089-1930  0.000000      0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter out customers with no predictions (variance=0 and count=0)
filtered_knn_df = knn_df[knn_df['Count'] > 0]
filtered_svd_df = svd_df[svd_df['Count'] > 0]

# Combine into one DataFrame for easier plotting
svd_df['Model'] = 'SVD++'
knn_df['Model'] = 'Item-KNN'
combined_df = pd.concat([svd_df, knn_df])

plt.figure(figsize=(10,6))
sns.boxplot(data=combined_df, x='Model', y='Variance')
plt.title('Comparison of Individual Variances by Model')
plt.ylabel('Variance of Predicted Ratings')
plt.xlabel('Recommender Model')
plt.show()

# %% [markdown]
# ---
# **2) Mean Average Envy for Individual Fairness:**
# --

# %%
def calculate_individual_mean_average_envy(top_5_recommendations):
    """
    Calculates Mean Average Envy (MAE) for each customer based on their predicted ratings.
    Envy is defined as the average positive difference between the ratings of other customers
    and the focal customer's own rating for the same category.

    Parameters:
        top_5_recommendations (dict):
            Dictionary mapping customer IDs to a list of tuples (product_category, predicted_rating).

    Returns:
        dict: Dictionary mapping customer IDs to their MAE values.
              Format: {customer_id: mean_average_envy (float)}
    """
    individual_envy = {}
    customers = list(top_5_recommendations.keys())

    for customer_i in customers:
        recs_i = top_5_recommendations.get(customer_i, [])
        total_envy = 0
        comparisons = 0

        for category_i, rating_i in recs_i:
            # Compare against all other customers
            for customer_j in customers:
                if customer_i == customer_j:
                    continue
                recs_j = top_5_recommendations.get(customer_j, [])
                # Check ratings for the same category
                for category_j, rating_j in recs_j:
                    if category_j == category_i:
                        envy = max(rating_j - rating_i, 0)
                        total_envy += envy
                        comparisons += 1

        individual_envy[customer_i] = total_envy / comparisons if comparisons > 0 else 0.0

    return individual_envy

# %%
def group_envy_by_age(individual_envy, customer_demographics, age_key="age_group"):
    """
    Groups individual MAE values by customer age group.

    Parameters:
        individual_envy (dict):
            Dictionary mapping customer IDs to MAE values.
        customer_demographics (dict):
            Dictionary mapping customer IDs to their demographic information.
        age_key (str):
            Demographic attribute to group by age (default "age_group").

    Returns:
        list[dict]: List containing MAE data grouped by age, ready for DataFrame creation.
                    Format: [{"Age Group": str, "Customer ID": str, "Envy": float}, ...]
    """
    rows = []

    for customer, envy_value in individual_envy.items():
        demographics = customer_demographics.get(customer, {})
        age_group = demographics.get(age_key, "Unknown")

        rows.append({
            "Age Group": age_group,
            "Customer ID": customer,
            "Envy": envy_value
        })

    return rows

# %%
# --- Generate Individual Envy from SVD++ recommendations ---
svd_individual_envy = calculate_individual_mean_average_envy(svd_top_5_recs)
svd_envy_rows = group_envy_by_age(svd_individual_envy, customer_demographics)

# Create DataFrame and sort
svd_envy_df = pd.DataFrame(svd_envy_rows).sort_values(by=["Age Group", "Customer ID"])

# Display individual envy grouped by age group
print("SVD++ Individual Envy by Age Group")
print("====================================")

current_age_group = None
for _, row in svd_envy_df.iterrows():
    age_group = row["Age Group"]
    customer_id = row["Customer ID"]
    envy_value = row["Envy"]

    # Print header for new age group
    if age_group != current_age_group:
        current_age_group = age_group
        print(f"\n=== Age Group: {current_age_group} ===")

    # Print envy score per customer
    print(f"Customer ID: {customer_id}, Envy: {envy_value:.2f}")
# Out:
# SVD++ Individual Envy by Age Group
# ====================================
#
# === Age Group: 18–25 ===
# Customer ID: 00-265-0556, Envy: 0.06
# Customer ID: 00-275-9990, Envy: 0.01
# Customer ID: 02-055-8248, Envy: 0.06
# Customer ID: 02-677-6735, Envy: 0.11
# Customer ID: 03-102-0288, Envy: 0.07
# Customer ID: 03-977-8103, Envy: 0.03
# Customer ID: 04-468-5487, Envy: 0.19
# Customer ID: 04-809-8989, Envy: 0.06
# Customer ID: 05-067-9686, Envy: 0.14
# Customer ID: 05-167-0833, Envy: 0.06
# Customer ID: 05-546-5128, Envy: 0.03
# Customer ID: 05-857-1572, Envy: 0.06
# Customer ID: 06-061-0023, Envy: 0.06
# Customer ID: 06-160-8063, Envy: 0.01
# Customer ID: 07-314-2945, Envy: 0.01
# Customer ID: 07-751-9620, Envy: 0.05
# Customer ID: 07-966-8728, Envy: 0.06
# Customer ID: 08-584-8296, Envy: 0.06
# Customer ID: 08-806-0588, Envy: 0.06
# Customer ID: 09-775-4058, Envy: 0.08
# Customer ID: 09-783-7921, Envy: 0.05
# Customer ID: 09-948-3150, Envy: 0.06
# Customer ID: 10-430-5821, Envy: 0.06
# Customer ID: 11-820-5039, Envy: 0.06
# Customer ID: 12-839-8066, Envy: 0.06
# Customer ID: 13-571-6506, Envy: 0.09
# Customer ID: 13-588-5783, Envy: 0.02
# Customer ID: 13-792-4356, Envy: 0.03
# Customer ID: 14-025-2335, Envy: 0.04
# Customer ID: 14-118-5229, Envy: 0.11
# Customer ID: 14-784-5606, Envy: 0.10
# Customer ID: 15-152-9751, Envy: 0.06
# Customer ID: 15-421-1255, Envy: 0.08
# Customer ID: 15-663-7994, Envy: 0.06
# Customer ID: 18-452-1635, Envy: 0.10
# Customer ID: 18-593-8611, Envy: 0.01
# Customer ID: 18-925-1867, Envy: 0.01
# Customer ID: 19-184-7665, Envy: 0.06
# Customer ID: 19-311-9149, Envy: 0.04
# Customer ID: 19-386-9088, Envy: 0.11
# Customer ID: 19-925-2376, Envy: 0.03
# Customer ID: 20-421-2544, Envy: 0.03
# Customer ID: 21-232-1397, Envy: 0.02
# Customer ID: 21-734-0212, Envy: 0.13
# Customer ID: 21-959-5766, Envy: 0.06
# Customer ID: 22-157-2494, Envy: 0.10
# Customer ID: 22-860-9860, Envy: 0.06
# Customer ID: 23-066-1915, Envy: 0.04
# Customer ID: 23-253-2565, Envy: 0.06
knn_envy_rows = group_envy_by_age(knn_individual_envy, customer_demographics)

# Create DataFrame and sort
knn_envy_df = pd.DataFrame(knn_envy_rows).sort_values(by=["Age Group", "Customer ID"])

# Display individual envy grouped by age group
print("\nKNN Individual Envy by Age Group")
print("====================================")

current_age_group = None
for _, row in knn_envy_df.iterrows():
    age_group = row["Age Group"]
    customer_id = row["Customer ID"]
    envy_value = row["Envy"]

    # Print header for new age group
    if age_group != current_age_group:
        current_age_group = age_group
        print(f"\n=== Age Group: {current_age_group} ===")

    # Print envy score per customer
    print(f"Customer ID: {customer_id}, Envy: {envy_value:.2f}")
# Out:
# KNN Individual Envy by Age Group
# ====================================
#
# === Age Group: 18–25 ===
# Customer ID: 00-265-0556, Envy: 0.00
# Customer ID: 00-275-9990, Envy: 0.00
# Customer ID: 02-055-8248, Envy: 0.00
# Customer ID: 02-677-6735, Envy: 0.00
# Customer ID: 03-102-0288, Envy: 0.00
# Customer ID: 03-977-8103, Envy: 0.00
# Customer ID: 04-468-5487, Envy: 0.00
# Customer ID: 04-809-8989, Envy: 0.00
# Customer ID: 05-067-9686, Envy: 0.00
# Customer ID: 05-167-0833, Envy: 0.00
# Customer ID: 05-546-5128, Envy: 0.00
# Customer ID: 05-857-1572, Envy: 0.00
# Customer ID: 06-061-0023, Envy: 0.00
# Customer ID: 06-160-8063, Envy: 0.00
# Customer ID: 07-314-2945, Envy: 0.00
# Customer ID: 07-751-9620, Envy: 0.00
# Customer ID: 07-966-8728, Envy: 0.00
# Customer ID: 08-584-8296, Envy: 0.65
# Customer ID: 08-806-0588, Envy: 0.00
# Customer ID: 09-775-4058, Envy: 0.00
# Customer ID: 09-783-7921, Envy: 0.00
# Customer ID: 09-948-3150, Envy: 0.00
# Customer ID: 10-430-5821, Envy: 0.00
# Customer ID: 11-820-5039, Envy: 0.00
# Customer ID: 12-839-8066, Envy: 0.00
# Customer ID: 13-571-6506, Envy: 0.00
# Customer ID: 13-588-5783, Envy: 0.00
# Customer ID: 13-792-4356, Envy: 0.00
# Customer ID: 14-025-2335, Envy: 0.00
# Customer ID: 14-118-5229, Envy: 0.00
# Customer ID: 14-784-5606, Envy: 0.00
# Customer ID: 15-152-9751, Envy: 0.00
# Customer ID: 15-421-1255, Envy: 0.00
# Customer ID: 15-663-7994, Envy: 0.00
# Customer ID: 18-452-1635, Envy: 0.00
# Customer ID: 18-593-8611, Envy: 0.00
# Customer ID: 18-925-1867, Envy: 0.00
# Customer ID: 19-184-7665, Envy: 0.00
# Customer ID: 19-311-9149, Envy: 0.10
# Customer ID: 19-386-9088, Envy: 0.00
# Customer ID: 19-925-2376, Envy: 0.54
# Customer ID: 20-421-2544, Envy: 0.00
# Customer ID: 21-232-1397, Envy: 0.00
# Customer ID: 21-734-0212, Envy: 0.51
# Customer ID: 21-959-5766, Envy: 0.00
# Customer ID: 22-157-2494, Envy: 0.00
# Customer ID: 22-860-9860, Envy: 0.00
# Customer ID: 23-066-1915, Envy: 0.00
# Customer ID: 23-253-2565, Envy: 0.00
filtered_knn_envy_df = knn_envy_df[knn_envy_df['Envy'] > 0]

# Clearly state how many customers were removed (optional but recommended for transparency)
print(f"SVD++: {len(svd_envy_df) - len(filtered_svd_envy_df)} customers with zero envy removed.")
print(f"Item-KNN: {len(knn_envy_df) - len(filtered_knn_envy_df)} customers with zero envy removed.")

# Combine envy data into one filtered DataFrame for accurate visualization
filtered_svd_envy_df['Model'] = 'SVD++'
filtered_knn_envy_df['Model'] = 'Item-KNN'
filtered_combined_envy_df = pd.concat([filtered_svd_envy_df, filtered_knn_envy_df])

# Create boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=filtered_combined_envy_df, x='Model', y='Envy')
plt.title('Comparison of Individual Mean Average Envy by Model (Filtered)')
plt.ylabel('Mean Average Envy')
plt.xlabel('Recommender Model')
plt.show()
# Out:
# SVD++: 0 customers with zero envy removed.
# Item-KNN: 789 customers with zero envy removed.
# C:\Users\vahav\AppData\Local\Temp\ipykernel_31124\3010405682.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_knn_envy_df['Model'] = 'Item-KNN'

# %% [markdown]
# ---
# ---
# **Group User Fairness**
# ---
# To evaluate group fairness in the recommender systems, four complementary fairness metrics are applied across various demographic attributes (gender, age, income and education level and sarital status). Each metric captures a different dimension of fairness in predicted satisfaction.
#
# 1) **Variance** captures how consistent the predicted ratings are for users within a demographic group across product categories. A fair recommender should treat users in the same group similarly (e.g., same gender or age group). Lower vairance refers to a fairer system (more consistency for that group).It is computed as follows:
#     - Group customers by demographic attribute (e.g. gender_female)
#     - For each product category, collect all predicted ratings from users in that group.
#     - Compute the variance of those ratings.
#     - Average variances across all categories → gives one fairness score per group.
#
# 2) **Mean Average Envy (MAE)** quantifies how much users in a demographic group might envy recommendations given to others in the same group. A fair model should make all users feel their recommendations are not worse than others in their dempgraphical attribute group. Lower envy → users aren’t disadvantaged compared to their peers → fairer system. Within each demographic group (e.g., gender_female), it:
#     - Compares all pairs of users who received recommendations for the same category within each demographic group (e.g. gender_female)
#     - For each pair (comparison): calculatete envy:
#         - Envy 𝑖 → 𝑗 = max(Rating 𝑗 − Rating 𝑖, 0)
#             - If user j got a better rating than i, user i envies that.
#     - All envy values are summed and averaged over the number of comparisons.
#     - The final output is the mean average envy per group.
#
# 3) **Absolute Difference (AD)** captures the difference in average predicted satisfaction between a rotected group (females) and an unprotected group (males). These groups were selected to showcase for the metric works, but tehy could also be e.g. active users and inactive users. A fair model should not favor one group over another in terms of average predicted rating. Lower AD indicates smaller disparity (gap) between protected and unprotected groups → more equal (fair) treatment across groups. This is computes as:
#     - For each product category, seperate predicted ratings by gender
#     - Compute: AD category = ∣average rating of the unprotected group − average rating of the protected group∣
#     - Average across all categories for an overall fairness score.
#
# 4) **Fraction of Satisfied Users (FSU)** reflects how many users in a group are at least as satisfied as the group's average, based on predicted ratings. If most users in a group feel they are at or above the group norm, that suggests equitable treatment. Higher satisfaction means that more users in that group receive recommendations they are likely to appriciate → more equitable satisfaction. It is computes as follows:
#     - Compute each user's average predicted rating (i.e. their "utility").
#     - Calculate the average utility for their group.
#     - Mark user as "satisfied" if their average utility is ≥ group average.
#     - Count the fraction of satisfied users in each group by summing satisfied customers and dividing by the group total.

# %% [markdown]
# ---
# **1) Variance for Group Fairness:**
# ---
#
# Measuring the consistency within a group.

# %% [markdown]
# Function for calculating the variance within each demographic group for each product category:

# %%
def calculate_group_variances(top_5_recommendations, customer_demographics, demographic_columns, product_categories):
    """
    Calculates variance in predicted ratings for each demographic group across product categories.

    Parameters:
        top_5_recommendations (dict):
            Dictionary mapping customer IDs to lists of tuples (category, predicted_rating).
        customer_demographics (dict):
            Dictionary mapping customer IDs to their demographic attributes.
        demographic_columns (list[str]):
            List of demographic attributes (e.g., ['gender', 'age_group']).
        product_categories (list[str]):
            List of product categories.

    Returns:
        dict: Nested dictionary structured as follows:
            {
                'gender_Male': {
                    'Category1': {'variance': float, 'count': int},
                    'Category2': {'variance': float, 'count': int}, ...
                },
                ...
            }
    """
    group_stats = defaultdict(lambda: defaultdict(dict))

    # Group customers based on demographics
    demographic_groups = {
        col: defaultdict(list) for col in demographic_columns
    }
    for customer_id, demographics in customer_demographics.items():
        for col in demographic_columns:
            group_value = demographics.get(col, "Unknown")
            demographic_groups[col][group_value].append(customer_id)

    # Calculate variance per group per category
    for col, groups in demographic_groups.items():
        for group_value, customers in groups.items():
            group_key = f"{col}_{group_value}"
            for category in product_categories:
                ratings = [
                    rating
                    for customer in customers
                    for cat, rating in top_5_recommendations.get(customer, [])
                    if cat == category
                ]
                variance = np.var(ratings) if ratings else 0.0
                count = len(ratings)

                group_stats[group_key][category] = {
                    "variance": variance,
                    "count": count
                }

    return group_stats

# %%
def analyze_group_variances(group_stats):
    """
    Computes the average variance across all categories for each demographic group and sorts groups by average variance.

    Parameters:
        group_stats (dict):
            Output dictionary from `calculate_group_variances`.

    Returns:
        list[tuple]: Sorted list of groups based on average variance.
            Format: [(group_key, {'avg_variance': float, 'total_count': int}), ...]
    """
    group_analysis = []

    for group_key, category_stats in group_stats.items():
        variances = [stats['variance'] for stats in category_stats.values()]
        total_count = sum(stats['count'] for stats in category_stats.values())
        avg_variance = np.mean(variances) if variances else 0.0

        group_analysis.append(
            (group_key, {"avg_variance": avg_variance, "total_count": total_count})
        )

    # Sort groups descendingly by average variance
    sorted_groups = sorted(
        group_analysis,
        key=lambda x: x[1]["avg_variance"],
        reverse=True
    )

    return sorted_groups

# %%
# Calculate variances for demographic groups (SVD++)
svd_group_stats = calculate_group_variances(
    svd_top_5_recs,
    customer_demographics,
    ['gender', 'age_group', 'income_level', 'education_level', 'occupation', 'marital_status'],
    list(user_item_matrix.index)
)

# Analyze and sort groups
sorted_svd_groups = analyze_group_variances(svd_group_stats)

# Display results clearly
print("Groups with Highest Average Variance (SVD++ Recommendations)")
print("=" * 65)
for group, stats in sorted_svd_groups:
    print(f"Group: {group}")
    print(f"Average Variance:  {stats['avg_variance']:.2f}")
    print(f"Total Predictions: {stats['total_count']}")
    print("-" * 50)
# Out:
# Groups with Highest Average Variance (SVD++ Recommendations)
# =================================================================
# Group: occupation_Middle
# Average Variance:  0.01
# Total Predictions: 2415
# --------------------------------------------------
# Group: marital_status_Single
# Average Variance:  0.01
# Total Predictions: 1210
# --------------------------------------------------
# Group: gender_Male
# Average Variance:  0.01
# Total Predictions: 2245
# --------------------------------------------------
# Group: income_level_Middle
# Average Variance:  0.01
# Total Predictions: 2425
# --------------------------------------------------
# Group: income_level_High
# Average Variance:  0.01
# Total Predictions: 2575
# --------------------------------------------------
# Group: age_group_36–40
# Average Variance:  0.01
# Total Predictions: 835
# --------------------------------------------------
# Group: education_level_Bachelor's
# Average Variance:  0.01
# Total Predictions: 1705
# --------------------------------------------------
# Group: education_level_Master's
# Average Variance:  0.01
# Total Predictions: 1640
# --------------------------------------------------
# Group: marital_status_Married
# Average Variance:  0.01
# Total Predictions: 1265
# --------------------------------------------------
# Group: occupation_High
# Average Variance:  0.01
# Total Predictions: 2585
# --------------------------------------------------
# Group: gender_Female
# Average Variance:  0.01
# Total Predictions: 2260
# --------------------------------------------------
# Group: education_level_High School
# Average Variance:  0.01
# Total Predictions: 1655
# --------------------------------------------------
# Group: age_group_31–35
# Average Variance:  0.01
# Total Predictions: 715
# --------------------------------------------------
# Group: marital_status_Widowed
# Average Variance:  0.01
# Total Predictions: 1300
# --------------------------------------------------
# Group: age_group_46–50
# Average Variance:  0.01
# Total Predictions: 750
# --------------------------------------------------
# Group: marital_status_Divorced
# Average Variance:  0.01
# Total Predictions: 1225
# --------------------------------------------------
# Group: age_group_26–30
# Average Variance:  0.01
# Total Predictions: 825
# --------------------------------------------------
# Group: age_group_18–25
# Average Variance:  0.01
# Total Predictions: 1110
# --------------------------------------------------
# Group: age_group_41–45
# Average Variance:  0.01
# Total Predictions: 765
# --------------------------------------------------
# Group: gender_Agender
# Average Variance:  0.01
# Total Predictions: 95
# --------------------------------------------------
# Group: gender_Genderfluid
# Average Variance:  0.00
# Total Predictions: 85
# --------------------------------------------------
# Group: gender_Bigender
# Average Variance:  0.00
# Total Predictions: 100
# --------------------------------------------------
# Group: gender_Polygender
# Average Variance:  0.00
# Total Predictions: 75
# --------------------------------------------------
# Group: gender_Non-binary
# Average Variance:  0.00
# Total Predictions: 80
# --------------------------------------------------
# Group: gender_Genderqueer
# Average Variance:  0.00
# Total Predictions: 60
# --------------------------------------------------

# %%
# Calculate variances for demographic groups (Item-KNN)
knn_group_stats = calculate_group_variances(
    knn_top_5_recs,
    customer_demographics,
    ['gender', 'age_group', 'income_level', 'education_level', 'occupation', 'marital_status'],
    list(user_item_matrix.index)
)

# Analyze and sort groups
sorted_knn_groups = analyze_group_variances(knn_group_stats)

# Display results clearly
print("\nGroups with Highest Average Variance (Item-KNN Recommendations)")
print("=" * 65)
for group, stats in sorted_knn_groups:
    print(f"Group: {group}")
    print(f"Average Variance:  {stats['avg_variance']:.2f}")
    print(f"Total Predictions: {stats['total_count']}")
    print("-" * 50)
# Out:
# Groups with Highest Average Variance (Item-KNN Recommendations)
# =================================================================
# Group: gender_Female
# Average Variance:  0.97
# Total Predictions: 360
# --------------------------------------------------
# Group: occupation_Middle
# Average Variance:  0.97
# Total Predictions: 359
# --------------------------------------------------
# Group: education_level_Master's
# Average Variance:  0.95
# Total Predictions: 225
# --------------------------------------------------
# Group: marital_status_Widowed
# Average Variance:  0.95
# Total Predictions: 176
# --------------------------------------------------
# Group: occupation_High
# Average Variance:  0.94
# Total Predictions: 371
# --------------------------------------------------
# Group: income_level_High
# Average Variance:  0.93
# Total Predictions: 396
# --------------------------------------------------
# Group: education_level_High School
# Average Variance:  0.92
# Total Predictions: 229
# --------------------------------------------------
# Group: income_level_Middle
# Average Variance:  0.91
# Total Predictions: 334
# --------------------------------------------------
# Group: marital_status_Single
# Average Variance:  0.87
# Total Predictions: 143
# --------------------------------------------------
# Group: gender_Male
# Average Variance:  0.87
# Total Predictions: 301
# --------------------------------------------------
# Group: education_level_Bachelor's
# Average Variance:  0.85
# Total Predictions: 276
# --------------------------------------------------
# Group: age_group_41–45
# Average Variance:  0.81
# Total Predictions: 97
# --------------------------------------------------
# Group: marital_status_Divorced
# Average Variance:  0.79
# Total Predictions: 206
# --------------------------------------------------
# Group: marital_status_Married
# Average Variance:  0.75
# Total Predictions: 205
# --------------------------------------------------
# Group: age_group_26–30
# Average Variance:  0.72
# Total Predictions: 83
# --------------------------------------------------
# Group: age_group_18–25
# Average Variance:  0.70
# Total Predictions: 182
# --------------------------------------------------
# Group: age_group_36–40
# Average Variance:  0.69
# Total Predictions: 124
# --------------------------------------------------
# Group: age_group_46–50
# Average Variance:  0.68
# Total Predictions: 133
# --------------------------------------------------
# Group: age_group_31–35
# Average Variance:  0.67
# Total Predictions: 111
# --------------------------------------------------
# Group: gender_Non-binary
# Average Variance:  0.22
# Total Predictions: 8
# --------------------------------------------------
# Group: gender_Genderfluid
# Average Variance:  0.08
# Total Predictions: 15
# --------------------------------------------------
# Group: gender_Bigender
# Average Variance:  0.02
# Total Predictions: 14
# --------------------------------------------------
# Group: gender_Polygender
# Average Variance:  0.00
# Total Predictions: 8
# --------------------------------------------------
# Group: gender_Agender
# Average Variance:  0.00
# Total Predictions: 10
# --------------------------------------------------
# Group: gender_Genderqueer
# Average Variance:  0.00
# Total Predictions: 14
# --------------------------------------------------

# %%
# --- Convert your group-level variance data to DataFrames ---
svd_group_df = pd.DataFrame([
    {'Group': g, 'Avg_Variance': stats['avg_variance'], 'Total_Predictions': stats['total_count']}
    for g, stats in sorted_svd_groups
])

knn_group_df = pd.DataFrame([
    {'Group': g, 'Avg_Variance': stats['avg_variance'], 'Total_Predictions': stats['total_count']}
    for g, stats in sorted_knn_groups
])

# Add a column to distinguish between models
svd_group_df['Model'] = 'SVD++'
knn_group_df['Model'] = 'Item-KNN'

# Combine DataFrames for visualization
combined_group_df = pd.concat([svd_group_df, knn_group_df])

# --- Visualize group-level fairness with a bar plot ---
plt.figure(figsize=(14, 7))
sns.barplot(
    data=combined_group_df,
    x='Group',
    y='Avg_Variance',
    hue='Model'
)

# Customize plot
plt.title('Group-level Fairness Comparison (Average Variance)', fontsize=16)
plt.xlabel('Demographic Group', fontsize=14)
plt.ylabel('Average Variance', fontsize=14)
plt.xticks(rotation=75)
plt.legend(title='Recommender Model')
plt.tight_layout()

# Show the plot
plt.show()

# %%
print("\nGroups with Highest Variance (Top 10):")
print("SVD++ model:")
print(svd_group_df.sort_values(by='Avg_Variance', ascending=False).head(10))

print("\nItem-KNN model:")
print(knn_group_df.sort_values(by='Avg_Variance', ascending=False).head(10))
# Out:
# Groups with Highest Variance (Top 10):
# SVD++ model:
#                         Group  Avg_Variance  Total_Predictions  Model
# 0           occupation_Middle      0.011009               2415  SVD++
# 1       marital_status_Single      0.010916               1210  SVD++
# 2                 gender_Male      0.010742               2245  SVD++
# 3         income_level_Middle      0.010595               2425  SVD++
# 4           income_level_High      0.010120               2575  SVD++
# 5             age_group_36–40      0.010040                835  SVD++
# 6  education_level_Bachelor's      0.009959               1705  SVD++
# 7    education_level_Master's      0.009943               1640  SVD++
# 8      marital_status_Married      0.009663               1265  SVD++
# 9             occupation_High      0.009590               2585  SVD++
#
# Item-KNN model:
#                          Group  Avg_Variance  Total_Predictions     Model
# 0                gender_Female      0.968629                360  Item-KNN
# 1            occupation_Middle      0.967023                359  Item-KNN
# 2     education_level_Master's      0.952045                225  Item-KNN
# 3       marital_status_Widowed      0.945799                176  Item-KNN
# 4              occupation_High      0.943236                371  Item-KNN
# 5            income_level_High      0.933443                396  Item-KNN
# 6  education_level_High School      0.923881                229  Item-KNN
# 7          income_level_Middle      0.910406                334  Item-KNN
# 8        marital_status_Single      0.871959                143  Item-KNN
# 9                  gender_Male      0.866596                301  Item-KNN

# %%
# Convert variance dictionaries into DataFrames
svd_var_df = pd.DataFrame([
    {'Group': group, 'Model': 'SVD++', 'Variance': stats['avg_variance']}
    for group, stats in sorted_svd_groups
])

knn_var_df = pd.DataFrame([
    {'Group': group, 'Model': 'Item-KNN', 'Variance': stats['avg_variance']}
    for group, stats in sorted_knn_groups
])

# Combine into a single DataFrame
variance_df = pd.concat([svd_var_df, knn_var_df])

# Optional: Filter out groups with zero variance (usually due to no predictions)
variance_df = variance_df[variance_df['Variance'] > 0]

# Split group name into demographic type and value
variance_df[['Demographic', 'Value']] = variance_df['Group'].str.split('_', n=1, expand=True)

# Create one heatmap per demographic type
for demo_col in variance_df['Demographic'].unique():
    demo_data = variance_df[variance_df['Demographic'] == demo_col]
    heatmap_data = demo_data.pivot(index='Value', columns='Model', values='Variance')

    plt.figure(figsize=(6, max(4, len(heatmap_data) * 0.5)))
    sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt=".2f", cbar_kws={'label': 'Average Variance'})
    plt.title(f"Group-Level Variance Heatmap ({demo_col.capitalize()})")
    plt.xlabel("Model")
    plt.ylabel(f"{demo_col.capitalize()} Group")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ---
# **2) Mean Average Envy (MAE) for Group Fairness:**
# ---
# Measuring fairness relative to peers in the same group.

# %%
def calculate_group_envy(top_5_recommendations, customer_demographics, demographic_columns, product_categories):
    """
    Calculates total envy scores for each demographic group and each product category.
    Envy is computed by summing positive rating differences within customer pairs in the same demographic group.

    Parameters:
        top_5_recommendations (dict):
            Dictionary mapping customer IDs to lists of tuples (category, predicted_rating).
        customer_demographics (dict):
            Dictionary mapping customer IDs to their demographic attributes.
        demographic_columns (list[str]):
            List of demographic attributes to group by (e.g., ['gender', 'age_group']).
        product_categories (list[str]):
            List of product categories.

    Returns:
        dict: Nested dictionary of total envy values structured as:
            { 'demographic_group': { 'category': total_envy_value, ... }, ... }
    """
    group_envy = defaultdict(lambda: defaultdict(float))

    # Group customers by demographics
    demographic_groups = {col: defaultdict(list) for col in demographic_columns}
    for customer_id, demographics in customer_demographics.items():
        for col in demographic_columns:
            group_value = demographics.get(col, "Unknown")
            demographic_groups[col][group_value].append(customer_id)

    # Calculate envy within each demographic group
    for col, groups in demographic_groups.items():
        for group_value, customers in groups.items():
            group_key = f"{col}_{group_value}"
            for idx_i, customer_i in enumerate(customers):
                recs_i = top_5_recommendations.get(customer_i, [])
                for customer_j in customers[idx_i + 1:]:
                    recs_j = top_5_recommendations.get(customer_j, [])
                    # Compare ratings for the same categories
                    for cat_i, rating_i in recs_i:
                        for cat_j, rating_j in recs_j:
                            if cat_i == cat_j:
                                envy_ij = max(rating_j - rating_i, 0)
                                envy_ji = max(rating_i - rating_j, 0)
                                group_envy[group_key][cat_i] += envy_ij + envy_ji
    return group_envy

# %% [markdown]
# Total envy for SVD++ model:

# %%
svd_group_envy_values = calculate_group_envy(
    svd_top_5_recs, 
    customer_demographics, 
    ['gender', 'age_group', 'income_level', 'education_level', 'occupation', 'marital_status'], 
    list(user_item_matrix.index)
)

# Display envy results for SVD++
for group, categories_envy in svd_group_envy_values.items():
    print(f"\nTotal Envy for SVD++ {group}:")
    for category, total_envy in categories_envy.items():
        print(f"  {category}: {total_envy:.2f}")
# Out:
# Total Envy for SVD++ gender_Female:
#   Baby Products: 6193.41
#   Travel & Leisure (Flights: 6867.70
#   Toys & Games: 11504.09
#   Hotels: 7564.46
#   Clothing: 398.04
#   Luxury Goods: 518.55
#   Office Supplies: 37.98
#   Electronics: 517.79
#   Software & Apps: 2684.02
#   Furniture: 152.62
#   Beauty & Personal Care: 129.57
#   Sports & Outdoors: 25.67
#   Mobile Accessories: 485.90
#   Packages): 101.60
#   Home Appliances: 7.73
#   Arts & Crafts: 5.97
#   Animal Feed: 12.11
#   Health Supplements: 5.13
#   Health Care: 2.94
#   Groceries: 0.05
#
# Total Envy for SVD++ gender_Male:
#   Toys & Games: 10687.90
#   Baby Products: 5751.36
#   Hotels: 7872.87
#   Mobile Accessories: 523.40
#   Electronics: 400.49
#   Travel & Leisure (Flights: 6477.51
#   Clothing: 277.37
#   Furniture: 182.00
#   Books: 0.47
#   Software & Apps: 2969.33
#   Health Supplements: 4.99
#   Animal Feed: 8.48
#   Health Care: 9.16
#   Luxury Goods: 442.24
#   Packages): 112.63
#   Sports & Outdoors: 18.31
#   Groceries: 0.53
#   Beauty & Personal Care: 203.14
#   Arts & Crafts: 5.62
#   Office Supplies: 38.35
#   Home Appliances: 13.64
#   Food & Beverages: 0.26
#   Jewelry & Accessories: 0.08
#
# Total Envy for SVD++ gender_Bigender:
#   Baby Products: 17.16
#   Toys & Games: 12.65
#   Software & Apps: 2.25
#   Travel & Leisure (Flights: 9.23
#   Electronics: 0.59
#   Hotels: 13.20
#   Luxury Goods: 1.70
#   Packages): 0.24
#   Beauty & Personal Care: 0.26
#   Sports & Outdoors: 0.37
#   Office Supplies: 0.27
#   Clothing: 0.09
#
# Total Envy for SVD++ gender_Genderfluid:
#   Toys & Games: 25.68
#   Hotels: 9.92
#   Clothing: 1.46
#   Furniture: 0.38
#   Software & Apps: 1.84
#   Luxury Goods: 1.71
#   Mobile Accessories: 0.22
#   Travel & Leisure (Flights: 4.61
#   Baby Products: 5.99
#   Beauty & Personal Care: 0.72
#   Office Supplies: 0.14
#
# Total Envy for SVD++ gender_Non-binary:
#   Baby Products: 13.06
#   Toys & Games: 10.87
#   Hotels: 7.94
#   Packages): 0.93
#   Clothing: 0.80
#   Travel & Leisure (Flights: 8.60
#   Mobile Accessories: 0.05
#   Beauty & Personal Care: 0.12
#   Software & Apps: 1.27
#
# Total Envy for SVD++ gender_Polygender:
#   Hotels: 6.43
#   Toys & Games: 8.44
#   Software & Apps: 7.66
#   Furniture: 0.02
#   Travel & Leisure (Flights: 6.77
#   Health Supplements: 0.03
#   Baby Products: 2.74
#   Beauty & Personal Care: 0.64
#   Office Supplies: 0.11
#   Mobile Accessories: 0.14
#   Luxury Goods: 0.24
#   Clothing: 0.17
#
# Total Envy for SVD++ gender_Agender:
#   Toys & Games: 17.47
#   Hotels: 23.28
#   Electronics: 1.21
#   Travel & Leisure (Flights: 11.35
#   Baby Products: 7.31
#   Furniture: 0.68
#   Clothing: 0.07
#   Office Supplies: 0.12
#   Software & Apps: 7.63
#   Mobile Accessories: 0.20
#   Luxury Goods: 0.19
#   Health Supplements: 0.28
#
# Total Envy for SVD++ gender_Genderqueer:
#   Toys & Games: 9.65
#   Hotels: 5.90
#   Luxury Goods: 1.07
#   Travel & Leisure (Flights: 6.47
#   Baby Products: 2.16
#   Software & Apps: 0.07
#   Mobile Accessories: 0.12
#   Clothing: 0.09
#
# Total Envy for SVD++ age_group_18–25:
#   Baby Products: 1539.98
#   Travel & Leisure (Flights: 1461.10
#   Toys & Games: 2865.49
#   Hotels: 1877.41
#   Clothing: 69.70
#   Luxury Goods: 184.87
#   Office Supplies: 8.92
#   Furniture: 39.39
#   Beauty & Personal Care: 37.21
#   Electronics: 76.29
#   Software & Apps: 767.07
#   Mobile Accessories: 69.83
#   Packages): 39.46
#   Home Appliances: 2.46
#   Sports & Outdoors: 6.78
#   Animal Feed: 1.77
#   Health Supplements: 3.99
#   Health Care: 0.00
#   Arts & Crafts: 0.35
#
# Total Envy for SVD++ age_group_46–50:
#   Toys & Games: 1171.04
#   Mobile Accessories: 79.35
#   Electronics: 47.34
#   Hotels: 722.45
#   Baby Products: 675.17
#   Travel & Leisure (Flights: 817.82
#   Luxury Goods: 20.61
#   Software & Apps: 332.63
#   Packages): 12.15
#   Beauty & Personal Care: 25.83
#   Office Supplies: 0.03
#   Clothing: 21.70
#   Animal Feed: 1.48
#   Home Appliances: 0.83
#   Sports & Outdoors: 1.60
#   Health Supplements: 0.31
#   Furniture: 15.95
#   Health Care: 0.68
#
# Total Envy for SVD++ age_group_26–30:
#   Toys & Games: 1435.54
#   Hotels: 1100.94
#   Travel & Leisure (Flights: 951.61
#   Software & Apps: 291.33
#   Electronics: 48.33
#   Furniture: 27.12
#   Sports & Outdoors: 0.14
#   Baby Products: 744.01
#   Luxury Goods: 46.03
#   Clothing: 62.03
#   Mobile Accessories: 92.51
#   Packages): 10.67
#   Arts & Crafts: 2.37
#   Health Supplements: 0.07
#   Office Supplies: 9.36
#   Beauty & Personal Care: 17.83
#   Animal Feed: 0.94
#   Health Care: 0.63
#   Home Appliances: 0.70
#
# Total Envy for SVD++ age_group_31–35:
#   Baby Products: 640.25
#   Toys & Games: 1012.88
#   Hotels: 900.99
#   Beauty & Personal Care: 11.85
#   Furniture: 25.80
#   Electronics: 34.71
#   Software & Apps: 327.38
#   Mobile Accessories: 21.36
#   Travel & Leisure (Flights: 603.57
#   Animal Feed: 3.22
#   Health Supplements: 1.12
#   Luxury Goods: 21.45
#   Groceries: 0.53
#   Health Care: 0.39
#   Clothing: 27.98
#   Office Supplies: 6.36
#   Arts & Crafts: 5.25
#   Packages): 2.74
#   Sports & Outdoors: 1.35
#   Home Appliances: 0.10
#   Jewelry & Accessories: 0.08
#
# Total Envy for SVD++ age_group_41–45:
#   Travel & Leisure (Flights: 655.38
#   Clothing: 46.17
#   Toys & Games: 1218.43
#   Baby Products: 627.82
#   Furniture: 11.55
#   Luxury Goods: 129.43
#   Software & Apps: 342.89
#   Hotels: 796.34
#   Electronics: 38.41
#   Packages): 15.27
#   Mobile Accessories: 38.56
#   Beauty & Personal Care: 13.13
#   Sports & Outdoors: 3.54
#   Home Appliances: 3.24
#   Office Supplies: 4.69
#   Animal Feed: 0.36
#   Health Supplements: 0.45
#   Food & Beverages: 0.09
#
# Total Envy for SVD++ age_group_36–40:
#   Toys & Games: 1657.64
#   Hotels: 1122.20
#   Travel & Leisure (Flights: 997.70
#   Baby Products: 766.38
#   Books: 0.45
#   Electronics: 95.76
#   Luxury Goods: 58.18
#   Sports & Outdoors: 8.50
#   Clothing: 56.67
#   Software & Apps: 294.79
#   Furniture: 13.78
#   Health Care: 2.39
#   Mobile Accessories: 84.46
#   Packages): 14.51
#   Beauty & Personal Care: 34.62
#   Office Supplies: 6.88
#   Health Supplements: 0.82
#   Home Appliances: 1.01
#   Animal Feed: 1.55
#   Arts & Crafts: 0.18
#
# Total Envy for SVD++ income_level_Middle:
#   Baby Products: 7543.70
#   Travel & Leisure (Flights: 8498.15
#   Toys & Games: 13763.07
#   Hotels: 8569.37
#   Clothing: 396.83
#   Luxury Goods: 650.12
#   Office Supplies: 43.74
#   Electronics: 393.62
#   Software & Apps: 2921.72
#   Furniture: 231.64
#   Beauty & Personal Care: 203.19
#   Books: 0.23
#   Mobile Accessories: 529.49
#   Packages): 94.42
#   Home Appliances: 9.57
#   Arts & Crafts: 16.78
#   Animal Feed: 7.72
#   Health Supplements: 11.26
#   Sports & Outdoors: 28.33
#   Health Care: 2.58
#   Jewelry & Accessories: 0.06
#   Food & Beverages: 0.13
#
# Total Envy for SVD++ income_level_High:
#   Toys & Games: 13396.78
#   Hotels: 10673.98
#   Baby Products: 7020.58
#   Electronics: 637.45
#   Mobile Accessories: 593.37
#   Travel & Leisure (Flights: 7811.92
#   Luxury Goods: 531.81
#   Software & Apps: 4030.35
#   Sports & Outdoors: 29.02
#   Animal Feed: 23.49
#   Health Supplements: 9.54
#   Furniture: 171.98
#   Clothing: 428.49
#   Health Care: 12.26
#   Packages): 161.55
#   Beauty & Personal Care: 215.35
#   Books: 0.22
#   Office Supplies: 57.40
#   Home Appliances: 15.21
#   Arts & Crafts: 2.93
#   Food & Beverages: 0.08
#   Groceries: 1.60
#
# Total Envy for SVD++ education_level_Bachelor's:
#   Baby Products: 3651.05
#   Travel & Leisure (Flights: 3561.92
#   Toys & Games: 6350.44
#   Hotels: 4729.16
#   Clothing: 165.50
#   Electronics: 315.36
#   Software & Apps: 1336.40
#   Mobile Accessories: 294.14
#   Luxury Goods: 232.86
#   Sports & Outdoors: 29.34
#   Furniture: 84.11
#   Health Care: 3.92
#   Packages): 53.95
#   Beauty & Personal Care: 87.19
#   Books: 0.02
#   Groceries: 0.71
#   Office Supplies: 10.50
#   Animal Feed: 3.25
#   Arts & Crafts: 5.85
#   Home Appliances: 5.29
#   Health Supplements: 3.63
#   Food & Beverages: 0.13
#
# Total Envy for SVD++ education_level_High School:
#   Toys & Games: 5748.08
#   Hotels: 3947.94
#   Baby Products: 3295.97
#   Electronics: 122.59
#   Mobile Accessories: 203.37
#   Furniture: 82.18
#   Beauty & Personal Care: 102.33
#   Travel & Leisure (Flights: 3354.98
#   Books: 0.01
#   Software & Apps: 1595.43
#   Animal Feed: 9.16
#   Health Supplements: 7.77
#   Sports & Outdoors: 1.78
#   Luxury Goods: 347.94
#   Clothing: 188.69
#   Home Appliances: 5.07
#   Arts & Crafts: 2.04
#   Packages): 55.74
#   Office Supplies: 26.91
#   Health Care: 0.33
#   Food & Beverages: 0.08
#
# Total Envy for SVD++ education_level_Master's:
#   Toys & Games: 6054.19
#   Travel & Leisure (Flights: 3957.04
#   Baby Products: 2833.81
#   Luxury Goods: 218.08
#   Office Supplies: 31.07
#   Hotels: 4103.30
#   Electronics: 263.26
#   Software & Apps: 1641.30
#   Clothing: 188.45
#   Furniture: 99.72
#   Mobile Accessories: 249.68
#   Beauty & Personal Care: 89.20
#   Packages): 61.72
#   Health Care: 5.49
#   Health Supplements: 2.72
#   Arts & Crafts: 3.29
#   Sports & Outdoors: 14.55
#   Animal Feed: 4.98
#   Home Appliances: 5.00
#   Groceries: 0.31
#
# Total Envy for SVD++ occupation_Middle:
#   Travel & Leisure (Flights: 7273.76
#   Hotels: 8789.13
#   Toys & Games: 12495.29
#   Baby Products: 6959.94
#   Clothing: 548.52
#   Electronics: 457.38
#   Software & Apps: 2941.38
#   Furniture: 173.62
#   Beauty & Personal Care: 196.46
#   Books: 0.43
#   Luxury Goods: 486.50
#   Mobile Accessories: 607.93
#   Sports & Outdoors: 36.71
#   Animal Feed: 15.33
#   Health Supplements: 8.13
#   Packages): 175.59
#   Office Supplies: 53.76
#   Arts & Crafts: 9.86
#   Home Appliances: 8.80
#   Health Care: 2.46
#   Food & Beverages: 0.02
#   Jewelry & Accessories: 0.08
#   Groceries: 0.23
#
# Total Envy for SVD++ occupation_High:
#   Toys & Games: 14818.09
#   Baby Products: 7685.17
#   Electronics: 566.14
#   Hotels: 10445.22
#   Mobile Accessories: 513.17
#   Travel & Leisure (Flights: 9057.75
#   Luxury Goods: 725.59
#   Office Supplies: 45.99
#   Furniture: 229.59
#   Clothing: 291.90
#   Software & Apps: 3991.42
#   Sports & Outdoors: 20.40
#   Health Care: 11.71
#   Groceries: 1.22
#   Packages): 94.11
#   Home Appliances: 16.16
#   Arts & Crafts: 7.26
#   Animal Feed: 13.40
#   Beauty & Personal Care: 224.29
#   Health Supplements: 13.32
#   Food & Beverages: 0.03
#
# Total Envy for SVD++ marital_status_Married:
#   Baby Products: 2078.89
#   Hotels: 2633.45
#   Toys & Games: 3855.48
#   Travel & Leisure (Flights: 1988.58
#   Clothing: 102.63
#   Electronics: 147.07
#   Mobile Accessories: 159.11
#   Furniture: 36.57
#   Software & Apps: 977.46
#   Animal Feed: 3.81
#   Health Supplements: 2.51
#   Packages): 13.28
#   Beauty & Personal Care: 57.92
#   Luxury Goods: 161.27
#   Books: 0.02
#   Office Supplies: 6.61
#   Arts & Crafts: 2.40
#   Sports & Outdoors: 1.68
#   Home Appliances: 3.92
#   Health Care: 0.07
#
# Total Envy for SVD++ marital_status_Single:
#   Toys & Games: 3064.72
#   Travel & Leisure (Flights: 2322.22
#   Baby Products: 1559.92
#   Luxury Goods: 91.11
#   Office Supplies: 13.50
#   Hotels: 2149.91
#   Electronics: 111.39
#   Software & Apps: 932.32
#   Books: 0.01
#   Mobile Accessories: 118.57
#   Health Care: 3.51
#   Clothing: 89.04
#   Furniture: 56.40
#   Beauty & Personal Care: 57.23
#   Packages): 33.93
#   Home Appliances: 2.99
#   Animal Feed: 3.50
#   Sports & Outdoors: 9.30
#   Arts & Crafts: 0.45
#   Health Supplements: 1.38
#   Food & Beverages: 0.02
#
# Total Envy for SVD++ marital_status_Widowed:
#   Toys & Games: 3550.54
#   Hotels: 2450.05
#   Furniture: 48.97
#   Baby Products: 1817.59
#   Beauty & Personal Care: 36.18
#   Sports & Outdoors: 16.78
#   Luxury Goods: 254.90
#   Electronics: 124.95
#   Travel & Leisure (Flights: 1898.35
#   Software & Apps: 827.05
#   Mobile Accessories: 158.03
#   Clothing: 97.41
#   Packages): 64.30
#   Office Supplies: 22.90
#   Home Appliances: 3.55
#   Arts & Crafts: 4.31
#   Health Supplements: 2.36
#   Animal Feed: 4.65
#   Health Care: 1.47
#
# Total Envy for SVD++ marital_status_Divorced:
#   Baby Products: 1877.89
#   Toys & Games: 3165.20
#   Hotels: 2352.43
#   Beauty & Personal Care: 54.04
#   Furniture: 55.52
#   Travel & Leisure (Flights: 1930.71
#   Luxury Goods: 111.58
#   Electronics: 118.97
#   Mobile Accessories: 123.10
#   Software & Apps: 707.02
#   Clothing: 118.36
#   Packages): 29.23
#   Sports & Outdoors: 4.02
#   Animal Feed: 0.79
#   Office Supplies: 8.18
#   Health Supplements: 3.18
#   Health Care: 2.07
#   Food & Beverages: 0.03
#   Home Appliances: 1.18
#   Groceries: 0.31
#   Arts & Crafts: 0.92
#   Jewelry & Accessories: 0.08

# %% [markdown]
# Total envy for ItemKNN model:

# %%
knn_group_envy_values = calculate_group_envy(
    knn_top_5_recs, 
    customer_demographics, 
    ['gender', 'age_group', 'income_level', 'education_level', 'occupation', 'marital_status'], 
    list(user_item_matrix.index)
)

# Display envy results for Item-KNN
for group, categories_envy in knn_group_envy_values.items():
    print(f"\nTotal Envy for Item-KNN {group}:")
    for category, total_envy in categories_envy.items():
        print(f"  {category}: {total_envy:.2f}")
# Out:
# Total Envy for Item-KNN gender_Female:
#   Software & Apps: 162.50
#   Food & Beverages: 218.20
#   Baby Products: 95.80
#   Office Supplies: 31.10
#   Mobile Accessories: 194.65
#   Electronics: 286.90
#   Furniture: 162.55
#   Home Appliances: 179.30
#   Hotels: 68.80
#   Toys & Games: 169.70
#   Books: 48.80
#   Luxury Goods: 73.70
#   Travel & Leisure (Flights: 125.75
#   Sports & Outdoors: 124.00
#   Health Supplements: 22.90
#   Clothing: 71.20
#   Health Care: 103.80
#   Packages): 216.20
#   Groceries: 170.60
#   Gardening & Outdoors: 86.80
#   Jewelry & Accessories: 187.50
#   Animal Feed: 136.80
#   Arts & Crafts: 91.75
#   Beauty & Personal Care: 15.65
#
# Total Envy for Item-KNN gender_Male:
#   Software & Apps: 58.15
#   Luxury Goods: 22.40
#   Electronics: 64.00
#   Toys & Games: 392.20
#   Health Care: 39.20
#   Furniture: 57.00
#   Mobile Accessories: 63.80
#   Packages): 145.10
#   Jewelry & Accessories: 49.55
#   Baby Products: 99.80
#   Office Supplies: 110.80
#   Groceries: 76.40
#   Animal Feed: 192.90
#   Gardening & Outdoors: 54.15
#   Hotels: 99.60
#   Home Appliances: 165.00
#   Food & Beverages: 23.20
#   Health Supplements: 64.00
#   Clothing: 65.00
#   Sports & Outdoors: 127.20
#   Arts & Crafts: 84.20
#   Beauty & Personal Care: 28.20
#   Travel & Leisure (Flights: 18.50
#   Books: 62.75
#
# Total Envy for Item-KNN gender_Bigender:
#   Baby Products: 0.00
#   Office Supplies: 1.30
#   Electronics: 0.40
#
# Total Envy for Item-KNN gender_Genderfluid:
#   Health Supplements: 2.60
#   Luxury Goods: 0.90
#   Clothing: 0.40
#   Sports & Outdoors: 0.40
#
# Total Envy for Item-KNN gender_Non-binary:
#   Gardening & Outdoors: 1.60
#   Packages): 0.00
#   Travel & Leisure (Flights: 4.30
#
# Total Envy for Item-KNN gender_Polygender:
#   Luxury Goods: 0.40
#
# Total Envy for Item-KNN gender_Agender:
#   Beauty & Personal Care: 0.10
#
# Total Envy for Item-KNN gender_Genderqueer:
#   Hotels: 0.00
#
# Total Envy for Item-KNN age_group_18–25:
#   Software & Apps: 148.95
#   Office Supplies: 10.20
#   Baby Products: 79.80
#   Food & Beverages: 39.00
#   Mobile Accessories: 21.50
#   Electronics: 27.95
#   Hotels: 46.60
#   Toys & Games: 174.50
#   Home Appliances: 62.00
#   Books: 17.30
#   Luxury Goods: 8.80
#   Clothing: 8.10
#   Health Care: 30.80
#   Health Supplements: 9.60
#   Packages): 13.70
#   Groceries: 12.40
#   Sports & Outdoors: 44.50
#   Travel & Leisure (Flights: 40.80
#   Animal Feed: 1.40
#   Gardening & Outdoors: 37.40
#   Furniture: 21.20
#   Arts & Crafts: 1.10
#   Jewelry & Accessories: 0.60
#
# Total Envy for Item-KNN age_group_46–50:
#   Toys & Games: 4.60
#   Baby Products: 6.00
#   Office Supplies: 14.20
#   Groceries: 38.40
#   Luxury Goods: 18.40
#   Mobile Accessories: 38.60
#   Arts & Crafts: 30.00
#   Food & Beverages: 7.80
#   Home Appliances: 30.90
#   Health Supplements: 5.60
#   Furniture: 6.90
#   Beauty & Personal Care: 11.25
#   Electronics: 23.70
#   Packages): 12.40
#   Jewelry & Accessories: 14.10
#   Animal Feed: 66.60
#   Hotels: 12.20
#   Sports & Outdoors: 23.60
#   Travel & Leisure (Flights: 1.10
#   Software & Apps: 3.40
#   Clothing: 2.20
#   Gardening & Outdoors: 0.00
#   Health Care: 5.60
#   Books: 3.00
#
# Total Envy for Item-KNN age_group_26–30:
#   Health Supplements: 2.10
#   Toys & Games: 8.00
#   Hotels: 6.00
#   Luxury Goods: 12.00
#   Packages): 22.20
#   Baby Products: 1.40
#   Arts & Crafts: 19.90
#   Beauty & Personal Care: 0.50
#   Software & Apps: 7.20
#   Health Care: 8.80
#   Gardening & Outdoors: 12.50
#   Books: 6.40
#   Groceries: 0.80
#   Clothing: 4.00
#   Food & Beverages: 1.80
#   Animal Feed: 3.80
#   Furniture: 8.60
#   Office Supplies: 0.80
#   Electronics: 9.80
#   Mobile Accessories: 10.00
#   Jewelry & Accessories: 1.60
#   Home Appliances: 1.40
#
# Total Envy for Item-KNN age_group_31–35:
#   Luxury Goods: 4.50
#   Travel & Leisure (Flights: 14.00
#   Furniture: 2.20
#   Mobile Accessories: 10.40
#   Toys & Games: 39.60
#   Health Care: 3.60
#   Gardening & Outdoors: 11.00
#   Electronics: 6.10
#   Packages): 35.90
#   Baby Products: 1.40
#   Home Appliances: 23.80
#   Hotels: 3.60
#   Arts & Crafts: 12.30
#   Health Supplements: 4.80
#   Animal Feed: 6.00
#   Jewelry & Accessories: 4.10
#   Groceries: 12.10
#   Office Supplies: 20.60
#   Beauty & Personal Care: 7.55
#   Books: 0.50
#   Software & Apps: 1.60
#   Clothing: 4.20
#   Sports & Outdoors: 15.20
#   Food & Beverages: 6.30
#
# Total Envy for Item-KNN age_group_41–45:
#   Food & Beverages: 18.20
#   Gardening & Outdoors: 0.10
#   Home Appliances: 4.00
#   Packages): 12.05
#   Sports & Outdoors: 27.40
#   Books: 6.10
#   Furniture: 11.20
#   Hotels: 1.20
#   Jewelry & Accessories: 7.80
#   Clothing: 19.50
#   Software & Apps: 8.20
#   Animal Feed: 11.60
#   Toys & Games: 6.20
#   Health Supplements: 7.20
#   Travel & Leisure (Flights: 6.20
#   Arts & Crafts: 7.80
#   Beauty & Personal Care: 1.80
#   Baby Products: 4.80
#   Office Supplies: 3.20
#   Electronics: 28.20
#   Health Care: 3.00
#   Groceries: 9.80
#   Luxury Goods: 0.20
#   Mobile Accessories: 0.90
#
# Total Envy for Item-KNN age_group_36–40:
#   Electronics: 22.20
#   Food & Beverages: 3.20
#   Furniture: 37.50
#   Mobile Accessories: 14.90
#   Luxury Goods: 0.90
#   Home Appliances: 9.30
#   Sports & Outdoors: 10.80
#   Packages): 52.00
#   Jewelry & Accessories: 58.00
#   Health Supplements: 8.90
#   Toys & Games: 38.20
#   Groceries: 7.50
#   Baby Products: 18.80
#   Animal Feed: 52.70
#   Gardening & Outdoors: 22.30
#   Health Care: 0.70
#   Hotels: 4.20
#   Office Supplies: 1.20
#   Books: 5.20
#   Beauty & Personal Care: 2.50
#   Clothing: 11.10
#   Travel & Leisure (Flights: 3.50
#
# Total Envy for Item-KNN income_level_Middle:
#   Software & Apps: 148.15
#   Food & Beverages: 73.60
#   Office Supplies: 88.00
#   Baby Products: 60.80
#   Mobile Accessories: 251.20
#   Toys & Games: 314.00
#   Hotels: 115.00
#   Books: 70.35
#   Home Appliances: 94.45
#   Luxury Goods: 76.20
#   Travel & Leisure (Flights: 69.65
#   Electronics: 88.20
#   Furniture: 177.60
#   Health Care: 133.70
#   Packages): 200.90
#   Jewelry & Accessories: 75.10
#   Groceries: 80.00
#   Health Supplements: 27.55
#   Gardening & Outdoors: 126.05
#   Arts & Crafts: 63.90
#   Sports & Outdoors: 109.40
#   Clothing: 115.30
#   Animal Feed: 49.45
#   Beauty & Personal Care: 0.50
#
# Total Envy for Item-KNN income_level_High:
#   Food & Beverages: 155.40
#   Electronics: 332.10
#   Baby Products: 252.80
#   Office Supplies: 79.40
#   Furniture: 99.05
#   Luxury Goods: 52.20
#   Sports & Outdoors: 168.60
#   Home Appliances: 282.10
#   Mobile Accessories: 71.30
#   Clothing: 66.60
#   Health Supplements: 128.30
#   Health Care: 51.60
#   Gardening & Outdoors: 92.70
#   Animal Feed: 386.65
#   Packages): 242.60
#   Toys & Games: 255.00
#   Travel & Leisure (Flights: 101.00
#   Groceries: 175.90
#   Jewelry & Accessories: 153.40
#   Arts & Crafts: 133.95
#   Hotels: 82.00
#   Beauty & Personal Care: 119.90
#   Books: 61.40
#   Software & Apps: 101.40
#
# Total Envy for Item-KNN education_level_Bachelor's:
#   Office Supplies: 52.10
#   Baby Products: 121.80
#   Food & Beverages: 98.60
#   Software & Apps: 32.25
#   Electronics: 150.10
#   Furniture: 88.45
#   Mobile Accessories: 172.90
#   Health Care: 42.40
#   Toys & Games: 207.40
#   Home Appliances: 97.50
#   Sports & Outdoors: 133.70
#   Luxury Goods: 50.60
#   Health Supplements: 63.85
#   Clothing: 33.65
#   Packages): 194.55
#   Jewelry & Accessories: 83.05
#   Groceries: 88.20
#   Gardening & Outdoors: 41.55
#   Books: 11.60
#   Arts & Crafts: 20.40
#   Hotels: 19.20
#   Animal Feed: 28.60
#   Travel & Leisure (Flights: 41.85
#   Beauty & Personal Care: 0.15
#
# Total Envy for Item-KNN education_level_High School:
#   Software & Apps: 40.35
#   Mobile Accessories: 45.30
#   Hotels: 82.90
#   Toys & Games: 90.60
#   Home Appliances: 25.70
#   Books: 59.40
#   Luxury Goods: 25.70
#   Electronics: 38.60
#   Packages): 56.80
#   Food & Beverages: 58.10
#   Animal Feed: 89.85
#   Health Care: 33.20
#   Gardening & Outdoors: 30.50
#   Groceries: 16.30
#   Sports & Outdoors: 27.60
#   Travel & Leisure (Flights: 36.20
#   Clothing: 51.60
#   Arts & Crafts: 60.60
#   Baby Products: 62.20
#   Jewelry & Accessories: 56.20
#   Health Supplements: 28.60
#   Beauty & Personal Care: 8.75
#   Furniture: 49.70
#   Office Supplies: 27.20
#
# Total Envy for Item-KNN education_level_Master's:
#   Luxury Goods: 11.00
#   Travel & Leisure (Flights: 27.60
#   Gardening & Outdoors: 85.00
#   Health Supplements: 7.90
#   Toys & Games: 74.20
#   Hotels: 38.40
#   Home Appliances: 158.55
#   Jewelry & Accessories: 17.00
#   Baby Products: 18.50
#   Office Supplies: 27.60
#   Furniture: 37.30
#   Packages): 62.20
#   Animal Feed: 153.20
#   Arts & Crafts: 50.45
#   Beauty & Personal Care: 48.40
#   Electronics: 73.70
#   Clothing: 31.30
#   Sports & Outdoors: 49.60
#   Software & Apps: 94.20
#   Health Care: 27.70
#   Groceries: 83.60
#   Books: 21.00
#   Food & Beverages: 10.80
#   Mobile Accessories: 13.20
#
# Total Envy for Item-KNN occupation_Middle:
#   Software & Apps: 187.80
#   Food & Beverages: 172.00
#   Baby Products: 138.80
#   Office Supplies: 120.00
#   Mobile Accessories: 187.15
#   Electronics: 220.20
#   Furniture: 103.20
#   Home Appliances: 114.60
#   Toys & Games: 202.00
#   Hotels: 141.10
#   Books: 30.70
#   Luxury Goods: 84.50
#   Travel & Leisure (Flights: 78.40
#   Sports & Outdoors: 175.20
#   Groceries: 104.40
#   Health Supplements: 77.40
#   Jewelry & Accessories: 76.80
#   Packages): 171.70
#   Animal Feed: 139.40
#   Clothing: 80.20
#   Arts & Crafts: 105.10
#   Beauty & Personal Care: 29.15
#   Health Care: 71.20
#   Gardening & Outdoors: 104.00
#
# Total Envy for Item-KNN occupation_High:
#   Electronics: 165.15
#   Food & Beverages: 69.20
#   Baby Products: 142.60
#   Office Supplies: 53.80
#   Software & Apps: 81.40
#   Luxury Goods: 44.60
#   Health Care: 105.40
#   Mobile Accessories: 118.40
#   Furniture: 174.20
#   Toys & Games: 375.50
#   Health Supplements: 57.90
#   Clothing: 95.25
#   Packages): 276.50
#   Jewelry & Accessories: 149.10
#   Hotels: 64.10
#   Gardening & Outdoors: 126.40
#   Groceries: 151.55
#   Animal Feed: 239.70
#   Home Appliances: 284.90
#   Sports & Outdoors: 116.40
#   Books: 109.10
#   Arts & Crafts: 87.00
#   Beauty & Personal Care: 39.90
#   Travel & Leisure (Flights: 82.95
#
# Total Envy for Item-KNN marital_status_Married:
#   Office Supplies: 52.80
#   Baby Products: 39.00
#   Food & Beverages: 89.00
#   Software & Apps: 38.50
#   Electronics: 27.60
#   Luxury Goods: 5.80
#   Health Care: 6.90
#   Health Supplements: 3.60
#   Clothing: 11.20
#   Gardening & Outdoors: 54.40
#   Mobile Accessories: 66.60
#   Furniture: 9.70
#   Packages): 68.80
#   Hotels: 32.60
#   Home Appliances: 103.80
#   Arts & Crafts: 45.00
#   Toys & Games: 125.60
#   Animal Feed: 81.10
#   Sports & Outdoors: 40.60
#   Jewelry & Accessories: 35.00
#   Books: 36.95
#   Travel & Leisure (Flights: 1.20
#   Beauty & Personal Care: 6.90
#   Groceries: 13.80
#
# Total Envy for Item-KNN marital_status_Single:
#   Luxury Goods: 2.60
#   Travel & Leisure (Flights: 17.80
#   Toys & Games: 43.20
#   Mobile Accessories: 41.50
#   Health Care: 21.00
#   Furniture: 24.40
#   Food & Beverages: 13.60
#   Groceries: 9.60
#   Health Supplements: 53.20
#   Electronics: 12.60
#   Home Appliances: 29.00
#   Animal Feed: 19.30
#   Clothing: 4.40
#   Baby Products: 52.90
#   Sports & Outdoors: 29.40
#   Arts & Crafts: 17.00
#   Beauty & Personal Care: 1.10
#   Packages): 22.50
#   Hotels: 6.60
#   Office Supplies: 23.90
#   Books: 6.20
#   Gardening & Outdoors: 9.80
#   Software & Apps: 2.00
#   Jewelry & Accessories: 6.20
#
# Total Envy for Item-KNN marital_status_Widowed:
#   Food & Beverages: 14.10
#   Furniture: 76.80
#   Electronics: 76.10
#   Home Appliances: 39.85
#   Hotels: 20.10
#   Toys & Games: 85.10
#   Books: 12.10
#   Mobile Accessories: 30.30
#   Luxury Goods: 27.00
#   Sports & Outdoors: 30.30
#   Packages): 34.20
#   Health Supplements: 7.60
#   Arts & Crafts: 21.00
#   Beauty & Personal Care: 11.30
#   Baby Products: 22.00
#   Travel & Leisure (Flights: 8.65
#   Clothing: 63.65
#   Software & Apps: 48.45
#   Jewelry & Accessories: 7.00
#   Health Care: 14.20
#   Groceries: 47.35
#   Gardening & Outdoors: 25.30
#   Office Supplies: 3.40
#   Animal Feed: 10.80
#
# Total Envy for Item-KNN marital_status_Divorced:
#   Software & Apps: 48.85
#   Mobile Accessories: 10.30
#   Packages): 81.30
#   Jewelry & Accessories: 73.10
#   Baby Products: 17.80
#   Toys & Games: 27.40
#   Groceries: 80.40
#   Office Supplies: 13.40
#   Luxury Goods: 34.50
#   Animal Feed: 87.50
#   Sports & Outdoors: 38.80
#   Travel & Leisure (Flights: 69.40
#   Health Supplements: 13.65
#   Home Appliances: 24.00
#   Hotels: 39.90
#   Clothing: 23.00
#   Furniture: 28.10
#   Beauty & Personal Care: 11.95
#   Books: 15.60
#   Electronics: 73.20
#   Gardening & Outdoors: 16.75
#   Arts & Crafts: 6.00
#   Food & Beverages: 14.20
#   Health Care: 32.00

# %% [markdown]
# Function to calculate Mean Average Envy (MAE) for each demographic group:

# %%
def calculate_group_mae(group_envy, customer_demographics, demographic_columns):
    """
    Calculates Mean Average Envy (MAE) per demographic group, averaging total envy across all comparisons.

    Parameters:
        group_envy (dict):
            Nested dictionary containing total envy per group and category.
        customer_demographics (dict):
            Dictionary mapping customer IDs to demographic attributes.
        demographic_columns (list[str]):
            List of demographic attributes used for grouping.

    Returns:
        dict: Dictionary mapping each demographic group to their MAE value.
              Format: {'demographic_group': MAE_value, ...}
    """
    mae_by_group = {}
    
    # Compute group sizes for envy normalization
    demographic_groups = {col: defaultdict(list) for col in demographic_columns}
    for customer_id, demographics in customer_demographics.items():
        for col in demographic_columns:
            group_value = demographics.get(col, "Unknown")
            demographic_groups[col][group_value].append(customer_id)

    for col, groups in demographic_groups.items():
        for group_value, customers in groups.items():
            group_key = f"{col}_{group_value}"
            num_customers = len(customers)
            num_comparisons = num_customers * (num_customers - 1)  # All possible pairs (both directions)
            
            total_group_envy = sum(group_envy.get(group_key, {}).values())
            mae = total_group_envy / num_comparisons if num_comparisons > 0 else 0.0
            mae_by_group[group_key] = mae
    
    return mae_by_group

# %% [markdown]
# MAE for the SVD++ model:

# %%
svd_group_mae_values = calculate_group_mae(
    svd_group_envy_values, 
    customer_demographics, 
    ['gender', 'age_group', 'income_level', 'education_level', 'occupation', 'marital_status']
)

print("\nMean Average Envy (MAE) per Group (SVD++):")
print("-" * 45)
for group, mae in svd_group_mae_values.items():
    print(f"{group}: {mae:.2f}")
# Out:
# Mean Average Envy (MAE) per Group (SVD++):
# ---------------------------------------------
# gender_Female: 0.18
# gender_Male: 0.18
# gender_Bigender: 0.15
# gender_Genderfluid: 0.19
# gender_Non-binary: 0.18
# gender_Polygender: 0.16
# gender_Agender: 0.20
# gender_Genderqueer: 0.19
# age_group_18–25: 0.18
# age_group_46–50: 0.18
# age_group_26–30: 0.18
# age_group_31–35: 0.18
# age_group_41–45: 0.17
# age_group_36–40: 0.19
# income_level_Middle: 0.19
# income_level_High: 0.17
# education_level_Bachelor's: 0.18
# education_level_High School: 0.17
# education_level_Master's: 0.18
# occupation_Middle: 0.18
# occupation_High: 0.18
# marital_status_Married: 0.19
# marital_status_Single: 0.18
# marital_status_Widowed: 0.17
# marital_status_Divorced: 0.18

# %% [markdown]
# MAE for the ItemKNN model:

# %%
knn_group_mae_values = calculate_group_mae(
    knn_group_envy_values, 
    customer_demographics, 
    ['gender', 'age_group', 'income_level', 'education_level', 'occupation', 'marital_status']
)

print("\nMean Average Envy (MAE) per Group (Item-KNN):")
print("-" * 45)
for group, mae in knn_group_mae_values.items():
    print(f"{group}: {mae:.2f}")
# Out:
# Mean Average Envy (MAE) per Group (Item-KNN):
# ---------------------------------------------
# gender_Female: 0.01
# gender_Male: 0.01
# gender_Bigender: 0.00
# gender_Genderfluid: 0.02
# gender_Non-binary: 0.02
# gender_Polygender: 0.00
# gender_Agender: 0.00
# gender_Genderqueer: 0.00
# age_group_18–25: 0.02
# age_group_46–50: 0.02
# age_group_26–30: 0.01
# age_group_31–35: 0.01
# age_group_41–45: 0.01
# age_group_36–40: 0.01
# income_level_Middle: 0.01
# income_level_High: 0.01
# education_level_Bachelor's: 0.02
# education_level_High School: 0.01
# education_level_Master's: 0.01
# occupation_Middle: 0.01
# occupation_High: 0.01
# marital_status_Married: 0.02
# marital_status_Single: 0.01
# marital_status_Widowed: 0.01
# marital_status_Divorced: 0.01

# %% [markdown]
# Comparing the results to define which model is more fair:

# %%
# --- Convert your group-level MAE results into DataFrames ---
svd_group_mae_df = pd.DataFrame([
    {'Group': group, 'MAE': mae}
    for group, mae in svd_group_mae_values.items()
])

knn_group_mae_df = pd.DataFrame([
    {'Group': group, 'MAE': mae}
    for group, mae in knn_group_mae_values.items()
])

# Add a column to distinguish models
svd_group_mae_df['Model'] = 'SVD++'
knn_group_mae_df['Model'] = 'Item-KNN'

# Combine DataFrames for visualization
combined_mae_df = pd.concat([svd_group_mae_df, knn_group_mae_df])

# --- Optional filtering (Recommended): remove groups with MAE=0 due to no predictions ---
filtered_combined_mae_df = combined_mae_df[combined_mae_df['MAE'] > 0]

# --- Plotting the group-level MAE comparison ---
plt.figure(figsize=(14, 7))
sns.barplot(
    data=filtered_combined_mae_df,
    x='Group',
    y='MAE',
    hue='Model'
)

# Customize plot appearance
plt.title('Group-level Fairness Comparison (Mean Average Envy)', fontsize=16)
plt.xlabel('Demographic Group', fontsize=14)
plt.ylabel('Mean Average Envy (Lower = Fairer)', fontsize=14)
plt.xticks(rotation=75)
plt.legend(title='Recommender Model')
plt.tight_layout()

# Display the plot
plt.show()

# %%
sns.stripplot(data=combined_mae_df, x='MAE', y='Group', hue='Model', dodge=True)
# Out:
# <Axes: xlabel='MAE', ylabel='Group'>

# %%
# Convert MAE dictionaries into DataFrames
svd_mae_df = pd.DataFrame([
    {'Group': group, 'Model': 'SVD++', 'MAE': mae}
    for group, mae in svd_group_mae_values.items()
])

knn_mae_df = pd.DataFrame([
    {'Group': group, 'Model': 'Item-KNN', 'MAE': mae}
    for group, mae in knn_group_mae_values.items()
])

# Combine both into one DataFrame
mae_df = pd.concat([svd_mae_df, knn_mae_df])

# Optional: filter out zero MAE (e.g. due to no predictions)
mae_df = mae_df[mae_df['MAE'] > 0]

# Split the group name into demographic type and value for better structure
mae_df[['Demographic', 'Value']] = mae_df['Group'].str.split('_', n=1, expand=True)

# Pivot table: rows = demographic values, columns = model, separate tables per demographic
for demo_col in mae_df['Demographic'].unique():
    demo_data = mae_df[mae_df['Demographic'] == demo_col]
    heatmap_data = demo_data.pivot(index='Value', columns='Model', values='MAE')

    plt.figure(figsize=(6, max(4, len(heatmap_data) * 0.5)))
    sns.heatmap(heatmap_data, annot=True, cmap='YlOrRd', fmt=".2f", cbar_kws={'label': 'Mean Average Envy'})
    plt.title(f"Group-Level MAE Heatmap ({demo_col.capitalize()})")
    plt.xlabel("Model")
    plt.ylabel(f"{demo_col.capitalize()} Group")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ---
# **3) Absolute Difference (AD) for Group Fairness:**
# ---
# Measuring the disparity between two groups (female and male)

# %%
def calculate_absolute_difference(predictions, customer_demographics, product_categories, gender_key="gender"):
    """
    Calculates Absolute Difference (AD) in predicted ratings between protected (female) 
    and unprotected (male) groups for each product category.

    Parameters:
        predictions (dict):
            Dictionary mapping customer IDs to a list of (category, predicted_rating) tuples.
        customer_demographics (dict):
            Dictionary mapping customer IDs to demographic attributes, including gender.
        product_categories (list):
            List of product categories to evaluate.
        gender_key (str):
            Key in demographic dict for gender. Default is "gender".

    Returns:
        dict: Mapping from product category to AD value (float), or None if one group is missing.
              Format: {category: abs_diff_value or None}
    """
    ad_by_category = {}

    for category in product_categories:
        ratings_male = []
        ratings_female = []

        for customer, recs in predictions.items():
            gender = customer_demographics.get(customer, {}).get(gender_key, "unknown").lower()
            if gender not in {"male", "female"}:
                continue

            for cat, rating in recs:
                if cat == category:
                    if gender == "male":
                        ratings_male.append(rating)
                    elif gender == "female":
                        ratings_female.append(rating)

        if ratings_male and ratings_female:
            avg_male = np.mean(ratings_male)
            avg_female = np.mean(ratings_female)
            ad_by_category[category] = abs(avg_male - avg_female)
        else:
            ad_by_category[category] = None  # Not enough data for comparison

    return ad_by_category

# %%
def create_ad_comparison_df(svd_ad_dict, knn_ad_dict):
    """
    Combines AD values from both models into a single DataFrame for side-by-side comparison.

    Parameters:
        svd_ad_dict (dict): AD values from SVD++ model.
        knn_ad_dict (dict): AD values from Item-KNN model.

    Returns:
        DataFrame: Columns include product category, AD for each model.
    """
    all_categories = sorted(set(svd_ad_dict.keys()) | set(knn_ad_dict.keys()))

    df = pd.DataFrame({
        "Product Category": all_categories,
        "SVD++ AD": [svd_ad_dict.get(cat) for cat in all_categories],
        "Item-KNN AD": [knn_ad_dict.get(cat) for cat in all_categories]
    })

    return df

# %%
def compute_average_ad(ad_dict):
    """
    Compute the average Absolute Difference (AD) across product categories,
    excluding those with missing (None) values.

    Parameters:
        ad_dict (dict): Dictionary mapping category -> AD value (or None).

    Returns:
        float: Mean AD value (overall group fairness score).
    """
    valid_ads = [val for val in ad_dict.values() if val is not None]
    return np.mean(valid_ads) if valid_ads else None

# Define product categories (from user-item matrix index)
product_categories = list(user_item_matrix.index)

# Compute AD for SVD++ model
svd_ad = calculate_absolute_difference(
    svd_top_5_recs, 
    customer_demographics, 
    product_categories,
    gender_key="gender"
)

# Compute AD for Item-KNN model
knn_ad = calculate_absolute_difference(
    knn_top_5_recs, 
    customer_demographics, 
    product_categories,
    gender_key="gender"
)

# Create side-by-side comparison DataFrame
ad_df = create_ad_comparison_df(svd_ad, knn_ad)

# Compute model-level average AD
svd_avg_ad = compute_average_ad(svd_ad)
knn_avg_ad = compute_average_ad(knn_ad)

print(f"\nOverall Fairness (Average AD across categories):")
print(f"SVD++:   {svd_avg_ad:.4f}")
print(f"Item-KNN: {knn_avg_ad:.4f}")
print(f"")
# Print results
print("Absolute Difference (AD) Fairness Metrics by Product Category:")
print(ad_df.to_string(index=False))
# Out:
# Overall Fairness (Average AD across categories):
# SVD++:   0.0373
# Item-KNN: 0.3413
#
# Absolute Difference (AD) Fairness Metrics by Product Category:
#          Product Category  SVD++ AD  Item-KNN AD
#               Animal Feed  0.034418     0.210319
#             Arts & Crafts  0.047097     0.204226
#             Baby Products  0.006537     0.826667
#    Beauty & Personal Care  0.015108     0.719445
#                     Books       NaN     0.095001
#                  Clothing  0.013159     0.649999
#               Electronics  0.003449     0.248180
#          Food & Beverages  0.056980     0.571429
#                 Furniture  0.013926     0.229556
#      Gardening & Outdoors       NaN     0.191996
#                 Groceries  0.231157     0.014912
#               Health Care  0.072802     1.190909
#        Health Supplements  0.073274     0.182323
#           Home Appliances  0.040760     0.206319
#                    Hotels  0.002347     0.645238
#     Jewelry & Accessories  0.100465     0.030000
#              Luxury Goods  0.007097     0.578571
#        Mobile Accessories  0.005167     0.114167
#           Office Supplies  0.038148     0.718270
#                 Packages)  0.014056     0.015004
#           Software & Apps  0.005434     0.118057
#         Sports & Outdoors  0.035619     0.028335
#              Toys & Games  0.002585     0.191251
# Travel & Leisure (Flights  0.001179     0.210714

# %% [markdown]
# ---
# **4) Fraction of Satisfied Users (FSU) for Group Fairness:**
# ---
# Measruing the percentage of users receiving fair treatment.

# %%
def compute_customer_utility(predictions, product_categories):
    """
    Computes the average predicted rating (utility) for each customer 
    based on their top-5 recommendations.

    Parameters:
        predictions (dict):
            Dictionary mapping customer IDs to a list of (category, predicted_rating) tuples.
        product_categories (list[str]):
            List of valid product categories to include.

    Returns:
        dict: Mapping of customer ID to average utility (float).
              Customers with no valid predictions are assigned np.nan.
    """
    utilities = {}

    for customer_id, recs in predictions.items():
        ratings = [rating for category, rating in recs if category in product_categories]
        utilities[customer_id] = np.mean(ratings) if ratings else np.nan

    return utilities

# %%
def compute_fraction_satisfied_by_group(utilities, customer_demographics, group_key):
    """
    Calculates the fraction of satisfied users within each demographic group.
    A user is considered satisfied if their utility is >= their group's average utility.

    Parameters:
        utilities (dict):
            Mapping from customer ID to their average predicted utility.
        customer_demographics (dict):
            Mapping from customer ID to demographic attributes.
        group_key (str):
            The demographic column to group by (e.g., 'gender').

    Returns:
        DataFrame: Group-level statistics including:
            - Number of customers
            - Group average utility
            - Number of satisfied users
            - Fraction satisfied
    """
    records = [
        {
            "CustomerID": customer,
            "Utility": util,
            "Group": customer_demographics.get(customer, {}).get(group_key, "Unknown")
        }
        for customer, util in utilities.items()
        if not np.isnan(util)
    ]

    df = pd.DataFrame(records)

    # Calculate group average utility
    group_avg = df.groupby("Group")["Utility"].mean().reset_index().rename(columns={"Utility": "Group_Avg"})
    df = df.merge(group_avg, on="Group", how="left")

    # Determine satisfaction
    df["Satisfied"] = df["Utility"] >= df["Group_Avg"]

    # Aggregate results per group
    summary = df.groupby("Group").agg(
        Num_Customers=("CustomerID", "count"),
        Group_Avg=("Group_Avg", "first"),
        Num_Satisfied=("Satisfied", "sum")
    ).reset_index()

    summary["Fraction_Satisfied"] = summary["Num_Satisfied"] / summary["Num_Customers"]

    return summary

# %%
# ---------------------------------------------------
# Fraction of Satisfied Users Evaluation
# ---------------------------------------------------

product_categories = list(user_item_matrix.index)

# Compute utilities
svd_utilities = compute_customer_utility(svd_top_5_recs, product_categories)
knn_utilities = compute_customer_utility(knn_top_5_recs, product_categories)

# Demographic columns to evaluate
demographic_columns = ["gender", "age_group", "income_level", "education_level", "occupation", "marital_status"]

# SVD++ Model
print("=== SVD++ Group Fairness Evaluation (Fraction of Satisfied Users) ===")
for demo_col in demographic_columns:
    svd_summary = compute_fraction_satisfied_by_group(svd_utilities, customer_demographics, group_key=demo_col)
    print(f"\n[Demographic Column: {demo_col}]")
    print(svd_summary.to_string(index=False))

# Item-KNN Model
print("\n=== Item-KNN Group Fairness Evaluation (Fraction of Satisfied Users) ===")
for demo_col in demographic_columns:
    knn_summary = compute_fraction_satisfied_by_group(knn_utilities, customer_demographics, group_key=demo_col)
    print(f"\n[Demographic Column: {demo_col}]")
    print(knn_summary.to_string(index=False))
# Out:
# === SVD++ Group Fairness Evaluation (Fraction of Satisfied Users) ===
#
# [Demographic Column: gender]
#       Group  Num_Customers  Group_Avg  Num_Satisfied  Fraction_Satisfied
#     Agender             19   4.048887              8            0.421053
#    Bigender             20   4.015978             10            0.500000
#      Female            452   4.027661            191            0.422566
# Genderfluid             17   4.030948              7            0.411765
# Genderqueer             12   4.058424              4            0.333333
#        Male            449   4.027218            202            0.449889
#  Non-binary             16   4.045831              6            0.375000
#  Polygender             15   4.047063              8            0.533333
#
# [Demographic Column: age_group]
# Group  Num_Customers  Group_Avg  Num_Satisfied  Fraction_Satisfied
# 18–25            222   4.028466             97            0.436937
# 26–30            165   4.018730             62            0.375758
# 31–35            143   4.031878             69            0.482517
# 36–40            167   4.036476             79            0.473054
# 41–45            153   4.027841             70            0.457516
# 46–50            150   4.028794             61            0.406667
#
# [Demographic Column: income_level]
#  Group  Num_Customers  Group_Avg  Num_Satisfied  Fraction_Satisfied
#   High            515   4.021432            222            0.431068
# Middle            485   4.036292            217            0.447423
#
# [Demographic Column: education_level]
#       Group  Num_Customers  Group_Avg  Num_Satisfied  Fraction_Satisfied
#  Bachelor's            341   4.030898            155            0.454545
# High School            331   4.026738            141            0.425982
#    Master's            328   4.028207            144            0.439024
#
# [Demographic Column: occupation]
#  Group  Num_Customers  Group_Avg  Num_Satisfied  Fraction_Satisfied
#   High            517   4.031464            232            0.448743
# Middle            483   4.025615            208            0.430642
#
# [Demographic Column: marital_status]
#    Group  Num_Customers  Group_Avg  Num_Satisfied  Fraction_Satisfied
# Divorced            245   4.025851            111            0.453061
#  Married            253   4.030273            110            0.434783
#   Single            242   4.034632            104            0.429752
#  Widowed            260   4.024097            116            0.446154
#
# === Item-KNN Group Fairness Evaluation (Fraction of Satisfied Users) ===
#
# [Demographic Column: gender]
#       Group  Num_Customers  Group_Avg  Num_Satisfied  Fraction_Satisfied
#     Agender              3   3.508333              1            0.333333
#    Bigender              4   3.958333              2            0.500000
#      Female            104   3.867253             54            0.519231
# Genderfluid              4   3.406248              2            0.500000
# Genderqueer              3   4.273333              1            0.333333
#        Male             87   3.894864             42            0.482759
#  Non-binary              3   3.838889              2            0.666667
#  Polygender              3   3.969466              2            0.666667
#
# [Demographic Column: age_group]
# Group  Num_Customers  Group_Avg  Num_Satisfied  Fraction_Satisfied
# 18–25             53   4.045142             29            0.547170
# 26–30             25   4.072105             13            0.520000
# 31–35             32   3.826276             14            0.437500
# 36–40             36   3.875278             17            0.472222
# 41–45             27   3.777904             15            0.555556
# 46–50             38   3.608591             16            0.421053
#
# [Demographic Column: income_level]
#  Group  Num_Customers  Group_Avg  Num_Satisfied  Fraction_Satisfied
#   High            113   3.830407             57            0.504425
# Middle             98   3.922856             56            0.571429
#
# [Demographic Column: education_level]
#       Group  Num_Customers  Group_Avg  Num_Satisfied  Fraction_Satisfied
#  Bachelor's             77   3.993996             41            0.532468
# High School             67   3.859873             35            0.522388
#    Master's             67   3.748159             32            0.477612
#
# [Demographic Column: occupation]
#  Group  Num_Customers  Group_Avg  Num_Satisfied  Fraction_Satisfied
#   High            105   3.850906             53            0.504762
# Middle            106   3.895573             54            0.509434
#
# [Demographic Column: marital_status]
#    Group  Num_Customers  Group_Avg  Num_Satisfied  Fraction_Satisfied
# Divorced             57   3.772045             30            0.526316
#  Married             60   3.990945             30            0.500000
#   Single             42   3.687444             23            0.547619
#  Widowed             52   3.998845             27            0.519231

# %%
# --- Combine SVD++ and KNN summaries into one DataFrame ---
def build_combined_satisfaction_df(svd_utilities, knn_utilities, customer_demographics, group_key):
    svd_summary = compute_fraction_satisfied_by_group(svd_utilities, customer_demographics, group_key)
    svd_summary['Model'] = 'SVD++'

    knn_summary = compute_fraction_satisfied_by_group(knn_utilities, customer_demographics, group_key)
    knn_summary['Model'] = 'Item-KNN'

    combined_df = pd.concat([svd_summary, knn_summary])
    combined_df['Demographic'] = group_key
    return combined_df


# --- Create bar plots for all demographic columns ---
demographic_columns = ["gender", "age_group", "income_level", "education_level", "occupation", "marital_status"]
satisfaction_all = pd.DataFrame()

for col in demographic_columns:
    df = build_combined_satisfaction_df(svd_utilities, knn_utilities, customer_demographics, group_key=col)
    satisfaction_all = pd.concat([satisfaction_all, df])

# --- Plot: Grouped barplot by demographic group ---
plt.figure(figsize=(14, 7))
sns.barplot(
    data=satisfaction_all,
    x='Group',
    y='Fraction_Satisfied',
    hue='Model'
)
plt.xticks(rotation=75)
plt.title("Fraction of Satisfied Users per Demographic Group")
plt.xlabel("Group")
plt.ylabel("Fraction Satisfied (Utility ≥ Group Avg)")
plt.legend(title="Model")
plt.tight_layout()
plt.show()

# %%
svd_summary_avg = satisfaction_all[satisfaction_all['Model'] == 'SVD++']['Fraction_Satisfied'].mean()
knn_summary_avg = satisfaction_all[satisfaction_all['Model'] == 'Item-KNN']['Fraction_Satisfied'].mean()

print("\n=== Overall Average Fraction Satisfied ===")
print(f"SVD++:    {svd_summary_avg:.4f}")
print(f"Item-KNN: {knn_summary_avg:.4f}")
# Out:
# === Overall Average Fraction Satisfied ===
# SVD++:    0.4368
# Item-KNN: 0.5068

# %%
# Heatmap per demographic dimension
for col in demographic_columns:
    df = build_combined_satisfaction_df(svd_utilities, knn_utilities, customer_demographics, group_key=col)
    pivot_df = df.pivot(index='Group', columns='Model', values='Fraction_Satisfied')

    plt.figure(figsize=(6, max(3, len(pivot_df) * 0.5)))
    sns.heatmap(pivot_df, annot=True, fmt=".2f", cmap="Greens", cbar_kws={'label': 'Fraction Satisfied'})
    plt.title(f"Fraction of Satisfied Users (Demographic: {col.capitalize()})")
    plt.ylabel(f"{col.capitalize()} Group")
    plt.xlabel("Model")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ---
